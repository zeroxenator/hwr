# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *
# Out:
# Using TensorFlow backend.

# %%
path = 'image-data/test9.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image, path, plot = True)
# Out:
# Average word height and width: 50.333333333333336 45.432432432432435
# [193.7352017785179, 5]
# [305.9639389558141, 2]
# [332.82761156369406, 2]
# [425.78491883105823, 14]
# [529.0210495496884, 14]
# [639.8830505453076, 14]
# [759.8398231938579, 16]
# [906.0112971658515, 5]
# [995.8724500188524, 10]
# [1112.3283444218491, 7]
# [1219.3276257860648, 10]
# [1349.3118859514957, 8]
# [1468.593700509506, 4]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 300)               399600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 27)                8127
# =================================================================
# Total params: 407,727
# Trainable params: 407,727
# Non-trainable params: 0
# _________________________________________________________________
# LSTM model: None
# Recognizing the following word:
# -----CNN:-------
# 15
# 44
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf jpg'] [0.92290425]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet jpg', 'alef jpg'] [0.85703516, 0.09820251]
# ---------------------------------------------------
#
#
# Candidates: [['kaf jpg'], ['bet jpg', 'alef jpg']]
# Combinations: [('kaf jpg', 'bet jpg'), ('kaf jpg', 'alef jpg')]
# Combi: ('kaf jpg', 'bet jpg') Probability: 0
# Combi: ('kaf jpg', 'alef jpg') Probability: 0
# Best word: kaf jpg_bet jpg
# Best?!: ['kaf jpg', 'bet jpg']
# -----LSTM:-------
# orig shape: (96, 79)
# [ 39   0  10  33 209]
# [ 15  34  32  43 664]
# [ 44  34  31  25 393]
# [19 66  5 14 70]
# [49 70  9  7 56]
# [ 4 86  8  6 43]
# N chars: 2
# Trimmed output: [[0.06200261 0.1649741  0.1832947  0.8575671 ]]
# Idx: [ 1  9 20 23]
# Word-wise predictions: ['ayin', 'lamed', 'taw', 'tsadi-medial']
# Trimmed output: [[0.66838044]]
# Idx: [0]
# Character recognition: ['alef']
# Trimmed output: [[0.5267192]]
# Idx: [18]
# Character recognition: ['samekh']
# Recognizing the following word:
# -----CNN:-------
# 4
# 40
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final jpg'] [0.9602228]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem medial jpg'] [0.97925055]
# ---------------------------------------------------
#
#
# Candidates: [['nun final jpg'], ['mem medial jpg']]
# Combinations: [('nun final jpg', 'mem medial jpg')]
# Combi: ('nun final jpg', 'mem medial jpg') Probability: 0
# Best word: nun final jpg_mem medial jpg
# Best?!: ['nun final jpg', 'mem medial jpg']
# -----LSTM:-------
# orig shape: (88, 83)
# [  4   4  37  64 960]
# [66 18  5  6 30]
# [72 20  7  5 35]
# [ 40  30  22  27 300]
# [ 31  59  13  14 116]
# [13 73  5  5 25]
# [20 78  6  6 35]
# N chars: 1
# Trimmed output: [[0.09076615 0.09900283 0.5122278  0.60691893]]
# Idx: [ 4  9 16 19]
# Word-wise predictions: ['gimel', 'lamed', 'qof', 'shin']
# Trimmed output: [[0.38569406]]
# Idx: [18]
# Character recognition: ['samekh']
# Recognizing the following word:
# -----CNN:-------
# 9
# 73
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem medial jpg'] [0.9995277]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf jpg'] [0.97765666]
# ---------------------------------------------------
#
#
# Candidates: [['mem medial jpg'], ['kaf jpg']]
# Combinations: [('mem medial jpg', 'kaf jpg')]
# Combi: ('mem medial jpg', 'kaf jpg') Probability: 0
# Best word: mem medial jpg_kaf jpg
# Best?!: ['mem medial jpg', 'kaf jpg']
# -----LSTM:-------
# orig shape: (49, 104)
# [  9   4  34  41 609]
# [ 4  6  9  5 45]
# [ 48   9  18  19 265]
# [ 73  12  15  11 127]
# [ 73  13  27  29 364]
# [39 34  5  7 35]
# [63 36  8  9 66]
# N chars: 2
# Trimmed output: [[0.21430808 0.46504328 0.49602184 0.8362088 ]]
# Idx: [ 2  7  9 21]
# Word-wise predictions: ['bet', 'kaf', 'lamed', 'tet']
# Trimmed output: [[0.4622242]]
# Idx: [2]
# Character recognition: ['bet']
# Trimmed output: [[0.96800643]]
# Idx: [7]
# Character recognition: ['kaf']
# Recognizing the following word:
# -----CNN:-------
# 4
# 56
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin jpg', 'bet jpg'] [0.48249778, 0.4645786]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef jpg'] [0.99284923]
# ---------------------------------------------------
#
#
# Candidates: [['ayin jpg', 'bet jpg'], ['alef jpg']]
# Combinations: [('ayin jpg', 'alef jpg'), ('bet jpg', 'alef jpg')]
# Combi: ('ayin jpg', 'alef jpg') Probability: 0
# Combi: ('bet jpg', 'alef jpg') Probability: 0
# Best word: ayin jpg_alef jpg
# Best?!: ['ayin jpg', 'alef jpg']
# -----LSTM:-------
# orig shape: (55, 185)
# [   4    4   48   47 1275]
# [  56    6   52   44 1246]
# [147  19  10  27 173]
# [123  21   5   5  25]
# [132  22   7   5  35]
# [111  26   7   8  53]
# [170  27  11  12  94]
# [127  35   8  13  91]
# [165  43   5   5  25]
# N chars: 2
# Trimmed output: [[0.12003291 0.20056142 0.31912652 0.74561375]]
# Idx: [ 3 11 13 19]
# Word-wise predictions: ['dalet', 'mem-medial', 'nun-medial', 'shin']
# Trimmed output: [[0.5492465]]
# Idx: [0]
# Character recognition: ['alef']
# Trimmed output: [[0.98830825]]
# Idx: [24]
# Character recognition: ['waw']
# Recognizing the following word:
# -----CNN:-------
# 8
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin jpg'] [0.99930525]
# ---------------------------------------------------
#
#
# Candidates: [['ayin jpg']]
# Combinations: [('ayin jpg',)]
# Combi: ('ayin jpg',) Probability: 0
# Best word: ayin jpg
# Best?!: ['ayin jpg']
# -----LSTM:-------
# orig shape: (37, 37)
# [  4   5  14  13 137]
# [  8   4  25  29 263]
# N chars: 0
# Trimmed output: [[0.01752216 0.01754838 0.03272733 0.9989956 ]]
# Idx: [ 1  2 13 19]
# Word-wise predictions: ['ayin', 'bet', 'nun-medial', 'shin']
# Recognizing the following word:
# -----CNN:-------
# 4
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh jpg', 'mem medial jpg'] [0.6438565, 0.2725965]
# ---------------------------------------------------
#
#
# Candidates: [['resh jpg', 'mem medial jpg']]
# Combinations: [('resh jpg',), ('mem medial jpg',)]
# Combi: ('resh jpg',) Probability: 0
# Combi: ('mem medial jpg',) Probability: 0
# Best word: resh jpg
# Best?!: ['resh jpg']
# -----LSTM:-------
# orig shape: (45, 48)
# [38  2  6  8 46]
# [  4   5  34  36 656]
# N chars: 1
# Trimmed output: [[0.00426824 0.00700632 0.01602162 0.9327357 ]]
# Idx: [ 1  9 18 20]
# Word-wise predictions: ['ayin', 'lamed', 'samekh', 'taw']
# Trimmed output: [[0.6730421]]
# Idx: [1]
# Character recognition: ['ayin']
# Recognizing the following word:
# -----CNN:-------
# 4
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 2 recognition: ['bet jpg'] [0.99103713]
# Recognizing the following character:
# Recognition result: ['bet jpg'] [0.99103713]
# ---------------------------------------------------
#
#
# Candidates: [['bet jpg']]
# Combinations: [('bet jpg',)]
# Combi: ('bet jpg',) Probability: 0
# Best word: bet jpg
# Best?!: ['bet jpg']
# -----LSTM:-------
# orig shape: (70, 77)
# [   4    0   57   66 2088]
# [68 47  5  5 25]
# N chars: 1
# Trimmed output: [[0.02198306 0.02593316 0.02720289 0.03203344]]
# Idx: [ 1  5  9 19]
# Word-wise predictions: ['ayin', 'he', 'lamed', 'shin']
# Trimmed output: [[0.20776701]]
# Idx: [18]
# Character recognition: ['samekh']
# Recognizing the following word:
# -----CNN:-------
# 4
# 26
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['waw jpg', 'he jpg'] [0.6942143, 0.3010927]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf jpg', 'nun final jpg'] [0.716395, 0.28237468]
# ---------------------------------------------------
#
#
# Candidates: [['waw jpg', 'he jpg'], ['kaf jpg', 'nun final jpg']]
# Combinations: [('waw jpg', 'kaf jpg'), ('waw jpg', 'nun final jpg'), ('he jpg', 'kaf jpg'), ('he jpg', 'nun final jpg')]
# Combi: ('waw jpg', 'kaf jpg') Probability: 0
# Combi: ('waw jpg', 'nun final jpg') Probability: 0
# Combi: ('he jpg', 'kaf jpg') Probability: 0
# Combi: ('he jpg', 'nun final jpg') Probability: 0
# Best word: waw jpg_kaf jpg
# Best?!: ['waw jpg', 'kaf jpg']
# -----LSTM:-------
# orig shape: (82, 99)
# [  4   4  38  74 845]
# [  26    4   48   47 1067]
# [ 82   4  13  36 263]
# N chars: 2
# Trimmed output: [[0.0025415  0.01026992 0.9793466  0.98717993]]
# Idx: [16 17 24 25]
# Word-wise predictions: ['qof', 'resh', 'waw', 'yod']
# Trimmed output: [[0.9842657]]
# Idx: [25]
# Character recognition: ['yod']
# Trimmed output: [[0.48946786]]
# Idx: [24]
# Character recognition: ['waw']
# Recognizing the following word:
# -----CNN:-------
# 4
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh jpg', 'mem medial jpg'] [0.6438565, 0.2725965]
# ---------------------------------------------------
#
#
# Candidates: [['resh jpg', 'mem medial jpg']]
# Combinations: [('resh jpg',), ('mem medial jpg',)]
# Combi: ('resh jpg',) Probability: 0
# Combi: ('mem medial jpg',) Probability: 0
# Best word: resh jpg
# Best?!: ['resh jpg']
# -----LSTM:-------
# orig shape: (45, 48)
# [38  2  6  8 46]
# [  4   5  34  36 656]
# N chars: 1
# Trimmed output: [[0.00426824 0.00700632 0.01602162 0.9327357 ]]
# Idx: [ 1  9 18 20]
# Word-wise predictions: ['ayin', 'lamed', 'samekh', 'taw']
# Trimmed output: [[0.6730421]]
# Idx: [1]
# Character recognition: ['ayin']
# Recognizing the following word:
# -----CNN:-------
# 4
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 2 recognition: ['bet jpg'] [0.99103713]
# Recognizing the following character:
# Recognition result: ['bet jpg'] [0.99103713]
# ---------------------------------------------------
#
#
# Candidates: [['bet jpg']]
# Combinations: [('bet jpg',)]
# Combi: ('bet jpg',) Probability: 0
# Best word: bet jpg
# Best?!: ['bet jpg']
# -----LSTM:-------
# orig shape: (70, 77)
# [   4    0   57   66 2088]
# [68 47  5  5 25]
# N chars: 1
# Trimmed output: [[0.02198306 0.02593316 0.02720289 0.03203344]]
# Idx: [ 1  5  9 19]
# Word-wise predictions: ['ayin', 'he', 'lamed', 'shin']
# Trimmed output: [[0.20776701]]
# Idx: [18]
# Character recognition: ['samekh']
# Recognizing the following word:
# -----CNN:-------
# 4
# 26
# Component small enough,  proceed to recognition:
# Recognizing the following character:
