# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *

# %%
path = 'image-data/test7.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image)
# Out:
# Average word height and width: 42.7826086957 40.2753623188
# [178.958549025704, 7]
# [276.01291215214536, 8]
# [374.37640337702828, 10]
# [473.46429425556693, 11]
# [574.29642259252137, 9]
# [-100, 1]
# [680.61700515462769, 7]
# [772.78946131344549, 7]
# [862.57059468923853, 6]
# [956.73354023412867, 2]
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['qof', 'yod', 'samekh'] [0.43633935, 0.29850233, 0.11746687]
# Recognizing the following character:
# Window position 1 recognition: ['samekh', 'tet'] [0.54505998, 0.33202976]
# Recognizing the following character:
# Window position 2 recognition: ['tet', 'bet', 'samekh', 'mem'] [0.3049818, 0.30255446, 0.20205259, 0.14630884]
#
# Character found at position 0 :
#
# Character found at position 1 :
# Recognizing the following character:
# Recognition result: ['samekh', 'tet'] [0.54505998, 0.33202976]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.93293977]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['mem'] [0.98272818]
#
# Character found at position -1 :
# Recognizing the following character:
# Recognition result: ['mem'] [0.98272818]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he', 'het'] [0.64070165, 0.27984497]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'het', 'nun medial', 'qof'] [0.3502132, 0.27462557, 0.15691313, 0.13338372]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['yod'] [0.98262042]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.98790526]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun medial', 'ayin'] [0.42667818, 0.40043429]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['gimel', 'yod'] [0.79333055, 0.16872644]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'nun final'] [0.82161355, 0.14813159]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final', 'resh'] [0.57162499, 0.28069031]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'nun final'] [0.73641551, 0.10997623]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['alef'] [0.98360944]
#
# Character found at position -1 :
# Recognizing the following character:
# Recognition result: ['alef'] [0.98360944]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'nun final'] [0.48586652, 0.48554507]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['lamed', 'dalet'] [0.46985748, 0.37898079]
# Recognizing the following character:
# Window position 1 recognition: ['kaf', 'dalet', 'lamed'] [0.32805499, 0.30822086, 0.19620898]
#
# Character found at position 0 :
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['lamed', 'dalet'] [0.46985748, 0.37898079]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 18 recognition: ['kaf', 'bet'] [0.76596415, 0.23305535]
#
# Character found at position 0 :
#
# Character found at position 17 :
# Recognizing the following character:
