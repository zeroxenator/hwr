# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *

# %%
path = 'image-data/test7.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image, path, plot = True)
# Out:
# Average word height and width: 46.756097561 48.8536585366
# [180.77048608910576, 2]
# [276.49260643658334, 6]
# [374.35393888946328, 9]
# [471.2077636734503, 7]
# [572.56363456938016, 6]
# [681.55802704933114, 6]
# [771.57482060431869, 3]
# [-100, 1]
# Recognizing the following word:
# 5
# 41
# 62
# 105
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['waw', 'lamed'] [0.68002832, 0.15822014]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet', 'resh', 'he'] [0.43125507, 0.23767066, 0.23350467]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final'] [0.99016577]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he'] [0.97360319]
# ---------------------------------------------------
#
#
# Candidates: [['waw', 'lamed'], ['dalet', 'resh', 'he'], ['nun-final'], ['he']]
# Combinations: [('waw', 'dalet', 'nun-final', 'he'), ('waw', 'resh', 'nun-final', 'he'), ('waw', 'he', 'nun-final', 'he'), ('lamed', 'dalet', 'nun-final', 'he'), ('lamed', 'resh', 'nun-final', 'he'), ('lamed', 'he', 'nun-final', 'he')]
# Combi: ('waw', 'dalet', 'nun-final', 'he') Probability: 0
# Combi: ('waw', 'resh', 'nun-final', 'he') Probability: 0
# Combi: ('waw', 'he', 'nun-final', 'he') Probability: 0
# Combi: ('lamed', 'dalet', 'nun-final', 'he') Probability: 0
# Combi: ('lamed', 'resh', 'nun-final', 'he') Probability: 0
# Combi: ('lamed', 'he', 'nun-final', 'he') Probability: 0
# Best word: waw_dalet_nun-final_he
# Recognizing the following word:
# 5
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem', 'samekh', 'het'] [0.38899642, 0.29031089, 0.15875322]
# ---------------------------------------------------
#
#
# Candidates: [['mem', 'samekh', 'het']]
# Combinations: [('mem',), ('samekh',), ('het',)]
# Combi: ('mem',) Probability: 0
# Combi: ('samekh',) Probability: 0.005610561056105611
# Combi: ('het',) Probability: 0.02706270627062706
# Best word: het
# Recognizing the following word:
# 14
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'samekh', 'qof'] [0.29175302, 0.25896764, 0.19544548]
# ---------------------------------------------------
#
#
# Candidates: [['resh', 'samekh', 'qof']]
# Combinations: [('resh',), ('samekh',), ('qof',)]
# Combi: ('resh',) Probability: 0.020297029702970298
# Combi: ('samekh',) Probability: 0.005610561056105611
# Combi: ('qof',) Probability: 0.016336633663366337
# Best word: resh
# Recognizing the following word:
# 5
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.89975488]
# ---------------------------------------------------
#
#
# Candidates: [['ayin']]
# Combinations: [('ayin',)]
# Combi: ('ayin',) Probability: 0.036138613861386136
# Best word: ayin
# test7
# Recognizing the following word:
# 5
# 40
# 61
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-medial'] [0.88042933]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet', 'ayin', 'nun-final'] [0.70342058, 0.19529185, 0.091764294]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.99801183]
# ---------------------------------------------------
#
#
# Candidates: [['nun-medial'], ['dalet', 'ayin', 'nun-final'], ['resh']]
# Combinations: [('nun-medial', 'dalet', 'resh'), ('nun-medial', 'ayin', 'resh'), ('nun-medial', 'nun-final', 'resh')]
# Combi: ('nun-medial', 'dalet', 'resh') Probability: 2.5907341288613294e-05
# Combi: ('nun-medial', 'ayin', 'resh') Probability: 1.2230613256784359e-05
# Combi: ('nun-medial', 'nun-final', 'resh') Probability: 0
# Best word: nun-medial_dalet_resh
# Best is in names!
# נדר
# Recognizing the following word:
# 5
# 13
# 54
# 91
# 95
# 118
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['yod'] [0.90744829]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf', 'bet'] [0.83430141, 0.15698604]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf'] [0.99545896]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet'] [0.95792222]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final', 'taw', 'alef'] [0.63845778, 0.12427419, 0.094629958]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet'] [0.93037933]
# ---------------------------------------------------
#
#
# Candidates: [['yod'], ['kaf', 'bet'], ['kaf'], ['dalet'], ['nun-final', 'taw', 'alef'], ['dalet']]
# Combinations: [('yod', 'kaf', 'kaf', 'dalet', 'nun-final', 'dalet'), ('yod', 'kaf', 'kaf', 'dalet', 'taw', 'dalet'), ('yod', 'kaf', 'kaf', 'dalet', 'alef', 'dalet'), ('yod', 'bet', 'kaf', 'dalet', 'nun-final', 'dalet'), ('yod', 'bet', 'kaf', 'dalet', 'taw', 'dalet'), ('yod', 'bet', 'kaf', 'dalet', 'alef', 'dalet')]
# Combi: ('yod', 'kaf', 'kaf', 'dalet', 'nun-final', 'dalet') Probability: 0
# Combi: ('yod', 'kaf', 'kaf', 'dalet', 'taw', 'dalet') Probability: 5.8968542904883256e-12
# Combi: ('yod', 'kaf', 'kaf', 'dalet', 'alef', 'dalet') Probability: 5.930607435392606e-12
# Combi: ('yod', 'bet', 'kaf', 'dalet', 'nun-final', 'dalet') Probability: 0
# Combi: ('yod', 'bet', 'kaf', 'dalet', 'taw', 'dalet') Probability: 3.033251959153548e-11
# Combi: ('yod', 'bet', 'kaf', 'dalet', 'alef', 'dalet') Probability: 3.0506140623809665e-11
# Best word: yod_bet_kaf_dalet_alef_dalet
# Recognizing the following word:
# 5
# 39
# 89
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef'] [0.98113948]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet'] [0.9991191]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet', 'resh'] [0.79634488, 0.16912752]
# ---------------------------------------------------
#
#
# Candidates: [['alef'], ['tet'], ['dalet', 'resh']]
# Combinations: [('alef', 'tet', 'dalet'), ('alef', 'tet', 'resh')]
# Combi: ('alef', 'tet', 'dalet') Probability: 0.0
# Combi: ('alef', 'tet', 'resh') Probability: 0.0
# Best word: alef_tet_dalet
# Recognizing the following word:
# 5
# 74
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'bet'] [0.87056881, 0.098350823]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['bet', 'resh', 'kaf'] [0.70891887, 0.18543091, 0.094016537]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['bet', 'resh', 'kaf'] [0.70891887, 0.18543091, 0.094016537]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 25 recognition: ['bet'] [0.99994719]
#
# Character found at position 24 :
# Recognizing the following character:
# Recognition result: ['bet'] [0.95855236]
# ---------------------------------------------------
#
#
# Candidates: [['resh', 'bet'], ['bet'], ['bet', 'resh', 'kaf']]
# Combinations: [('resh', 'bet', 'bet'), ('resh', 'bet', 'resh'), ('resh', 'bet', 'kaf'), ('bet', 'bet', 'bet'), ('bet', 'bet', 'resh'), ('bet', 'bet', 'kaf')]
# Combi: ('resh', 'bet', 'bet') Probability: 0.000278722664836041
# Combi: ('resh', 'bet', 'resh') Probability: 0.00020839188214840553
# Combi: ('resh', 'bet', 'kaf') Probability: 0.00012704930834282028
# Combi: ('bet', 'bet', 'bet') Probability: 9.292303743380953e-05
# Combi: ('bet', 'bet', 'resh') Probability: 6.947553646980754e-05
# Combi: ('bet', 'bet', 'kaf') Probability: 4.235682678344182e-05
# Best word: resh_bet_bet
# test7
# Recognizing the following word:
# 5
# 77
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed'] [0.99998546]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['nun-final', 'tsadi-final'] [0.52965534, 0.33352768]
# Recognizing the following character:
# Window position 1 recognition: ['lamed', 'nun-final'] [0.6070286, 0.24074835]
# Recognizing the following character:
# Window position 2 recognition: ['nun-final', 'het', 'tsadi-final'] [0.5145303, 0.24093643, 0.11753036]
#
# Character found at position 1 :
# Recognizing the following character:
# Recognition result: ['qof', 'kaf-final'] [0.56060487, 0.42782348]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 29 recognition: ['tet'] [0.89551693]
#
# Character found at position 28 :
# Recognizing the following character:
# Recognition result: ['mem', 'tet'] [0.83967143, 0.13006394]
# ---------------------------------------------------
#
#
# Candidates: [['lamed'], ['mem', 'tet'], ['qof', 'kaf-final']]
# Combinations: [('lamed', 'mem', 'qof'), ('lamed', 'mem', 'kaf-final'), ('lamed', 'tet', 'qof'), ('lamed', 'tet', 'kaf-final')]
# Combi: ('lamed', 'mem', 'qof') Probability: 0.0
# Combi: ('lamed', 'mem', 'kaf-final') Probability: 0.0
# Combi: ('lamed', 'tet', 'qof') Probability: 0.0
# Combi: ('lamed', 'tet', 'kaf-final') Probability: 0.0
# Best word: lamed_mem_qof
# test7
# Recognizing the following word:
# 5
# 16
# 78
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'nun-medial'] [0.87877512, 0.10801756]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'lamed', 'nun-final'] [0.57771313, 0.26483759, 0.082741231]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final'] [0.99746752]
# ---------------------------------------------------
#
#
# Candidates: [['ayin', 'nun-medial'], ['ayin', 'lamed', 'nun-final'], ['nun-final']]
# Combinations: [('ayin', 'ayin', 'nun-final'), ('ayin', 'lamed', 'nun-final'), ('ayin', 'nun-final', 'nun-final'), ('nun-medial', 'ayin', 'nun-final'), ('nun-medial', 'lamed', 'nun-final'), ('nun-medial', 'nun-final', 'nun-final')]
# Combi: ('ayin', 'ayin', 'nun-final') Probability: 0.0
# Combi: ('ayin', 'lamed', 'nun-final') Probability: 0.0
# Combi: ('ayin', 'nun-final', 'nun-final') Probability: 0
# Combi: ('nun-medial', 'ayin', 'nun-final') Probability: 0.0
# Combi: ('nun-medial', 'lamed', 'nun-final') Probability: 0.0
# Combi: ('nun-medial', 'nun-final', 'nun-final') Probability: 0
# Best word: ayin_ayin_nun-final
# Recognizing the following word:
# 17
# 65
# 95
# 119
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet', 'bet'] [0.86531377, 0.10600868]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['waw'] [0.90041256]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet', 'kaf', 'resh', 'bet'] [0.46149462, 0.23291364, 0.21483588, 0.086415321]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['taw', 'mem'] [0.63830745, 0.33205017]
# ---------------------------------------------------
#
#
# Candidates: [['tet', 'bet'], ['waw'], ['dalet', 'kaf', 'resh', 'bet'], ['taw', 'mem']]
# Combinations: [('tet', 'waw', 'dalet', 'taw'), ('tet', 'waw', 'dalet', 'mem'), ('tet', 'waw', 'kaf', 'taw'), ('tet', 'waw', 'kaf', 'mem'), ('tet', 'waw', 'resh', 'taw'), ('tet', 'waw', 'resh', 'mem'), ('tet', 'waw', 'bet', 'taw'), ('tet', 'waw', 'bet', 'mem'), ('bet', 'waw', 'dalet', 'taw'), ('bet', 'waw', 'dalet', 'mem'), ('bet', 'waw', 'kaf', 'taw'), ('bet', 'waw', 'kaf', 'mem'), ('bet', 'waw', 'resh', 'taw'), ('bet', 'waw', 'resh', 'mem'), ('bet', 'waw', 'bet', 'taw'), ('bet', 'waw', 'bet', 'mem')]
# Combi: ('tet', 'waw', 'dalet', 'taw') Probability: 1.0361004350802155e-05
# Combi: ('tet', 'waw', 'dalet', 'mem') Probability: 0.0
# Combi: ('tet', 'waw', 'kaf', 'taw') Probability: 9.23734585394821e-06
# Combi: ('tet', 'waw', 'kaf', 'mem') Probability: 0.0
# Combi: ('tet', 'waw', 'resh', 'taw') Probability: 1.927807870053371e-05
# Combi: ('tet', 'waw', 'resh', 'mem') Probability: 0.0
# Combi: ('tet', 'waw', 'bet', 'taw') Probability: 1.6912746411874582e-05
# Combi: ('tet', 'waw', 'bet', 'mem') Probability: 0.0
# Combi: ('bet', 'waw', 'dalet', 'taw') Probability: 5.6595057240110485e-06
# Combi: ('bet', 'waw', 'dalet', 'mem') Probability: 0.0
# Combi: ('bet', 'waw', 'kaf', 'taw') Probability: 5.045728190534171e-06
# Combi: ('bet', 'waw', 'kaf', 'mem') Probability: 0.0
# Combi: ('bet', 'waw', 'resh', 'taw') Probability: 1.0530291568226117e-05
# Combi: ('bet', 'waw', 'resh', 'mem') Probability: 0.0
# Combi: ('bet', 'waw', 'bet', 'taw') Probability: 9.23827284363036e-06
# Combi: ('bet', 'waw', 'bet', 'mem') Probability: 0.0
# Best word: tet_waw_resh_taw
# Recognizing the following word:
# 5
# 46
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef', 'ayin'] [0.64620668, 0.27280375]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tsadi-final'] [0.98100567]
# ---------------------------------------------------
#
#
# Candidates: [['alef', 'ayin'], ['tsadi-final']]
# Combinations: [('alef', 'tsadi-final'), ('ayin', 'tsadi-final')]
# Combi: ('alef', 'tsadi-final') Probability: 0.0
# Combi: ('ayin', 'tsadi-final') Probability: 0.0
# Best word: alef_tsadi-final
# Recognizing the following word:
# 5
# 43
# 49
# 74
# 112
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet', 'kaf'] [0.77795488, 0.1965013]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he', 'taw', 'het', 'dalet'] [0.50596339, 0.15072316, 0.14152017, 0.13937686]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.99985766]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet', 'kaf'] [0.52875578, 0.46907932]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf'] [0.94592655]
# ---------------------------------------------------
#
#
# Candidates: [['dalet', 'kaf'], ['he', 'taw', 'het', 'dalet'], ['ayin'], ['bet', 'kaf'], ['kaf']]
# Combinations: [('dalet', 'he', 'ayin', 'bet', 'kaf'), ('dalet', 'he', 'ayin', 'kaf', 'kaf'), ('dalet', 'taw', 'ayin', 'bet', 'kaf'), ('dalet', 'taw', 'ayin', 'kaf', 'kaf'), ('dalet', 'het', 'ayin', 'bet', 'kaf'), ('dalet', 'het', 'ayin', 'kaf', 'kaf'), ('dalet', 'dalet', 'ayin', 'bet', 'kaf'), ('dalet', 'dalet', 'ayin', 'kaf', 'kaf'), ('kaf', 'he', 'ayin', 'bet', 'kaf'), ('kaf', 'he', 'ayin', 'kaf', 'kaf'), ('kaf', 'taw', 'ayin', 'bet', 'kaf'), ('kaf', 'taw', 'ayin', 'kaf', 'kaf'), ('kaf', 'het', 'ayin', 'bet', 'kaf'), ('kaf', 'het', 'ayin', 'kaf', 'kaf'), ('kaf', 'dalet', 'ayin', 'bet', 'kaf'), ('kaf', 'dalet', 'ayin', 'kaf', 'kaf')]
# Combi: ('dalet', 'he', 'ayin', 'bet', 'kaf') Probability: 9.17357104594842e-08
# Combi: ('dalet', 'he', 'ayin', 'kaf', 'kaf') Probability: 3.8485842962233884e-10
# Combi: ('dalet', 'taw', 'ayin', 'bet', 'kaf') Probability: 3.70949371361021e-08
# Combi: ('dalet', 'taw', 'ayin', 'kaf', 'kaf') Probability: 1.5562422944819156e-10
# Combi: ('dalet', 'het', 'ayin', 'bet', 'kaf') Probability: 0.0
# Combi: ('dalet', 'het', 'ayin', 'kaf', 'kaf') Probability: 0.0
# Combi: ('dalet', 'dalet', 'ayin', 'bet', 'kaf') Probability: 7.51722387559451e-09
# Combi: ('dalet', 'dalet', 'ayin', 'kaf', 'kaf') Probability: 3.153697683693856e-11
# Combi: ('kaf', 'he', 'ayin', 'bet', 'kaf') Probability: 3.0841339280325253e-07
# Combi: ('kaf', 'he', 'ayin', 'kaf', 'kaf') Probability: 1.2938853739098704e-09
# Combi: ('kaf', 'taw', 'ayin', 'bet', 'kaf') Probability: 3.9491337947134465e-08
# Combi: ('kaf', 'taw', 'ayin', 'kaf', 'kaf') Probability: 1.6567783941382155e-10
# Combi: ('kaf', 'het', 'ayin', 'bet', 'kaf') Probability: 0.0
# Combi: ('kaf', 'het', 'ayin', 'kaf', 'kaf') Probability: 0.0
# Combi: ('kaf', 'dalet', 'ayin', 'bet', 'kaf') Probability: 2.660947722125803e-08
# Combi: ('kaf', 'dalet', 'ayin', 'kaf', 'kaf') Probability: 1.1163462478407173e-10
# Best word: kaf_he_ayin_bet_kaf
# Recognizing the following word:
# 5
# 20
# 73
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.9769693]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.92769545]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf'] [0.93383729]
# ---------------------------------------------------
#
#
# Candidates: [['resh'], ['ayin'], ['kaf']]
# Combinations: [('resh', 'ayin', 'kaf')]
# Combi: ('resh', 'ayin', 'kaf') Probability: 1.114023177980122e-06
# Best word: resh_ayin_kaf
# test7
# Recognizing the following word:
# 5
# 50
# 99
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het'] [0.99451339]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet'] [0.97799635]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'he', 'mem'] [0.64992887, 0.12366749, 0.11437406]
# ---------------------------------------------------
#
#
# Candidates: [['het'], ['tet'], ['resh', 'he', 'mem']]
# Combinations: [('het', 'tet', 'resh'), ('het', 'tet', 'he'), ('het', 'tet', 'mem')]
# Combi: ('het', 'tet', 'resh') Probability: 2.0752000421038866e-05
# Combi: ('het', 'tet', 'he') Probability: 0.00028816598958645835
# Combi: ('het', 'tet', 'mem') Probability: 0.0
# Best word: het_tet_he
# Recognizing the following word:
# 5
# 61
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.97282594]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'tsadi-final'] [0.89685571, 0.093747556]
# ---------------------------------------------------
#
#
# Candidates: [['ayin'], ['ayin', 'tsadi-final']]
# Combinations: [('ayin', 'ayin'), ('ayin', 'tsadi-final')]
# Combi: ('ayin', 'ayin') Probability: 0.0
# Combi: ('ayin', 'tsadi-final') Probability: 0.0
# Best word: ayin_ayin
# Recognizing the following word:
# 21
# 44
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['resh'] [0.99966526]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['resh'] [0.99966526]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 25 recognition: ['ayin'] [0.99619138]
#
# Character found at position 24 :
# Recognizing the following character:
# Recognition result: ['alef', 'ayin'] [0.58300614, 0.3455357]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'resh', 'nun-medial'] [0.57352161, 0.25079474, 0.096920967]
# ---------------------------------------------------
#
#
# Candidates: [['alef', 'ayin'], ['resh'], ['ayin', 'resh', 'nun-medial']]
# Combinations: [('alef', 'resh', 'ayin'), ('alef', 'resh', 'resh'), ('alef', 'resh', 'nun-medial'), ('ayin', 'resh', 'ayin'), ('ayin', 'resh', 'resh'), ('ayin', 'resh', 'nun-medial')]
# Combi: ('alef', 'resh', 'ayin') Probability: 0.00011473055699472815
# Combi: ('alef', 'resh', 'resh') Probability: 1.1610398214942252e-06
# Combi: ('alef', 'resh', 'nun-medial') Probability: 9.429908794087248e-06
# Combi: ('ayin', 'resh', 'ayin') Probability: 8.654068355433506e-05
# Combi: ('ayin', 'resh', 'resh') Probability: 8.757665125824354e-07
# Combi: ('ayin', 'resh', 'nun-medial') Probability: 7.112932894876858e-06
# Best word: alef_resh_ayin
# Best is in names!
# ארע
# Recognizing the following word:
# 5
# 40
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['he', 'dalet', 'mem'] [0.68089539, 0.14365597, 0.12156756]
# Recognizing the following character:
# Window position 1 recognition: ['dalet', 'he', 'mem'] [0.4605836, 0.44515282, 0.092550747]
# Recognizing the following character:
# Window position 2 recognition: ['mem', 'dalet'] [0.84219342, 0.08750543]
#
# Character found at position 1 :
# Recognizing the following character:
# Recognition result: ['kaf', 'mem'] [0.79110056, 0.10664723]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 27 recognition: ['kaf'] [0.91477817]
#
# Character found at position 26 :
# Recognizing the following character:
# Recognition result: ['kaf'] [0.88997936]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet'] [0.82131785]
# ---------------------------------------------------
#
#
# Candidates: [['kaf'], ['kaf', 'mem'], ['dalet']]
# Combinations: [('kaf', 'kaf', 'dalet'), ('kaf', 'mem', 'dalet')]
# Combi: ('kaf', 'kaf', 'dalet') Probability: 9.976112779542132e-07
# Combi: ('kaf', 'mem', 'dalet') Probability: 0.0
# Best word: kaf_kaf_dalet
# Recognizing the following word:
# 5
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['resh', 'he'] [0.80178601, 0.17808607]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['resh', 'he'] [0.80178601, 0.17808607]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 27 recognition: ['ayin'] [0.99736291]
#
# Character found at position 26 :
# Recognizing the following character:
# Recognition result: ['ayin'] [0.99984002]
# ---------------------------------------------------
#
#
# Candidates: [['ayin'], ['resh', 'he']]
# Combinations: [('ayin', 'resh'), ('ayin', 'he')]
# Combi: ('ayin', 'resh') Probability: 0.0008693442248234733
# Combi: ('ayin', 'he') Probability: 0.004082053102029611
# Best word: ayin_he
# test7
# Recognizing the following word:
# 24
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['taw', 'dalet'] [0.48994181, 0.47892517]
# ---------------------------------------------------
#
#
# Candidates: [['taw', 'dalet']]
# Combinations: [('taw',), ('dalet',)]
# Combi: ('taw',) Probability: 0.033003300330033
# Combi: ('dalet',) Probability: 0.01353135313531353
# Best word: taw
# Recognizing the following word:
# 5
# 8
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'waw'] [0.8719821, 0.10672601]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tsadi-final', 'bet', 'qof'] [0.75979847, 0.1170978, 0.082790993]
# ---------------------------------------------------
#
#
# Candidates: [['ayin', 'waw'], ['tsadi-final', 'bet', 'qof']]
# Combinations: [('ayin', 'tsadi-final'), ('ayin', 'bet'), ('ayin', 'qof'), ('waw', 'tsadi-final'), ('waw', 'bet'), ('waw', 'qof')]
# Combi: ('ayin', 'tsadi-final') Probability: 0.0
# Combi: ('ayin', 'bet') Probability: 0.0038064825619865367
# Combi: ('ayin', 'qof') Probability: 8.684419474754468e-05
# Combi: ('waw', 'tsadi-final') Probability: 0.0
# Combi: ('waw', 'bet') Probability: 0.006090971018922641
# Combi: ('waw', 'qof') Probability: 0.00020052869263325273
# Best word: waw_bet
# Recognizing the following word:
# Candidates: []
# Combinations: [()]
# Combi: () Probability: 0
# Best word:
# Recognizing the following word:
# 5
# 39
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het'] [0.99663061]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet', 'ayin', 'samekh'] [0.51804346, 0.17437501, 0.17425366]
# ---------------------------------------------------
#
#
# Candidates: [['het'], ['tet', 'ayin', 'samekh']]
# Combinations: [('het', 'tet'), ('het', 'ayin'), ('het', 'samekh')]
# Combi: ('het', 'tet') Probability: 8.019045365951035e-05
# Combi: ('het', 'ayin') Probability: 0.0
# Combi: ('het', 'samekh') Probability: 0.00015761020725902435
# Best word: het_samekh
# Recognizing the following word:
# 5
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['nun-medial', 'tsadi-final', 'lamed'] [0.56983972, 0.19390576, 0.16619633]
# Recognizing the following character:
# Window position 1 recognition: ['lamed', 'tsadi-final'] [0.85061216, 0.14590794]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['bet'] [0.77829272]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 27 recognition: ['kaf', 'bet'] [0.75195003, 0.24797721]
#
# Character found at position 26 :
# Recognizing the following character:
# Recognition result: ['bet'] [0.93143219]
# ---------------------------------------------------
#
#
# Candidates: [['bet'], ['bet']]
# Combinations: [('bet', 'bet')]
# Combi: ('bet', 'bet') Probability: 0.003217194170084134
# Best word: bet_bet
# Recognizing the following word:
# 5
# 19
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet', 'pe'] [0.59516466, 0.14790426]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet', 'gimel'] [0.6196034, 0.17330611]
# ---------------------------------------------------
#
#
# Candidates: [['bet', 'pe'], ['bet', 'gimel']]
# Combinations: [('bet', 'bet'), ('bet', 'gimel'), ('pe', 'bet'), ('pe', 'gimel')]
# Combi: ('bet', 'bet') Probability: 0.003217194170084134
# Combi: ('bet', 'gimel') Probability: 9.965388557376807e-05
# Combi: ('pe', 'bet') Probability: 0.0
# Combi: ('pe', 'gimel') Probability: 1.8522260389304357e-05
# Best word: bet_bet
# Recognizing the following word:
# 5
# 18
# 50
# 95
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.8871116]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet'] [0.97582799]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-medial', 'bet'] [0.79019302, 0.15629394]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet', 'tet'] [0.54689223, 0.44844174]
# ---------------------------------------------------
#
#
# Candidates: [['resh'], ['bet'], ['nun-medial', 'bet'], ['bet', 'tet']]
# Combinations: [('resh', 'bet', 'nun-medial', 'bet'), ('resh', 'bet', 'nun-medial', 'tet'), ('resh', 'bet', 'bet', 'bet'), ('resh', 'bet', 'bet', 'tet')]
# Combi: ('resh', 'bet', 'nun-medial', 'bet') Probability: 5.504674990296995e-06
# Combi: ('resh', 'bet', 'nun-medial', 'tet') Probability: 2.4291709965061595e-08
# Combi: ('resh', 'bet', 'bet', 'bet') Probability: 8.050417615152296e-06
# Combi: ('resh', 'bet', 'bet', 'tet') Probability: 1.338322181993087e-07
# Best word: resh_bet_bet_bet
# test7
# Recognizing the following word:
# 5
# 30
# 92
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final'] [0.99887055]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet', 'bet'] [0.91010088, 0.086501516]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['pe', 'mem', 'resh', 'dalet'] [0.41522118, 0.20878454, 0.20840776, 0.09954451]
# ---------------------------------------------------
#
#
# Candidates: [['nun-final'], ['tet', 'bet'], ['pe', 'mem', 'resh', 'dalet']]
# Combinations: [('nun-final', 'tet', 'pe'), ('nun-final', 'tet', 'mem'), ('nun-final', 'tet', 'resh'), ('nun-final', 'tet', 'dalet'), ('nun-final', 'bet', 'pe'), ('nun-final', 'bet', 'mem'), ('nun-final', 'bet', 'resh'), ('nun-final', 'bet', 'dalet')]
# Combi: ('nun-final', 'tet', 'pe') Probability: 0.0
# Combi: ('nun-final', 'tet', 'mem') Probability: 0.0
# Combi: ('nun-final', 'tet', 'resh') Probability: 0.0
# Combi: ('nun-final', 'tet', 'dalet') Probability: 0.0
# Combi: ('nun-final', 'bet', 'pe') Probability: 0.0
# Combi: ('nun-final', 'bet', 'mem') Probability: 0.0
# Combi: ('nun-final', 'bet', 'resh') Probability: 0.0
# Combi: ('nun-final', 'bet', 'dalet') Probability: 0.0
# Best word: nun-final_tet_pe
# Recognizing the following word:
# 5
# 67
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem', 'bet', 'kaf', 'taw'] [0.36991119, 0.26855952, 0.16225082, 0.099902935]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed'] [0.99969888]
# ---------------------------------------------------
#
#
# Candidates: [['mem', 'bet', 'kaf', 'taw'], ['lamed']]
# Combinations: [('mem', 'lamed'), ('bet', 'lamed'), ('kaf', 'lamed'), ('taw', 'lamed')]
# Combi: ('mem', 'lamed') Probability: 0.0
# Combi: ('bet', 'lamed') Probability: 0.004176476516574812
# Combi: ('kaf', 'lamed') Probability: 0.011058717450242462
# Combi: ('taw', 'lamed') Probability: 0.0014285583683022645
# Best word: kaf_lamed
# Best is in names!
# כל
# Recognizing the following word:
# 5
# 42
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final'] [0.91023904]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.91675991]
# ---------------------------------------------------
#
#
# Candidates: [['nun-final'], ['resh']]
# Combinations: [('nun-final', 'resh')]
# Combi: ('nun-final', 'resh') Probability: 0
# Best word: nun-final_resh
# Recognizing the following word:
# 15
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['yod'] [0.95419514]
# ---------------------------------------------------
#
#
# Candidates: [['yod']]
# Combinations: [('yod',)]
# Combi: ('yod',) Probability: 0.06683168316831684
# Best word: yod
# Recognizing the following word:
# 5
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he', 'bet'] [0.68474025, 0.28569928]
# ---------------------------------------------------
#
#
# Candidates: [['he', 'bet']]
# Combinations: [('he',), ('bet',)]
# Combi: ('he',) Probability: 0.10066006600660066
# Combi: ('bet',) Probability: 0.11138613861386139
# Best word: bet
# Recognizing the following word:
# 5
# 50
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['waw', 'nun-final', 'nun-medial'] [0.55726427, 0.29482862, 0.13240516]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet', 'dalet', 'samekh', 'tet'] [0.55962509, 0.11330636, 0.10666152, 0.089197434]
# ---------------------------------------------------
#
#
# Candidates: [['waw', 'nun-final', 'nun-medial'], ['bet', 'dalet', 'samekh', 'tet']]
# Combinations: [('waw', 'bet'), ('waw', 'dalet'), ('waw', 'samekh'), ('waw', 'tet'), ('nun-final', 'bet'), ('nun-final', 'dalet'), ('nun-final', 'samekh'), ('nun-final', 'tet'), ('nun-medial', 'bet'), ('nun-medial', 'dalet'), ('nun-medial', 'samekh'), ('nun-medial', 'tet')]
# Combi: ('waw', 'bet') Probability: 0.006090971018922641
# Combi: ('waw', 'dalet') Probability: 0.0006928919633086564
# Combi: ('waw', 'samekh') Probability: 2.8079406823835196e-05
# Combi: ('waw', 'tet') Probability: 2.2515685347904998e-05
# Combi: ('nun-final', 'bet') Probability: 0
# Combi: ('nun-final', 'dalet') Probability: 0
# Combi: ('nun-final', 'samekh') Probability: 0
# Combi: ('nun-final', 'tet') Probability: 0
# Combi: ('nun-medial', 'bet') Probability: 0.0011690818478900472
# Combi: ('nun-medial', 'dalet') Probability: 0.00024476096560080993
# Combi: ('nun-medial', 'samekh') Probability: 4.761083522376489e-05
# Combi: ('nun-medial', 'tet') Probability: 5.159068832296503e-06
# Best word: waw_bet
# test7
