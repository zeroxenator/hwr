# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *

# %%
path = 'image-data/test16.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image)
# Out:
# Average word height and width: 52.5933333333 50.2933333333
# [141.20702631768236, 6]
# [238.94771341958139, 8]
# [346.01822500501106, 29]
# [433.14594048108592, 12]
# [518.6012820619876, 24]
# [613.19549413925847, 23]
# [736.65563569781068, 18]
# [863.01983485835467, 21]
# [955.11285775024487, 11]
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet'] [0.92367792]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['yod'] [0.99688965]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['yod'] [0.99688965]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 22 recognition: ['het', 'mem', 'gimel'] [0.38165593, 0.2611616, 0.23654519]
#
# Character found at position 21 :
# Recognizing the following character:
# Recognition result: ['het'] [0.97013378]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['gimel', 'nun medial'] [0.753847, 0.22916083]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het'] [0.99707615]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet'] [0.69731611]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tsadi final', 'ayin'] [0.73141932, 0.20573299]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['gimel'] [0.97548342]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem', 'nun medial', 'bet', 'kaf'] [0.29661155, 0.2414569, 0.20490929, 0.19833557]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['nun medial'] [0.92278016]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['nun medial'] [0.92278016]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 23 recognition: ['samekh', 'bet', 'tet'] [0.46649861, 0.33623841, 0.17225145]
#
# Character found at position 22 :
# Recognizing the following character:
# Recognition result: ['tet'] [0.89502937]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['shin'] [0.99994767]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.96258414]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['dalet'] [0.91968495]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['dalet'] [0.91968495]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 26 recognition: ['nun medial', 'kaf', 'bet', 'tet'] [0.53958273, 0.18944812, 0.095874645, 0.08145836]
#
# Character found at position 25 :
# Recognizing the following character:
# Recognition result: ['kaf', 'tet', 'samekh'] [0.45348662, 0.24662979, 0.1606195]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'nun medial', 'kaf'] [0.38474852, 0.32166848, 0.20577946]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'zayin'] [0.5486716, 0.41605055]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed', 'gimel'] [0.81536174, 0.10887291]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef', 'gimel'] [0.54560459, 0.44381118]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet', 'bet'] [0.59951645, 0.24703583]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet'] [0.99809545]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final', 'dalet', 'resh'] [0.60343683, 0.23432142, 0.14073993]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['yod', 'alef', 'resh'] [0.48930863, 0.28823078, 0.13774417]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-0405febc17d1> in <module>()
# ----> 1 recognize_handwriting(image)
#
# ~\Desktop\AI\BlockD\handwritingRecognition\hwr\Preprocessing\recognize_handwriting.py in recognize_handwriting(image)
#     489             # extract the characters in the word
#     490             #characters = extract_characters(cv2.morphologyEx(word, cv2.MORPH_CLOSE, kernel), avg_width)
# --> 491             recognize_word(cv2.morphologyEx(word, cv2.MORPH_CLOSE, kernel), avg_width)
#     492             # recognize the characters in the word
#     493             #for character in characters:
#
# ~\Desktop\AI\BlockD\handwritingRecognition\hwr\Preprocessing\recognize_word_window.py in recognize_word(word, avg_width)
#      82
#      83                     # try to recognize characters within the component
# ---> 84                     top_chars, top_scores = recognize_character(window)
#      85                     N_candidates = len(top_chars)
#      86                     print("Window position", int(window_x / stride) ,"recognition:", top_chars, top_scores)
#
# ~\Desktop\AI\BlockD\handwritingRecognition\hwr\Preprocessing\recognize_character_cnn.py in recognize_character(char)
#      12     user_defined_threshold = 0.08
#      13
# ---> 14     top_chars, top_scores = recognition_char(char, user_defined_threshold)
#      15
#      16     return top_chars, top_scores
#
# ~\Desktop\AI\BlockD\handwritingRecognition\hwr\Preprocessing\CNN_test\classify.py in recognition_char(image, user_defined_threshold)
#      55
#      56         # predictions = sess.run(softmax_tensor, {'DecodeJpeg/contents:0': image})  # this reads tensor image from disk
# ---> 57         predictions = sess.run(softmax_tensor, {'DecodeJpeg:0': image})  # this reads tensor image from np array
#      58
#      59         # Sort to show labels of first prediction in order of confidence
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
