# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *
# Out:
# Using TensorFlow backend.

# %%
path = 'image-data/test7.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image, path, plot = True)
# Out:
# Average word height and width: 46.75609756097561 48.853658536585364
# [302.6832826893371, 5]
# [396.318250756607, 8]
# [493.17810320260526, 10]
# [592.8281150630826, 8]
# [692.9997894172499, 7]
# [793.5702176033146, 7]
# [889.809769137882, 5]
# [982.0532900447353, 2]
# [-100, 1]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 300)               399600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 27)                8127
# =================================================================
# Total params: 407,727
# Trainable params: 407,727
# Non-trainable params: 0
# _________________________________________________________________
# LSTM model: None
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.99994755
# Best character: kaf
# Component:
# Recognizing the following character:
# Best score: 0.9974375
# Best character: waw
# Predicted sequence: ['kaf', 'waw'] [0.99994755, 0.9974375]
# -----LSTM:-------
# N chars: 2
# orig shape: (50, 62)
# Idx: [14 24]
# Idx: [7]
# Idx: [24]
# Word preds: ['pe', 'waw']
# Word probs: [0.369907945394516, 0.8997498154640198]
# ch preds: ['kaf', 'waw']
# ch probs: [0.9912940859794617, 0.9998821020126343]
# Final output: ['kaf', 'waw']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9999409
# Best character: yod
# Component:
# Recognizing the following character:
# Best score: 0.9000033
# Best character: he
# Component:
# Recognizing the following character:
# Best score: 0.9997178
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.88801163
# Best character: he
# Predicted sequence: ['yod', 'he', 'nun-final', 'he'] [0.9999409, 0.9000033, 0.9997178, 0.88801163]
# -----LSTM:-------
# N chars: 4
# orig shape: (58, 133)
# Idx: [ 3  5  6 17]
# Idx: [25]
# Idx: [5]
# Idx: [24]
# Idx: [5]
# Word preds: ['dalet', 'he', 'het', 'resh']
# Word probs: [0.04469966143369675, 0.3518923819065094, 0.9985376596450806, 0.9990718364715576]
# ch preds: ['yod', 'he', 'waw', 'he']
# ch probs: [0.6702904105186462, 0.9970389604568481, 0.9919667840003967, 0.9994202852249146]
# Empty position: 0
# LSTM:  yod 0.6702904105186462
# CNN:  yod 0.9999409
# Empty position: 2
# LSTM:  waw 0.9919667840003967
# CNN:  nun-final 0
# Final output: ['yod', 'he', 'waw', 'he']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.7724192
# Best character: het
# Predicted sequence: ['het'] [0.7724192]
# -----LSTM:-------
# N chars: 1
# orig shape: (52, 76)
# Idx: [19]
# Idx: [6]
# Word preds: ['shin']
# Word probs: [0.6965409517288208]
# ch preds: ['het']
# ch probs: [0.24634137749671936]
# Empty position: 0
# LSTM:  het 0.24634137749671936
# CNN:  het 0.7724192
# Final output: ['het']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.99092567
# Best character: nun-final
# Predicted sequence: ['nun-final'] [0.99092567]
# -----LSTM:-------
# N chars: 1
# orig shape: (47, 43)
# Idx: [14]
# Idx: [1]
# Word preds: ['pe']
# Word probs: [0.7600572109222412]
# ch preds: ['ayin']
# ch probs: [0.704636812210083]
# Empty position: 0
# LSTM:  ayin 0.704636812210083
# CNN:  nun-final 0.99092567
# Final output: ['nun-final']
# test7
# ch: kaf
# code: 1499
# chr: כ
# ch: waw
# code: 1493
# chr: ו
# ch: yod
# code: 1497
# chr: י
# ch: he
# code: 1492
# chr: ה
# ch: waw
# code: 1493
# chr: ו
# ch: he
# code: 1492
# chr: ה
# ch: het
# code: 1495
# chr: ח
# ch: nun-final
# code: 1503
# chr: ן
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9999548
# Best character: nun-medial
# Component:
# Recognizing the following character:
# Best score: 0.52855283
# Best character: waw
# Component:
# Recognizing the following character:
# Best score: 0.99910957
# Best character: resh
# Predicted sequence: ['nun-medial', 'waw', 'resh'] [0.9999548, 0.52855283, 0.99910957]
# -----LSTM:-------
# N chars: 3
# orig shape: (54, 111)
# Idx: [ 2  4 17]
# Idx: [13]
# Idx: [24]
# Idx: [17]
# Word preds: ['bet', 'gimel', 'resh']
# Word probs: [0.2619055211544037, 0.3718535602092743, 0.9407562613487244]
# ch preds: ['nun-medial', 'waw', 'resh']
# ch probs: [0, 0.9059115052223206, 0.6359928250312805]
# Empty position: 0
# LSTM:  nun-medial 0
# CNN:  nun-medial 0
# Empty position: 1
# LSTM:  waw 0.9059115052223206
# CNN:  waw 0.52855283
# Final output: ['gimel', 'waw', 'resh']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.83313584
# Best character: waw
# Component:
# Recognizing the following character:
# Best score: 0.9748687
# Best character: nun-medial
# Component:
# Recognizing the following character:
# Best score: 0.7583254
# Best character: kaf
# Component:
# Recognizing the following character:
# Best score: 0.99966085
# Best character: dalet
# Component:
# Recognizing the following character:
# Best score: 0.56779397
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.9992204
# Best character: nun-final
# Predicted sequence: ['waw', 'nun-medial', 'kaf', 'dalet', 'nun-final', 'nun-final'] [0.83313584, 0.9748687, 0.7583254, 0.99966085, 0.56779397, 0.9992204]
# -----LSTM:-------
# N chars: 6
# orig shape: (69, 158)
# Idx: [ 1  2  5  6  9 21]
# Idx: [17]
# Idx: [2]
# Idx: [14]
# Idx: [17]
# Idx: [2]
# Idx: [2]
# Word preds: ['ayin', 'bet', 'he', 'het', 'lamed', 'tet']
# Word probs: [0.0008825730765238404, 0.002445212099701166, 0.006077997386455536, 0.951296865940094, 0.9911053776741028, 0.9994115829467773]
# ch preds: ['resh', 'bet', 'pe', 'resh', 'bet', 'bet']
# ch probs: [0.5088946223258972, 0.9901753067970276, 0.7491072416305542, 0.3463899493217468, 0.9936218857765198, 0.26792189478874207]
# Empty position: 0
# LSTM:  resh 0.5088946223258972
# CNN:  waw 0.83313584
# Empty position: 3
# LSTM:  resh 0.3463899493217468
# CNN:  dalet 0.99966085
# Empty position: 5
# LSTM:  bet 0.26792189478874207
# CNN:  nun-final 0.9992204
# Final output: ['waw', 'bet', 'kaf', 'dalet', 'bet', 'nun-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9792985
# Best character: alef
# Component:
# Recognizing the following character:
# Best score: 0.99582964
# Best character: tet
# Component:
# Recognizing the following character:
# Best score: 0.9992514
# Best character: dalet
# Predicted sequence: ['alef', 'tet', 'dalet'] [0.9792985, 0.99582964, 0.9992514]
# -----LSTM:-------
# N chars: 3
# orig shape: (56, 135)
# Idx: [ 0 19 25]
# Idx: [0]
# Idx: [19]
# Idx: [3]
# Word preds: ['alef', 'shin', 'yod']
# Word probs: [0.15112470090389252, 0.17750152945518494, 0.9618443250656128]
# ch preds: ['alef', 'shin', 'dalet']
# ch probs: [0.9986442923545837, 0.9998407363891602, 0.9185105562210083]
# Empty position: 2
# LSTM:  dalet 0.9185105562210083
# CNN:  dalet 0.9992514
# Final output: ['alef', 'shin', 'dalet']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9573966
# Best character: dalet
# Component:
# CLASSIFIYING!@#!@#!@#!@#@!:
# (48, 35)
# Recognizing the following character:
# Best score: 0.665102
# Best character: dalet
# CLASSIFIYING!@#!@#!@#!@#@!:
# (48, 37)
# Recognizing the following character:
# Best score: 0.9772372
# Best character: bet
# Predicted sequence: ['dalet', 'bet', 'dalet'] [0.9573966, 0.9772372, 0.665102]
# -----LSTM:-------
# N chars: 3
# orig shape: (53, 114)
# Idx: [ 2  3 17]
# Idx: [17]
# Idx: [2]
# Idx: [17]
# Word preds: ['bet', 'dalet', 'resh']
# Word probs: [0.9923243522644043, 0.9991745352745056, 0.9998815059661865]
# ch preds: ['resh', 'bet', 'resh']
# ch probs: [0.426653116941452, 0.9981157779693604, 0.7537665963172913]
# Final output: ['dalet', 'bet', 'resh']
# test7
# ch: gimel
# code: 1490
# chr: ג
# ch: waw
# code: 1493
# chr: ו
# ch: resh
# code: 1512
# chr: ר
# ch: waw
# code: 1493
# chr: ו
# ch: bet
# code: 1489
# chr: ב
# ch: kaf
# code: 1499
# chr: כ
# ch: dalet
# code: 1491
# chr: ד
# ch: bet
# code: 1489
# chr: ב
# ch: nun-final
# code: 1503
# chr: ן
# ch: alef
# code: 1488
# chr: א
# ch: shin
# code: 1513
# chr: ש
# ch: dalet
# code: 1491
# chr: ד
# ch: dalet
# code: 1491
# chr: ד
# ch: bet
# code: 1489
# chr: ב
# ch: resh
# code: 1512
# chr: ר
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.97278374
# Best character: nun-medial
# Component:
# CLASSIFIYING!@#!@#!@#!@#@!:
# (49, 43)
# Recognizing the following character:
# Best score: 0.9440844
# Best character: het
# CLASSIFIYING!@#!@#!@#!@#@!:
# (49, 38)
# Recognizing the following character:
# Best score: 0.9900705
# Best character: taw
# Predicted sequence: ['nun-medial', 'taw', 'het'] [0.97278374, 0.9900705, 0.9440844]
# -----LSTM:-------
# N chars: 3
# orig shape: (104, 111)
# Idx: [ 2 19 20]
# Idx: [1]
# Idx: [6]
# Idx: [6]
# Word preds: ['bet', 'shin', 'taw']
# Word probs: [0.12873676419258118, 0.14254574477672577, 0.7287306785583496]
# ch preds: ['ayin', 'het', 'het']
# ch probs: [0.497568815946579, 0.8383183479309082, 0.8641951084136963]
# Empty position: 0
# LSTM:  ayin 0.497568815946579
# CNN:  nun-medial 0
# Final output: ['ayin', 'taw', 'het']
# test7
# ch: ayin
# code: 1506
# chr: ע
# ch: taw
# code: 1514
# chr: ת
# ch: het
# code: 1495
# chr: ח
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.99999595
# Best character: nun-medial
# Component:
# Recognizing the following character:
# Best score: 0.9994413
# Best character: lamed
# Component:
# Recognizing the following character:
# Best score: 0.99895644
# Best character: nun-final
# Predicted sequence: ['nun-medial', 'lamed', 'nun-final'] [0.99999595, 0.9994413, 0.99895644]
# -----LSTM:-------
# N chars: 3
# orig shape: (94, 124)
# Idx: [ 6  9 13]
# Idx: [2]
# Idx: [13]
# Idx: [24]
# Word preds: ['het', 'lamed', 'nun-medial']
# Word probs: [0.7428971529006958, 0.9689441919326782, 0.9925501346588135]
# ch preds: ['bet', 'nun-medial', 'waw']
# ch probs: [0.9661797285079956, 0.2634434103965759, 0.9841469526290894]
# Empty position: 0
# LSTM:  bet 0.9661797285079956
# CNN:  nun-medial 0
# Empty position: 1
# LSTM:  nun-medial 0.2634434103965759
# CNN:  lamed 0.9994413
# Empty position: 2
# LSTM:  waw 0.9841469526290894
# CNN:  nun-final 0.99895644
# Final output: ['bet', 'lamed', 'nun-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9999732
# Best character: tet
# Component:
# Recognizing the following character:
# Best score: 0.94737
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.5417669
# Best character: kaf
# Component:
# Recognizing the following character:
# Best score: 0.47433147
# Best character: mem
# Predicted sequence: ['tet', 'nun-final', 'kaf', 'mem'] [0.9999732, 0.94737, 0.5417669, 0.47433147]
# -----LSTM:-------
# N chars: 4
# orig shape: (78, 164)
# Idx: [ 2  5 19 20]
# Idx: [19]
# Idx: [24]
# Idx: [2]
# Idx: [5]
# Word preds: ['bet', 'he', 'shin', 'taw']
# Word probs: [0.10912059247493744, 0.17336295545101166, 0.26039600372314453, 0.946366548538208]
# ch preds: ['shin', 'waw', 'bet', 'he']
# ch probs: [0.9736472964286804, 0.9996821880340576, 0.4590948224067688, 0.6693916320800781]
# Empty position: 1
# LSTM:  waw 0.9996821880340576
# CNN:  nun-final 0
# Empty position: 2
# LSTM:  bet 0.4590948224067688
# CNN:  kaf 0.5417669
# Final output: ['shin', 'waw', 'kaf', 'he']
# Recognizing the following word:
# -----CNN:-------
# Component:
# CLASSIFIYING!@#!@#!@#!@#@!:
# (73, 29)
# Recognizing the following character:
# Best score: 0.5742447
# Best character: resh
# CLASSIFIYING!@#!@#!@#!@#@!:
# (73, 40)
# Recognizing the following character:
# Best score: 0.9999957
# Best character: tsadi-medial
# Component:
# Recognizing the following character:
# Best score: 0.5376762
# Best character: nun-final
# Predicted sequence: ['tsadi-medial', 'resh', 'nun-final'] [0.9999957, 0.5742447, 0.5376762]
# -----LSTM:-------
# N chars: 3
# orig shape: (77, 117)
# Idx: [ 0 17 23]
# Idx: [0]
# Idx: [17]
# Idx: [22]
# Word preds: ['alef', 'resh', 'tsadi-medial']
# Word probs: [0.876700758934021, 0.9530765414237976, 0.99906986951828]
# ch preds: ['alef', 'resh', 'tsadi-final']
# ch probs: [0.96528559923172, 0.6443641185760498, 0.9932771325111389]
# Empty position: 2
# LSTM:  tsadi-final 0.9932771325111389
# CNN:  nun-final 0.5376762
# Final output: ['alef', 'resh', 'tsadi-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.99999964
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.99937004
# Best character: resh
# Component:
# Recognizing the following character:
# Best score: 0.9155831
# Best character: het
# Component:
# Recognizing the following character:
# Best score: 0.9999927
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.99770504
# Best character: kaf
# Component:
# Recognizing the following character:
# Best score: 0.37785724
# Best character: samekh
# Predicted sequence: ['nun-final', 'resh', 'het', 'nun-final', 'kaf', 'samekh'] [0.99999964, 0.99937004, 0.9155831, 0.9999927, 0.99770504, 0.37785724]
# -----LSTM:-------
# N chars: 6
# orig shape: (67, 168)
# Idx: [ 2  5  7 10 18 21]
# Idx: [10]
# Idx: [17]
# Idx: [2]
# Idx: [0]
# Idx: [2]
# Idx: [2]
# Word preds: ['bet', 'he', 'kaf', 'mem', 'samekh', 'tet']
# Word probs: [0.011454198509454727, 0.021172890439629555, 0.04759873449802399, 0.11021861433982849, 0.8154621124267578, 0.9949885010719299]
# ch preds: ['mem', 'resh', 'bet', 'alef', 'bet', 'bet']
# ch probs: [0.15516512095928192, 0.8168843388557434, 0.6994969248771667, 0.8986288905143738, 0.44295933842658997, 0.8833869695663452]
# Empty position: 0
# LSTM:  mem 0.15516512095928192
# CNN:  nun-final 0
# Empty position: 1
# LSTM:  resh 0.8168843388557434
# CNN:  resh 0.99937004
# Empty position: 3
# LSTM:  alef 0.8986288905143738
# CNN:  nun-final 0
# Final output: ['mem', 'resh', 'bet', 'alef', 'kaf', 'bet']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9877422
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.65370965
# Best character: tsadi-medial
# Component:
# Recognizing the following character:
# Best score: 0.69921684
# Best character: bet
# Predicted sequence: ['nun-final', 'tsadi-medial', 'bet'] [0.9877422, 0.65370965, 0.69921684]
# -----LSTM:-------
# N chars: 3
# orig shape: (54, 102)
# Idx: [ 2 10 11]
# Idx: [2]
# Idx: [21]
# Idx: [18]
# Word preds: ['bet', 'mem', 'mem-medial']
# Word probs: [0.11108233034610748, 0.12875840067863464, 0.6433077454566956]
# ch preds: ['bet', 'tet', 'samekh']
# ch probs: [0.9966596364974976, 0.08220960944890976, 0.10931621491909027]
# Empty position: 1
# LSTM:  tet 0.08220960944890976
# CNN:  tsadi-medial 0.65370965
# Empty position: 2
# LSTM:  samekh 0.10931621491909027
# CNN:  bet 0.69921684
# Final output: ['bet', 'tsadi-medial', 'bet']
# test7
# ch: bet
# code: 1489
# chr: ב
# ch: lamed
# code: 1500
# chr: ל
# ch: nun-final
# code: 1503
# chr: ן
# ch: shin
# code: 1513
# chr: ש
# ch: waw
# code: 1493
# chr: ו
# ch: kaf
# code: 1499
# chr: כ
# ch: he
# code: 1492
# chr: ה
# ch: alef
# code: 1488
# chr: א
# ch: resh
# code: 1512
# chr: ר
# ch: tsadi-final
# code: 1509
# chr: ץ
# ch: mem
# code: 1501
# chr: ם
# ch: resh
# code: 1512
# chr: ר
# ch: bet
# code: 1489
# chr: ב
# ch: alef
# code: 1488
# chr: א
# ch: kaf
# code: 1499
# chr: כ
# ch: bet
# code: 1489
# chr: ב
# ch: bet
# code: 1489
# chr: ב
# ch: tsadi-medial
# code: 1510
# chr: צ
# ch: bet
# code: 1489
# chr: ב
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.6233517
# Best character: mem
# Component:
# Recognizing the following character:
# Best score: 1.0
# Best character: tet
# Component:
# Recognizing the following character:
# Best score: 0.8839164
# Best character: he
# Predicted sequence: ['mem', 'tet', 'he'] [0.6233517, 1.0, 0.8839164]
# -----LSTM:-------
# N chars: 3
# orig shape: (55, 136)
# Idx: [ 5  6 21]
# Idx: [6]
# Idx: [21]
# Idx: [5]
# Word preds: ['he', 'het', 'tet']
# Word probs: [0.8557302355766296, 0.8966832160949707, 0.9968798160552979]
# ch preds: ['het', 'tet', 'he']
# ch probs: [0.920758068561554, 0.9179031848907471, 0.9992539286613464]
# Final output: ['het', 'tet', 'he']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.83990127
# Best character: nun-final
# Component:
# CLASSIFIYING!@#!@#!@#!@#@!:
# (48, 43)
# Recognizing the following character:
# Best score: 0.53952456
# Best character: taw
# CLASSIFIYING!@#!@#!@#!@#@!:
# (48, 35)
# Recognizing the following character:
# Best score: 0.97850615
# Best character: pe
# Component:
# Recognizing the following character:
# Best score: 0.99860793
# Best character: yod
# Predicted sequence: ['nun-final', 'pe', 'taw', 'yod'] [0.83990127, 0.97850615, 0.53952456, 0.99860793]
# -----LSTM:-------
# N chars: 4
# orig shape: (52, 138)
# Idx: [ 0 13 17 20]
# Idx: [24]
# Idx: [2]
# Idx: [5]
# Idx: [17]
# Word preds: ['alef', 'nun-medial', 'resh', 'taw']
# Word probs: [0.3114435374736786, 0.3744962513446808, 0.4736851155757904, 0.49648919701576233]
# ch preds: ['waw', 'bet', 'he', 'resh']
# ch probs: [0.13865084946155548, 0.6218120455741882, 0.5728144645690918, 0.41576847434043884]
# Empty position: 0
# LSTM:  waw 0.13865084946155548
# CNN:  nun-final 0
# Empty position: 1
# LSTM:  bet 0.6218120455741882
# CNN:  pe 0.97850615
# Empty position: 3
# LSTM:  resh 0.41576847434043884
# CNN:  yod 0.99860793
# Final output: ['waw', 'pe', 'he', 'yod']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 1.0
# Best character: nun-final
# Component:
# CLASSIFIYING!@#!@#!@#!@#@!:
# (52, 38)
# Recognizing the following character:
# Best score: 0.99270296
# Best character: he
# CLASSIFIYING!@#!@#!@#!@#@!:
# (52, 43)
# Recognizing the following character:
# Best score: 0.996487
# Best character: ayin
# Predicted sequence: ['nun-final', 'ayin', 'he'] [1.0, 0.996487, 0.99270296]
# -----LSTM:-------
# N chars: 3
# orig shape: (56, 111)
# Idx: [ 1  5 17]
# Idx: [12]
# Idx: [1]
# Idx: [5]
# Word preds: ['ayin', 'he', 'resh']
# Word probs: [0.4857975244522095, 0.9907209873199463, 0.9945963025093079]
# ch preds: ['nun-final', 'ayin', 'he']
# ch probs: [0, 0.9947708249092102, 0.6364436745643616]
# Final output: ['resh', 'ayin', 'he']
# Recognizing the following word:
# -----CNN:-------
# Component:
# CLASSIFIYING!@#!@#!@#!@#@!:
# (42, 29)
# Recognizing the following character:
# Best score: 0.90633047
# Best character: dalet
# CLASSIFIYING!@#!@#!@#!@#@!:
# (42, 43)
# Recognizing the following character:
# Best score: 0.9999573
# Best character: alef
# Component:
# Recognizing the following character:
# Best score: 0.4967012
# Best character: tsadi-medial
# Predicted sequence: ['alef', 'dalet', 'tsadi-medial'] [0.9999573, 0.90633047, 0.4967012]
# -----LSTM:-------
# N chars: 3
# orig shape: (47, 119)
# Idx: [ 0 17 19]
# Idx: [0]
# Idx: [17]
# Idx: [1]
# Word preds: ['alef', 'resh', 'shin']
# Word probs: [0.27567851543426514, 0.6275644898414612, 0.8288236856460571]
# ch preds: ['alef', 'resh', 'ayin']
# ch probs: [0.9988368153572083, 0.7052993774414062, 0.4882137179374695]
# Final output: ['alef', 'resh', 'ayin']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9999944
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.9999466
# Best character: shin
# Component:
# Recognizing the following character:
# Best score: 0.86523765
# Best character: nun-final
# Predicted sequence: ['nun-final', 'shin', 'nun-final'] [0.9999944, 0.9999466, 0.86523765]
# -----LSTM:-------
# N chars: 3
# orig shape: (47, 133)
# Idx: [ 1 17 19]
# Idx: [24]
# Idx: [19]
# Idx: [1]
# Word preds: ['ayin', 'resh', 'shin']
# Word probs: [0.9826280474662781, 0.991675853729248, 0.9998639822006226]
# ch preds: ['waw', 'shin', 'ayin']
# ch probs: [0.699467658996582, 0.9998706579208374, 0.6812031269073486]
# Empty position: 0
# LSTM:  waw 0.699467658996582
# CNN:  nun-final 0
# Final output: ['waw', 'shin', 'ayin']
# test7
# ch: het
# code: 1495
# chr: ח
# ch: tet
# code: 1496
# chr: ט
# ch: he
# code: 1492
# chr: ה
# ch: waw
# code: 1493
# chr: ו
# ch: pe
# code: 1508
# chr: פ
# ch: he
# code: 1492
# chr: ה
# ch: yod
# code: 1497
# chr: י
# ch: resh
# code: 1512
# chr: ר
# ch: ayin
# code: 1506
# chr: ע
# ch: he
# code: 1492
# chr: ה
# ch: alef
# code: 1488
# chr: א
# ch: resh
# code: 1512
# chr: ר
# ch: ayin
# code: 1506
# chr: ע
# ch: waw
# code: 1493
# chr: ו
# ch: shin
# code: 1513
# chr: ש
# ch: ayin
# code: 1506
# chr: ע
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9920013
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.7539077
# Best character: yod
# Component:
# Recognizing the following character:
# Best score: 0.98369265
# Best character: bet
# Predicted sequence: ['nun-final', 'yod', 'bet'] [0.9920013, 0.7539077, 0.98369265]
# -----LSTM:-------
# N chars: 3
# orig shape: (92, 49)
# Idx: [ 7 13 14]
# Idx: [2]
# Idx: [25]
# Idx: [7]
# Word preds: ['kaf', 'nun-medial', 'pe']
# Word probs: [0.09288769215345383, 0.10669968277215958, 0.6460956931114197]
# ch preds: ['bet', 'yod', 'kaf']
# ch probs: [0.7530631422996521, 0.2949516773223877, 0.7670143842697144]
# Empty position: 1
# LSTM:  yod 0.2949516773223877
# CNN:  yod 0.7539077
# Final output: ['bet', 'yod', 'kaf']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.70532644
# Best character: nun-final
# Predicted sequence: ['nun-final'] [0.70532644]
# -----LSTM:-------
# N chars: 1
# orig shape: (51, 39)
# Idx: [10]
# Idx: [21]
# Word preds: ['mem']
# Word probs: [0.5656032562255859]
# ch preds: ['tet']
# ch probs: [0.1321655809879303]
# Empty position: 0
# LSTM:  tet 0.1321655809879303
# CNN:  nun-final 0.70532644
# Final output: ['nun-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# CLASSIFIYING!@#!@#!@#!@#@!:
# (68, 29)
# Recognizing the following character:
# Best score: 0.9981818
# Best character: resh
# CLASSIFIYING!@#!@#!@#!@#@!:
# (68, 33)
# Recognizing the following character:
# Best score: 0.5360429
# Best character: alef
# Component:
# Recognizing the following character:
# Best score: 0.8188448
# Best character: tsadi-final
# Predicted sequence: ['alef', 'resh', 'tsadi-final'] [0.5360429, 0.9981818, 0.8188448]
# -----LSTM:-------
# N chars: 3
# orig shape: (72, 110)
# Idx: [ 0 17 22]
# Idx: [4]
# Idx: [17]
# Idx: [22]
# Word preds: ['alef', 'resh', 'tsadi-final']
# Word probs: [0.9987962245941162, 0.9999310970306396, 0.9999932050704956]
# ch preds: ['gimel', 'resh', 'tsadi-final']
# ch probs: [0.1414104700088501, 0.6662999987602234, 0.9990602135658264]
# Empty position: 0
# LSTM:  gimel 0.1414104700088501
# CNN:  alef 0.5360429
# Final output: ['alef', 'resh', 'tsadi-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.93527555
# Best character: resh
# Predicted sequence: ['resh'] [0.93527555]
# -----LSTM:-------
# N chars: 1
# orig shape: (47, 80)
# Idx: [17]
# Idx: [17]
# Word preds: ['resh']
# Word probs: [0.9110082983970642]
# ch preds: ['resh']
# ch probs: [0.6761361360549927]
# Final output: ['resh']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.86227894
# Best character: nun-medial
# Component:
# Recognizing the following character:
# Best score: 0.78738445
# Best character: nun-final
# Predicted sequence: ['nun-medial', 'nun-final'] [0.86227894, 0.78738445]
# -----LSTM:-------
# N chars: 2
# orig shape: (54, 54)
# Idx: [ 2 24]
# Idx: [21]
# Idx: [8]
# Word preds: ['bet', 'waw']
# Word probs: [0.521504819393158, 0.6197296977043152]
# ch preds: ['tet', 'kaf-final']
# ch probs: [0.9961870312690735, 0.9723861217498779]
# Empty position: 0
# LSTM:  tet 0.9961870312690735
# CNN:  nun-medial 0
# Empty position: 1
# LSTM:  kaf-final 0.9723861217498779
# CNN:  nun-final 0.78738445
# Final output: ['tet', 'kaf-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.95497847
# Best character: kaf-final
# Component:
# Recognizing the following character:
# Best score: 0.91789925
# Best character: mem-medial
# Component:
# Recognizing the following character:
# Best score: 0.9581836
# Best character: bet
# Component:
# CLASSIFIYING!@#!@#!@#!@#@!:
# (46, 12)
# Recognizing the following character:
# Best score: 0.994476
# Best character: nun-final
# CLASSIFIYING!@#!@#!@#!@#@!:
# (46, 21)
# Recognizing the following character:
# Best score: 0.71988523
# Best character: bet
# CLASSIFIYING!@#!@#!@#!@#@!:
# (46, 21)
# Recognizing the following character:
# Best score: 0.8197659
# Best character: nun-final
# Predicted sequence: ['kaf-final', 'mem-medial', 'bet', 'nun-final', 'bet', 'nun-final'] [0.95497847, 0.91789925, 0.9581836, 0.8197659, 0.71988523, 0.994476]
# -----LSTM:-------
# N chars: 6
# orig shape: (50, 124)
# Idx: [ 1  2  9 16 19 21]
# Idx: [16]
# Idx: [2]
# Idx: [2]
# Idx: [2]
# Idx: [14]
# Idx: [5]
# Word preds: ['ayin', 'bet', 'lamed', 'qof', 'shin', 'tet']
# Word probs: [4.9758265959098935e-05, 0.00014686267240904272, 0.0010548869613558054, 0.04352704808115959, 0.9822373986244202, 0.9913893342018127]
# ch preds: ['qof', 'bet', 'bet', 'bet', 'pe', 'he']
# ch probs: [0.8887143731117249, 0.9889709949493408, 0.23998333513736725, 0.2843385934829712, 0.15518079698085785, 0.06811847537755966]
# Empty position: 2
# LSTM:  bet 0.23998333513736725
# CNN:  bet 0.9581836
# Empty position: 3
# LSTM:  bet 0.2843385934829712
# CNN:  nun-final 0
# Empty position: 5
# LSTM:  he 0.06811847537755966
# CNN:  nun-final 0.994476
# Final output: ['qof', 'bet', 'bet', 'bet', 'bet', 'nun-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.59750944
# Best character: nun-final
# Component:
# CLASSIFIYING!@#!@#!@#!@#@!:
# (43, 43)
# Recognizing the following character:
# Best score: 0.6638869
# Best character: tsadi-medial
# CLASSIFIYING!@#!@#!@#!@#@!:
# (43, 33)
# Recognizing the following character:
# Best score: 0.99924576
# Best character: bet
# Predicted sequence: ['nun-final', 'bet', 'tsadi-medial'] [0.59750944, 0.99924576, 0.6638869]
# -----LSTM:-------
# N chars: 3
# orig shape: (47, 101)
# Idx: [ 0 20 25]
# Idx: [2]
# Idx: [2]
# Idx: [20]
# Word preds: ['alef', 'taw', 'yod']
# Word probs: [0.002618982456624508, 0.4191051721572876, 0.9997695088386536]
# ch preds: ['bet', 'bet', 'taw']
# ch probs: [0.1998583972454071, 0.7051951885223389, 0.999943733215332]
# Empty position: 0
# LSTM:  bet 0.1998583972454071
# CNN:  nun-final 0
# Empty position: 1
# LSTM:  bet 0.7051951885223389
# CNN:  bet 0.99924576
# Final output: ['bet', 'bet', 'taw']
# test7
# ch: bet
# code: 1489
# chr: ב
# ch: yod
# code: 1497
# chr: י
# ch: kaf
# code: 1499
# chr: כ
# ch: nun-final
# code: 1503
# chr: ן
# ch: alef
# code: 1488
# chr: א
# ch: resh
# code: 1512
# chr: ר
# ch: tsadi-final
# code: 1509
# chr: ץ
# ch: resh
# code: 1512
# chr: ר
# ch: tet
# code: 1496
# chr: ט
# ch: kaf-final
# code: 1498
# chr: ך
# ch: qof
# code: 1511
# chr: ק
# ch: bet
# code: 1489
# chr: ב
# ch: bet
# code: 1489
# chr: ב
# ch: bet
# code: 1489
# chr: ב
# ch: bet
# code: 1489
# chr: ב
# ch: nun-final
# code: 1503
# chr: ן
# ch: bet
# code: 1489
# chr: ב
# ch: bet
# code: 1489
# chr: ב
# ch: taw
# code: 1514
# chr: ת
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9995585
# Best character: nun-final
# Component:
# CLASSIFIYING!@#!@#!@#!@#@!:
# (50, 22)
# Recognizing the following character:
# Best score: 0.29823285
# Best character: pe
# CLASSIFIYING!@#!@#!@#!@#@!:
# (50, 36)
# Recognizing the following character:
# Best score: 0.6933571
# Best character: kaf
# Component:
# Recognizing the following character:
# Best score: 0.85720253
# Best character: pe
# Predicted sequence: ['nun-final', 'kaf', 'pe', 'pe'] [0.9995585, 0.6933571, 0.29823285, 0.85720253]
# -----LSTM:-------
# N chars: 4
# orig shape: (100, 117)
# Idx: [ 2  5 13 24]
# Idx: [24]
# Idx: [11]
# Idx: [17]
# Idx: [15]
# Word preds: ['bet', 'he', 'nun-medial', 'waw']
# Word probs: [0.038184139877557755, 0.04269065707921982, 0.09822898358106613, 0.9842260479927063]
# ch preds: ['waw', 'mem-medial', 'resh', 'pe-final']
# ch probs: [0.9989688396453857, 0.9952190518379211, 0.41157838702201843, 0.9677438735961914]
# Empty position: 2
# LSTM:  resh 0.41157838702201843
# CNN:  pe 0.29823285
# Empty position: 3
# LSTM:  pe-final 0.9677438735961914
# CNN:  pe 0.85720253
# Final output: ['waw', 'mem-medial', 'resh', 'pe-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# CLASSIFIYING!@#!@#!@#!@#@!:
# (50, 28)
# Recognizing the following character:
# Best score: 0.92145205
# Best character: resh
# CLASSIFIYING!@#!@#!@#!@#@!:
# (50, 34)
# Recognizing the following character:
# Best score: 0.9836945
# Best character: bet
# Component:
# Recognizing the following character:
# Best score: 0.99912804
# Best character: lamed
# Predicted sequence: ['bet', 'resh', 'lamed'] [0.9836945, 0.92145205, 0.99912804]
# -----LSTM:-------
# N chars: 3
# orig shape: (103, 132)
# Idx: [2 6 9]
# Idx: [2]
# Idx: [3]
# Idx: [9]
# Word preds: ['bet', 'het', 'lamed']
# Word probs: [0.0655193030834198, 0.3579231798648834, 0.8136497735977173]
# ch preds: ['bet', 'dalet', 'lamed']
# ch probs: [0.9480980038642883, 0.577034592628479, 0.971639096736908]
# Empty position: 1
# LSTM:  dalet 0.577034592628479
# CNN:  resh 0.92145205
# Final output: ['bet', 'resh', 'lamed']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.99988186
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.9995963
# Best character: resh
# Predicted sequence: ['nun-final', 'resh'] [0.99988186, 0.9995963]
# -----LSTM:-------
# N chars: 2
# orig shape: (35, 76)
# Idx: [ 3 19]
# Idx: [19]
# Idx: [25]
# Word preds: ['dalet', 'shin']
# Word probs: [0.6784380078315735, 0.7888342142105103]
# ch preds: ['shin', 'yod']
# ch probs: [0.9750644564628601, 0.4690419137477875]
# Empty position: 1
# LSTM:  yod 0.4690419137477875
# CNN:  resh 0.9995963
# Final output: ['shin', 'resh']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 1.0
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.9978635
# Best character: nun-final
# Predicted sequence: ['nun-final', 'nun-final'] [1.0, 0.9978635]
# -----LSTM:-------
# N chars: 2
# orig shape: (40, 61)
# Idx: [ 2 25]
# Idx: [24]
# Idx: [2]
# Word preds: ['bet', 'yod']
# Word probs: [0.7909088134765625, 0.816099226474762]
# ch preds: ['waw', 'bet']
# ch probs: [0.08193612843751907, 0.797277569770813]
# Final output: ['yod', 'bet']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9228773
# Best character: he
# Predicted sequence: ['he'] [0.9228773]
# -----LSTM:-------
# N chars: 1
# orig shape: (38, 46)
# Idx: [16]
# Idx: [16]
# Word preds: ['qof']
# Word probs: [0.04691113904118538]
# ch preds: ['qof']
# ch probs: [0.16563929617404938]
# Empty position: 0
# LSTM:  qof 0.16563929617404938
# CNN:  he 0.9228773
# Final output: ['he']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9999399
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.9710722
# Best character: taw
# Predicted sequence: ['nun-final', 'taw'] [0.9999399, 0.9710722]
# -----LSTM:-------
# N chars: 2
# orig shape: (52, 77)
# Idx: [ 8 24]
# Idx: [24]
# Idx: [5]
# Word preds: ['kaf-final', 'waw']
# Word probs: [0.9490489959716797, 0.9917629957199097]
# ch preds: ['waw', 'he']
# ch probs: [0.9654854536056519, 0.999891996383667]
# Empty position: 1
# LSTM:  he 0.999891996383667
# CNN:  taw 0.9710722
# Final output: ['waw', 'he']
# test7
# ch: waw
# code: 1493
# chr: ו
# ch: mem-medial
# code: 1502
# chr: מ
# ch: resh
# code: 1512
# chr: ר
# ch: pe-final
# code: 1507
# chr: ף
# ch: bet
# code: 1489
# chr: ב
# ch: resh
# code: 1512
# chr: ר
# ch: lamed
# code: 1500
# chr: ל
# ch: shin
# code: 1513
# chr: ש
# ch: resh
# code: 1512
# chr: ר
# ch: yod
# code: 1497
# chr: י
# ch: bet
# code: 1489
# chr: ב
# ch: he
# code: 1492
# chr: ה
# ch: waw
# code: 1493
# chr: ו
# ch: he
# code: 1492
# chr: ה
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.8788378
# Best character: dalet
# Component:
# Recognizing the following character:
# Best score: 0.8788508
# Best character: yod
# Component:
# Recognizing the following character:
# Best score: 0.82494706
# Best character: dalet
# Predicted sequence: ['dalet', 'yod', 'dalet'] [0.8788378, 0.8788508, 0.82494706]
# -----LSTM:-------
# N chars: 3
# orig shape: (51, 109)
# Idx: [ 0  6 18]
# Idx: [24]
# Idx: [17]
# Idx: [15]
# Word preds: ['alef', 'het', 'samekh']
# Word probs: [0.28556114435195923, 0.49193882942199707, 0.6241781115531921]
# ch preds: ['waw', 'resh', 'pe-final']
# ch probs: [0.3635508716106415, 0.4241238534450531, 0.9572222828865051]
# Empty position: 0
# LSTM:  waw 0.3635508716106415
# CNN:  dalet 0.8788378
# Empty position: 1
# LSTM:  resh 0.4241238534450531
# CNN:  yod 0.8788508
# Empty position: 2
# LSTM:  pe-final 0.9572222828865051
# CNN:  dalet 0.82494706
# Final output: ['dalet', 'yod', 'pe-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9094463
# Best character: kaf
# Component:
# Recognizing the following character:
# Best score: 0.71170133
# Best character: het
# Component:
# Recognizing the following character:
# Best score: 0.93622327
# Best character: ayin
# Component:
# Recognizing the following character:
# Best score: 1.0
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.7428664
# Best character: nun-medial
# Component:
# Recognizing the following character:
# Best score: 0.5562382
# Best character: resh
# Predicted sequence: ['kaf', 'het', 'ayin', 'nun-final', 'nun-medial', 'resh'] [0.9094463, 0.71170133, 0.93622327, 1.0, 0.7428664, 0.5562382]
# -----LSTM:-------
# N chars: 6
# orig shape: (52, 176)
# Idx: [ 6  9 10 16 20 23]
# Idx: [1]
# Idx: [18]
# Idx: [2]
# Idx: [12]
# Idx: [24]
# Idx: [17]
# Word preds: ['het', 'lamed', 'mem', 'qof', 'taw', 'tsadi-medial']
# Word probs: [0.005743829999119043, 0.006217947695404291, 0.027266446501016617, 0.037660107016563416, 0.33622539043426514, 0.9967488050460815]
# ch preds: ['ayin', 'samekh', 'bet', 'nun-final', 'waw', 'resh']
# ch probs: [0.7468705177307129, 0.2481420338153839, 0.37027832865715027, 0, 0.7809244990348816, 0.6581152081489563]
# Empty position: 0
# LSTM:  ayin 0.7468705177307129
# CNN:  kaf 0.9094463
# Empty position: 1
# LSTM:  samekh 0.2481420338153839
# CNN:  het 0.71170133
# Empty position: 2
# LSTM:  bet 0.37027832865715027
# CNN:  ayin 0.93622327
# Empty position: 3
# LSTM:  nun-final 0
# CNN:  nun-final 0
# Empty position: 4
# LSTM:  waw 0.7809244990348816
# CNN:  nun-medial 0.7428664
# Empty position: 5
# LSTM:  resh 0.6581152081489563
# CNN:  resh 0.5562382
# Final output: ['kaf', 'het', 'ayin', 'qof', 'waw', 'resh']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.99999666
# Best character: nun-final
# Predicted sequence: ['nun-final'] [0.99999666]
# -----LSTM:-------
# N chars: 1
# orig shape: (43, 43)
# Idx: [1]
# Idx: [24]
# Word preds: ['ayin']
# Word probs: [0.7343358993530273]
# ch preds: ['waw']
# ch probs: [0.7331199049949646]
# Empty position: 0
# LSTM:  waw 0.7331199049949646
# CNN:  nun-final 0.99999666
# Final output: ['nun-final']
# test7
# ch: dalet
# code: 1491
# chr: ד
# ch: yod
# code: 1497
# chr: י
# ch: pe-final
# code: 1507
# chr: ף
# ch: kaf
# code: 1499
# chr: כ
# ch: het
# code: 1495
# chr: ח
# ch: ayin
# code: 1506
# chr: ע
# ch: qof
# code: 1511
# chr: ק
# ch: waw
# code: 1493
# chr: ו
# ch: resh
# code: 1512
# chr: ר
# ch: nun-final
# code: 1503
# chr: ן
