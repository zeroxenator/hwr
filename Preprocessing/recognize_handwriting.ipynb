# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *

# %%
path = 'image-data/test15.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image, path, plot = False)
# Out:
# Average word height and width: 46.3237410072 51.4676258993
# [-100, 1]
# [343.16269386316731, 20]
# [453.03218706575831, 17]
# [560.21435906824161, 21]
# [664.23854712450918, 20]
# [760.13491260708975, 17]
# [856.80525077349591, 14]
# [953.49357821326407, 8]
# [1055.9767752831783, 9]
# [1156.1026097254396, 6]
# [1251.4833126441024, 4]
# [1465.9186931705051, 2]
# Recognizing the following word:
# 5
# 34
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['gimel'] [0.85684431]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['gimel'] [0.85684431]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 26 recognition: ['alef'] [0.94307959]
#
# Character found at position 25 :
# Recognizing the following character:
# Recognition result: ['gimel', 'alef'] [0.76171494, 0.17600007]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef', 'resh'] [0.83304405, 0.15829964]
# ---------------------------------------------------
#
#
# Candidates: [['gimel', 'alef'], ['gimel'], ['alef', 'resh']]
# Combinations: [('gimel', 'gimel', 'alef'), ('gimel', 'gimel', 'resh'), ('alef', 'gimel', 'alef'), ('alef', 'gimel', 'resh')]
# Combi: ('gimel', 'gimel', 'alef') Probability: 1.863519406436257e-06
# Combi: ('gimel', 'gimel', 'resh') Probability: 2.0896901378157006e-06
# Combi: ('alef', 'gimel', 'alef') Probability: 1.11032446889537e-07
# Combi: ('alef', 'gimel', 'resh') Probability: 1.2450817975989105e-07
# Best word: gimel_gimel_resh
# Best?!: ['gimel', 'gimel', 'resh']
# Recognizing the following word:
# 21
# 94
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final', 'ayin', 'yod'] [0.75166374, 0.14562887, 0.099375628]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['gimel', 'bet', 'dalet'] [0.49946016, 0.27856228, 0.10094891]
# Recognizing the following character:
# Window position 1 recognition: ['gimel'] [0.85253251]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['alef', 'gimel', 'bet'] [0.62223428, 0.16999878, 0.11043943]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 26 recognition: ['resh', 'het', 'samekh', 'taw'] [0.55642188, 0.16586494, 0.093704581, 0.088095665]
#
# Character found at position 25 :
# Recognizing the following character:
# Recognition result: ['taw'] [0.96483153]
# ---------------------------------------------------
#
#
# Candidates: [['nun-final', 'ayin', 'yod'], ['taw'], ['alef', 'gimel', 'bet']]
# Combinations: [('nun-final', 'taw', 'alef'), ('nun-final', 'taw', 'gimel'), ('nun-final', 'taw', 'bet'), ('ayin', 'taw', 'alef'), ('ayin', 'taw', 'gimel'), ('ayin', 'taw', 'bet'), ('yod', 'taw', 'alef'), ('yod', 'taw', 'gimel'), ('yod', 'taw', 'bet')]
# Combi: ('nun-final', 'taw', 'alef') Probability: 0.0
# Combi: ('nun-final', 'taw', 'gimel') Probability: 0.0
# Combi: ('nun-final', 'taw', 'bet') Probability: 0.0
# Combi: ('ayin', 'taw', 'alef') Probability: 5.484484112137614e-05
# Combi: ('ayin', 'taw', 'gimel') Probability: 5.468858801276822e-06
# Combi: ('ayin', 'taw', 'bet') Probability: 0.00024130451658880523
# Combi: ('yod', 'taw', 'alef') Probability: 7.376321328215784e-05
# Combi: ('yod', 'taw', 'gimel') Probability: 7.3553061677365355e-06
# Combi: ('yod', 'taw', 'bet') Probability: 0.00032454094421928415
# Best word: yod_taw_bet
# יתב
# Recognizing the following word:
# 5
# 32
# 91
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['shin', 'gimel', 'tsadi-medial'] [0.40333778, 0.36479178, 0.16231021]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed', 'ayin', 'kaf-final', 'bet'] [0.55905539, 0.13937771, 0.12615803, 0.11748248]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet'] [0.99988055]
# ---------------------------------------------------
#
#
# Candidates: [['shin', 'gimel', 'tsadi-medial'], ['lamed', 'ayin', 'kaf-final', 'bet'], ['bet']]
# Combinations: [('shin', 'lamed', 'bet'), ('shin', 'ayin', 'bet'), ('shin', 'kaf-final', 'bet'), ('shin', 'bet', 'bet'), ('gimel', 'lamed', 'bet'), ('gimel', 'ayin', 'bet'), ('gimel', 'kaf-final', 'bet'), ('gimel', 'bet', 'bet'), ('tsadi-medial', 'lamed', 'bet'), ('tsadi-medial', 'ayin', 'bet'), ('tsadi-medial', 'kaf-final', 'bet'), ('tsadi-medial', 'bet', 'bet')]
# Combi: ('shin', 'lamed', 'bet') Probability: 0.0003883804734948803
# Combi: ('shin', 'ayin', 'bet') Probability: 0.00016621042514912722
# Combi: ('shin', 'kaf-final', 'bet') Probability: 0
# Combi: ('shin', 'bet', 'bet') Probability: 0.0002622276368186223
# Combi: ('gimel', 'lamed', 'bet') Probability: 0.0006983168517644901
# Combi: ('gimel', 'ayin', 'bet') Probability: 0.0002810154911533685
# Combi: ('gimel', 'kaf-final', 'bet') Probability: 0
# Combi: ('gimel', 'bet', 'bet') Probability: 0.000545966795881967
# Combi: ('tsadi-medial', 'lamed', 'bet') Probability: 0.0
# Combi: ('tsadi-medial', 'ayin', 'bet') Probability: 0.0
# Combi: ('tsadi-medial', 'kaf-final', 'bet') Probability: 0
# Combi: ('tsadi-medial', 'bet', 'bet') Probability: 0.0
# Best word: gimel_lamed_bet
# Best?!: ['gimel', 'lamed', 'bet']
# Recognizing the following word:
# 5
# 75
# 121
# 147
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het'] [0.98719937]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final'] [0.91890073]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['qof', 'ayin'] [0.76858515, 0.14947109]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['resh'] [0.84379452]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['resh'] [0.84379452]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 26 recognition: ['yod'] [0.96558863]
#
# Character found at position 25 :
# Recognizing the following character:
# Recognition result: ['het', 'resh', 'yod'] [0.61259121, 0.24039869, 0.12387866]
# ---------------------------------------------------
#
#
# Candidates: [['het'], ['nun-final'], ['qof', 'ayin'], ['het', 'resh', 'yod'], ['resh']]
# Combinations: [('het', 'nun-final', 'qof', 'het', 'resh'), ('het', 'nun-final', 'qof', 'resh', 'resh'), ('het', 'nun-final', 'qof', 'yod', 'resh'), ('het', 'nun-final', 'ayin', 'het', 'resh'), ('het', 'nun-final', 'ayin', 'resh', 'resh'), ('het', 'nun-final', 'ayin', 'yod', 'resh')]
# Combi: ('het', 'nun-final', 'qof', 'het', 'resh') Probability: 0.0
# Combi: ('het', 'nun-final', 'qof', 'resh', 'resh') Probability: 0.0
# Combi: ('het', 'nun-final', 'qof', 'yod', 'resh') Probability: 0.0
# Combi: ('het', 'nun-final', 'ayin', 'het', 'resh') Probability: 0.0
# Combi: ('het', 'nun-final', 'ayin', 'resh', 'resh') Probability: 0.0
# Combi: ('het', 'nun-final', 'ayin', 'yod', 'resh') Probability: 0.0
# Best word: het_nun-final_qof_het_resh
# Best?!: ['het', 'nun-final', 'qof', 'het', 'resh']
# Recognizing the following word:
# 5
# 37
# 83
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final', 'ayin'] [0.49884498, 0.45382684]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed', 'gimel'] [0.79551971, 0.17184004]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef'] [0.94598275]
# ---------------------------------------------------
#
#
# Candidates: [['nun-final', 'ayin'], ['lamed', 'gimel'], ['alef']]
# Combinations: [('nun-final', 'lamed', 'alef'), ('nun-final', 'gimel', 'alef'), ('ayin', 'lamed', 'alef'), ('ayin', 'gimel', 'alef')]
# Combi: ('nun-final', 'lamed', 'alef') Probability: 0.0
# Combi: ('nun-final', 'gimel', 'alef') Probability: 0.0
# Combi: ('ayin', 'lamed', 'alef') Probability: 0.001459792431154239
# Combi: ('ayin', 'gimel', 'alef') Probability: 1.2651779688290177e-07
# Best word: ayin_lamed_alef
# עלא
# Recognizing the following word:
# 5
# 33
# 69
# 103
# 127
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet'] [0.98892844]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'nun-final'] [0.82309121, 0.17177604]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-medial', 'bet', 'kaf'] [0.42994526, 0.37712234, 0.17142144]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf', 'bet'] [0.88542563, 0.114287]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'yod', 'dalet'] [0.5749144, 0.17993064, 0.096578412]
# ---------------------------------------------------
#
#
# Candidates: [['bet'], ['ayin', 'nun-final'], ['nun-medial', 'bet', 'kaf'], ['kaf', 'bet'], ['resh', 'yod', 'dalet']]
# Combinations: [('bet', 'ayin', 'nun-medial', 'kaf', 'resh'), ('bet', 'ayin', 'nun-medial', 'kaf', 'yod'), ('bet', 'ayin', 'nun-medial', 'kaf', 'dalet'), ('bet', 'ayin', 'nun-medial', 'bet', 'resh'), ('bet', 'ayin', 'nun-medial', 'bet', 'yod'), ('bet', 'ayin', 'nun-medial', 'bet', 'dalet'), ('bet', 'ayin', 'bet', 'kaf', 'resh'), ('bet', 'ayin', 'bet', 'kaf', 'yod'), ('bet', 'ayin', 'bet', 'kaf', 'dalet'), ('bet', 'ayin', 'bet', 'bet', 'resh'), ('bet', 'ayin', 'bet', 'bet', 'yod'), ('bet', 'ayin', 'bet', 'bet', 'dalet'), ('bet', 'ayin', 'kaf', 'kaf', 'resh'), ('bet', 'ayin', 'kaf', 'kaf', 'yod'), ('bet', 'ayin', 'kaf', 'kaf', 'dalet'), ('bet', 'ayin', 'kaf', 'bet', 'resh'), ('bet', 'ayin', 'kaf', 'bet', 'yod'), ('bet', 'ayin', 'kaf', 'bet', 'dalet'), ('bet', 'nun-final', 'nun-medial', 'kaf', 'resh'), ('bet', 'nun-final', 'nun-medial', 'kaf', 'yod'), ('bet', 'nun-final', 'nun-medial', 'kaf', 'dalet'), ('bet', 'nun-final', 'nun-medial', 'bet', 'resh'), ('bet', 'nun-final', 'nun-medial', 'bet', 'yod'), ('bet', 'nun-final', 'nun-medial', 'bet', 'dalet'), ('bet', 'nun-final', 'bet', 'kaf', 'resh'), ('bet', 'nun-final', 'bet', 'kaf', 'yod'), ('bet', 'nun-final', 'bet', 'kaf', 'dalet'), ('bet', 'nun-final', 'bet', 'bet', 'resh'), ('bet', 'nun-final', 'bet', 'bet', 'yod'), ('bet', 'nun-final', 'bet', 'bet', 'dalet'), ('bet', 'nun-final', 'kaf', 'kaf', 'resh'), ('bet', 'nun-final', 'kaf', 'kaf', 'yod'), ('bet', 'nun-final', 'kaf', 'kaf', 'dalet'), ('bet', 'nun-final', 'kaf', 'bet', 'resh'), ('bet', 'nun-final', 'kaf', 'bet', 'yod'), ('bet', 'nun-final', 'kaf', 'bet', 'dalet')]
# Combi: ('bet', 'ayin', 'nun-medial', 'kaf', 'resh') Probability: 8.581393497313348e-09
# Combi: ('bet', 'ayin', 'nun-medial', 'kaf', 'yod') Probability: 2.791251299519325e-07
# Combi: ('bet', 'ayin', 'nun-medial', 'kaf', 'dalet') Probability: 2.619864681422766e-09
# Combi: ('bet', 'ayin', 'nun-medial', 'bet', 'resh') Probability: 3.332738048922934e-08
# Combi: ('bet', 'ayin', 'nun-medial', 'bet', 'yod') Probability: 1.3413372716924326e-07
# Combi: ('bet', 'ayin', 'nun-medial', 'bet', 'dalet') Probability: 7.1925137427918216e-09
# Combi: ('bet', 'ayin', 'bet', 'kaf', 'resh') Probability: 3.5212471398491566e-08
# Combi: ('bet', 'ayin', 'bet', 'kaf', 'yod') Probability: 1.1453484399835318e-06
# Combi: ('bet', 'ayin', 'bet', 'kaf', 'dalet') Probability: 1.0750224912935117e-08
# Combi: ('bet', 'ayin', 'bet', 'bet', 'resh') Probability: 1.413393851549239e-07
# Combi: ('bet', 'ayin', 'bet', 'bet', 'yod') Probability: 5.68852944586091e-07
# Combi: ('bet', 'ayin', 'bet', 'bet', 'dalet') Probability: 3.0503011493899855e-08
# Combi: ('bet', 'ayin', 'kaf', 'kaf', 'resh') Probability: 1.4772672907493593e-10
# Combi: ('bet', 'ayin', 'kaf', 'kaf', 'yod') Probability: 4.8050753602343234e-09
# Combi: ('bet', 'ayin', 'kaf', 'kaf', 'dalet') Probability: 4.510037211633557e-11
# Combi: ('bet', 'ayin', 'kaf', 'bet', 'resh') Probability: 4.6207980126645535e-09
# Combi: ('bet', 'ayin', 'kaf', 'bet', 'yod') Probability: 1.8597467032707096e-08
# Combi: ('bet', 'ayin', 'kaf', 'bet', 'dalet') Probability: 9.972326873843501e-10
# Combi: ('bet', 'nun-final', 'nun-medial', 'kaf', 'resh') Probability: 0.0
# Combi: ('bet', 'nun-final', 'nun-medial', 'kaf', 'yod') Probability: 0.0
# Combi: ('bet', 'nun-final', 'nun-medial', 'kaf', 'dalet') Probability: 0.0
# Combi: ('bet', 'nun-final', 'nun-medial', 'bet', 'resh') Probability: 0.0
# Combi: ('bet', 'nun-final', 'nun-medial', 'bet', 'yod') Probability: 0.0
# Combi: ('bet', 'nun-final', 'nun-medial', 'bet', 'dalet') Probability: 0.0
# Combi: ('bet', 'nun-final', 'bet', 'kaf', 'resh') Probability: 0.0
# Combi: ('bet', 'nun-final', 'bet', 'kaf', 'yod') Probability: 0.0
# Combi: ('bet', 'nun-final', 'bet', 'kaf', 'dalet') Probability: 0.0
# Combi: ('bet', 'nun-final', 'bet', 'bet', 'resh') Probability: 0.0
# Combi: ('bet', 'nun-final', 'bet', 'bet', 'yod') Probability: 0.0
# Combi: ('bet', 'nun-final', 'bet', 'bet', 'dalet') Probability: 0.0
# Combi: ('bet', 'nun-final', 'kaf', 'kaf', 'resh') Probability: 0.0
# Combi: ('bet', 'nun-final', 'kaf', 'kaf', 'yod') Probability: 0.0
# Combi: ('bet', 'nun-final', 'kaf', 'kaf', 'dalet') Probability: 0.0
# Combi: ('bet', 'nun-final', 'kaf', 'bet', 'resh') Probability: 0.0
# Combi: ('bet', 'nun-final', 'kaf', 'bet', 'yod') Probability: 0.0
# Combi: ('bet', 'nun-final', 'kaf', 'bet', 'dalet') Probability: 0.0
# Best word: bet_ayin_bet_kaf_yod
# Best?!: ['bet', 'ayin', 'bet', 'kaf', 'yod']
# Recognizing the following word:
# 5
# 34
# 67
# 117
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef'] [0.92348915]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['shin'] [0.93165213]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.99263668]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'yod'] [0.90001142, 0.086290702]
# ---------------------------------------------------
#
#
# Candidates: [['alef'], ['shin'], ['resh'], ['resh', 'yod']]
# Combinations: [('alef', 'shin', 'resh', 'resh'), ('alef', 'shin', 'resh', 'yod')]
# Combi: ('alef', 'shin', 'resh', 'resh') Probability: 6.432538010110403e-07
# Combi: ('alef', 'shin', 'resh', 'yod') Probability: 0.00037065539143623977
# Best word: alef_shin_resh_yod
# אשרי
# Recognizing the following word:
# 5
# 22
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het'] [0.882155]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final'] [0.95678043]
# ---------------------------------------------------
#
#
# Candidates: [['het'], ['nun-final']]
# Combinations: [('het', 'nun-final')]
# Combi: ('het', 'nun-final') Probability: 0.0
# Best word: het_nun-final
# חן
# Recognizing the following word:
# 5
# 52
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final', 'gimel', 'kaf', 'ayin'] [0.54893523, 0.13881175, 0.13023703, 0.087646894]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed'] [0.99979037]
# ---------------------------------------------------
#
#
# Candidates: [['nun-final', 'gimel', 'kaf', 'ayin'], ['lamed']]
# Combinations: [('nun-final', 'lamed'), ('gimel', 'lamed'), ('kaf', 'lamed'), ('ayin', 'lamed')]
# Combi: ('nun-final', 'lamed') Probability: 0
# Combi: ('gimel', 'lamed') Probability: 0.011790690094896354
# Combi: ('kaf', 'lamed') Probability: 0.011058717450242462
# Combi: ('ayin', 'lamed') Probability: 0.021750999522796004
# Best word: ayin_lamed
# על
# Recognizing the following word:
# 5
# 21
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['mem', 'tet', 'tsadi-medial'] [0.39212134, 0.33614111, 0.095423348]
# Recognizing the following character:
# Window position 1 recognition: ['tet', 'resh', 'qof'] [0.48863128, 0.24467577, 0.094975106]
# Recognizing the following character:
# Window position 2 recognition: ['tet'] [0.90435129]
#
# Character found at position 1 :
# Recognizing the following character:
# Recognition result: ['alef', 'tet', 'qof'] [0.33045134, 0.31130102, 0.23009238]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 32 recognition: ['ayin'] [0.97994965]
#
# Character found at position 31 :
# Recognizing the following character:
# Recognition result: ['ayin'] [0.99972838]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['qof', 'pe-final', 'dalet', 'tsadi-final', 'resh'] [0.34978527, 0.2624532, 0.1178944, 0.097559832, 0.080918901]
# ---------------------------------------------------
#
#
# Candidates: [['ayin'], ['alef', 'tet', 'qof'], ['qof', 'pe-final', 'dalet', 'tsadi-final', 'resh']]
# Combinations: [('ayin', 'alef', 'qof'), ('ayin', 'alef', 'pe-final'), ('ayin', 'alef', 'dalet'), ('ayin', 'alef', 'tsadi-final'), ('ayin', 'alef', 'resh'), ('ayin', 'tet', 'qof'), ('ayin', 'tet', 'pe-final'), ('ayin', 'tet', 'dalet'), ('ayin', 'tet', 'tsadi-final'), ('ayin', 'tet', 'resh'), ('ayin', 'qof', 'qof'), ('ayin', 'qof', 'pe-final'), ('ayin', 'qof', 'dalet'), ('ayin', 'qof', 'tsadi-final'), ('ayin', 'qof', 'resh')]
# Combi: ('ayin', 'alef', 'qof') Probability: 2.701284702591469e-07
# Combi: ('ayin', 'alef', 'pe-final') Probability: 0.0
# Combi: ('ayin', 'alef', 'dalet') Probability: 4.800299500876961e-06
# Combi: ('ayin', 'alef', 'tsadi-final') Probability: 0.0
# Combi: ('ayin', 'alef', 'resh') Probability: 1.7329894808250726e-05
# Combi: ('ayin', 'tet', 'qof') Probability: 0.0
# Combi: ('ayin', 'tet', 'pe-final') Probability: 0.0
# Combi: ('ayin', 'tet', 'dalet') Probability: 0.0
# Combi: ('ayin', 'tet', 'tsadi-final') Probability: 0.0
# Combi: ('ayin', 'tet', 'resh') Probability: 3.859151396504832e-06
# Combi: ('ayin', 'qof', 'qof') Probability: 3.7943940905535624e-07
# Combi: ('ayin', 'qof', 'pe-final') Probability: 0.0
# Combi: ('ayin', 'qof', 'dalet') Probability: 1.0371343847513072e-05
# Combi: ('ayin', 'qof', 'tsadi-final') Probability: 0.0
# Combi: ('ayin', 'qof', 'resh') Probability: 1.5026662960885418e-05
# Best word: ayin_alef_resh
# Best?!: ['ayin', 'alef', 'resh']
# Recognizing the following word:
# 5
# 45
# 110
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet'] [0.98012525]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he'] [0.91209847]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet'] [0.97908473]
# ---------------------------------------------------
#
#
# Candidates: [['tet'], ['he'], ['dalet']]
# Combinations: [('tet', 'he', 'dalet')]
# Combi: ('tet', 'he', 'dalet') Probability: 4.1164142818794925e-05
# Best word: tet_he_dalet
# Best?!: ['tet', 'he', 'dalet']
# test15
# ch: gimel
# code: 1490
# chr: ג
# ch: gimel
# code: 1490
# chr: ג
# ch: resh
# code: 1512
# chr: ר
# ch: gimel
# code: 1490
# chr: ג
# ch: lamed
# code: 1500
# chr: ל
# ch: bet
# code: 1489
# chr: ב
# ch: het
# code: 1495
# chr: ח
# ch: nun-final
# code: 1503
# chr: ן
# ch: qof
# code: 1511
# chr: ק
# ch: het
# code: 1495
# chr: ח
# ch: resh
# code: 1512
# chr: ר
# ch: bet
# code: 1489
# chr: ב
# ch: ayin
# code: 1506
# chr: ע
# ch: bet
# code: 1489
# chr: ב
# ch: kaf
# code: 1499
# chr: כ
# ch: yod
# code: 1497
# chr: י
# ch: ayin
# code: 1506
# chr: ע
# ch: alef
# code: 1488
# chr: א
# ch: resh
# code: 1512
# chr: ר
# ch: tet
# code: 1496
# chr: ט
# ch: he
# code: 1492
# chr: ה
# ch: dalet
# code: 1491
# chr: ד
# Recognizing the following word:
# 5
# 34
# 77
# 104
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'nun-medial', 'samekh'] [0.70250571, 0.11609106, 0.081651755]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final', 'dalet'] [0.53567857, 0.4619503]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.89783931]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'nun-medial'] [0.46873608, 0.41493395]
# ---------------------------------------------------
#
#
# Candidates: [['ayin', 'nun-medial', 'samekh'], ['nun-final', 'dalet'], ['ayin'], ['ayin', 'nun-medial']]
# Combinations: [('ayin', 'nun-final', 'ayin', 'ayin'), ('ayin', 'nun-final', 'ayin', 'nun-medial'), ('ayin', 'dalet', 'ayin', 'ayin'), ('ayin', 'dalet', 'ayin', 'nun-medial'), ('nun-medial', 'nun-final', 'ayin', 'ayin'), ('nun-medial', 'nun-final', 'ayin', 'nun-medial'), ('nun-medial', 'dalet', 'ayin', 'ayin'), ('nun-medial', 'dalet', 'ayin', 'nun-medial'), ('samekh', 'nun-final', 'ayin', 'ayin'), ('samekh', 'nun-final', 'ayin', 'nun-medial'), ('samekh', 'dalet', 'ayin', 'ayin'), ('samekh', 'dalet', 'ayin', 'nun-medial')]
# Combi: ('ayin', 'nun-final', 'ayin', 'ayin') Probability: 0.0
# Combi: ('ayin', 'nun-final', 'ayin', 'nun-medial') Probability: 0.0
# Combi: ('ayin', 'dalet', 'ayin', 'ayin') Probability: 0.0
# Combi: ('ayin', 'dalet', 'ayin', 'nun-medial') Probability: 4.762104859170183e-06
# Combi: ('nun-medial', 'nun-final', 'ayin', 'ayin') Probability: 0.0
# Combi: ('nun-medial', 'nun-final', 'ayin', 'nun-medial') Probability: 0.0
# Combi: ('nun-medial', 'dalet', 'ayin', 'ayin') Probability: 0.0
# Combi: ('nun-medial', 'dalet', 'ayin', 'nun-medial') Probability: 8.148552469207412e-07
# Combi: ('samekh', 'nun-final', 'ayin', 'ayin') Probability: 0.0
# Combi: ('samekh', 'nun-final', 'ayin', 'nun-medial') Probability: 0.0
# Combi: ('samekh', 'dalet', 'ayin', 'ayin') Probability: 0.0
# Combi: ('samekh', 'dalet', 'ayin', 'nun-medial') Probability: 5.9398043607453915e-06
# Best word: samekh_dalet_ayin_nun-medial
# Best?!: ['samekh', 'dalet', 'ayin', 'nun-medial']
# Recognizing the following word:
# 8
# 35
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['zayin', 'ayin'] [0.89923489, 0.09334521]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.99999857]
# ---------------------------------------------------
#
#
# Candidates: [['zayin', 'ayin'], ['ayin']]
# Combinations: [('zayin', 'ayin'), ('ayin', 'ayin')]
# Combi: ('zayin', 'ayin') Probability: 0.0004421854866243019
# Combi: ('ayin', 'ayin') Probability: 0.0
# Best word: zayin_ayin
# Best?!: ['zayin', 'ayin']
# Recognizing the following word:
# 12
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet'] [0.97923845]
# ---------------------------------------------------
#
#
# Candidates: [['bet']]
# Combinations: [('bet',)]
# Combi: ('bet',) Probability: 0.11138613861386139
# Best word: bet
# Best?!: ['bet']
# Recognizing the following word:
# 5
# 39
# 50
# 64
# 95
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final', 'ayin'] [0.8661896, 0.12700202]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf'] [0.99444771]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final'] [0.99967027]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final'] [0.99988747]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef', 'ayin'] [0.73110282, 0.23115638]
# ---------------------------------------------------
#
#
# Candidates: [['nun-final', 'ayin'], ['kaf'], ['nun-final'], ['nun-final'], ['alef', 'ayin']]
# Combinations: [('nun-final', 'kaf', 'nun-final', 'nun-final', 'alef'), ('nun-final', 'kaf', 'nun-final', 'nun-final', 'ayin'), ('ayin', 'kaf', 'nun-final', 'nun-final', 'alef'), ('ayin', 'kaf', 'nun-final', 'nun-final', 'ayin')]
# Combi: ('nun-final', 'kaf', 'nun-final', 'nun-final', 'alef') Probability: 0
# Combi: ('nun-final', 'kaf', 'nun-final', 'nun-final', 'ayin') Probability: 0
# Combi: ('ayin', 'kaf', 'nun-final', 'nun-final', 'alef') Probability: 0
# Combi: ('ayin', 'kaf', 'nun-final', 'nun-final', 'ayin') Probability: 0
# Best word: nun-final_kaf_nun-final_nun-final_alef
# Best?!: ['nun-final', 'kaf', 'nun-final', 'nun-final', 'alef']
# Recognizing the following word:
# 5
# 35
# 86
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['shin', 'ayin'] [0.56754863, 0.43158051]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet'] [0.98283064]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef'] [0.8307153]
# ---------------------------------------------------
#
#
# Candidates: [['shin', 'ayin'], ['tet'], ['alef']]
# Combinations: [('shin', 'tet', 'alef'), ('ayin', 'tet', 'alef')]
# Combi: ('shin', 'tet', 'alef') Probability: 2.0563079853677235e-05
# Combi: ('ayin', 'tet', 'alef') Probability: 1.0351938307014668e-05
# Best word: shin_tet_alef
# Best?!: ['shin', 'tet', 'alef']
# Recognizing the following word:
# 5
# 63
# 112
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef'] [0.93130463]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.94316643]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het'] [0.9753862]
# ---------------------------------------------------
#
#
# Candidates: [['alef'], ['ayin'], ['het']]
# Combinations: [('alef', 'ayin', 'het')]
# Combi: ('alef', 'ayin', 'het') Probability: 0.0
# Best word: alef_ayin_het
# Best?!: ['alef', 'ayin', 'het']
# Recognizing the following word:
# 5
# 21
# 62
# 101
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['tsadi-final', 'dalet'] [0.60162657, 0.28945199]
# Recognizing the following character:
# Window position 1 recognition: ['dalet', 'resh', 'tsadi-final', 'bet'] [0.54404384, 0.16379759, 0.15647347, 0.1032498]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['bet'] [0.88888192]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 26 recognition: ['bet'] [0.97092021]
#
# Character found at position 25 :
# Recognizing the following character:
# Recognition result: ['bet'] [0.98467594]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'dalet'] [0.54903537, 0.44641963]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he'] [0.89475358]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'het'] [0.83100885, 0.16140459]
# ---------------------------------------------------
#
#
# Candidates: [['bet'], ['bet'], ['resh', 'dalet'], ['he'], ['resh', 'het']]
# Combinations: [('bet', 'bet', 'resh', 'he', 'resh'), ('bet', 'bet', 'resh', 'he', 'het'), ('bet', 'bet', 'dalet', 'he', 'resh'), ('bet', 'bet', 'dalet', 'he', 'het')]
# Combi: ('bet', 'bet', 'resh', 'he', 'resh') Probability: 1.706058155317457e-07
# Combi: ('bet', 'bet', 'resh', 'he', 'het') Probability: 9.494030444156901e-08
# Combi: ('bet', 'bet', 'dalet', 'he', 'resh') Probability: 5.902554394573973e-08
# Combi: ('bet', 'bet', 'dalet', 'he', 'het') Probability: 3.2847081411448066e-08
# Best word: bet_bet_resh_he_resh
# Best?!: ['bet', 'bet', 'resh', 'he', 'resh']
# Recognizing the following word:
# 5
# 70
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['yod', 'resh'] [0.65487623, 0.29402366]
# Recognizing the following character:
# Window position 1 recognition: ['yod', 'resh'] [0.58946437, 0.32277104]
# Recognizing the following character:
# Window position 2 recognition: ['yod', 'resh'] [0.73372209, 0.23776326]
#
# Character found at position 1 :
# Recognizing the following character:
# Recognition result: ['tet'] [0.95352191]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 32 recognition: ['alef'] [0.98344457]
#
# Character found at position 31 :
# Recognizing the following character:
# Recognition result: ['alef'] [0.99928135]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['shin'] [0.90814048]
# ---------------------------------------------------
#
#
# Candidates: [['alef'], ['tet'], ['shin']]
# Combinations: [('alef', 'tet', 'shin')]
# Combi: ('alef', 'tet', 'shin') Probability: 0.0
# Best word: alef_tet_shin
# Best?!: ['alef', 'tet', 'shin']
# Recognizing the following word:
# 5
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['dalet'] [0.93197674]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['dalet'] [0.93197674]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 28 recognition: ['kaf'] [0.93247849]
#
# Character found at position 27 :
# Recognizing the following character:
# Recognition result: ['kaf', 'bet'] [0.53776622, 0.46179155]
# ---------------------------------------------------
#
#
# Candidates: [['kaf', 'bet'], ['dalet']]
# Combinations: [('kaf', 'dalet'), ('bet', 'dalet')]
# Combi: ('kaf', 'dalet') Probability: 9.454389043638739e-05
# Combi: ('bet', 'dalet') Probability: 0.0005191170643908445
# Best word: bet_dalet
# בד
# Recognizing the following word:
# 5
# 31
# 69
# 107
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf', 'bet'] [0.5438394, 0.36318353]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet'] [0.98377568]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet', 'kaf'] [0.47049385, 0.40888405]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final', 'resh'] [0.86416805, 0.13096415]
# ---------------------------------------------------
#
#
# Candidates: [['kaf', 'bet'], ['dalet'], ['bet', 'kaf'], ['nun-final', 'resh']]
# Combinations: [('kaf', 'dalet', 'bet', 'nun-final'), ('kaf', 'dalet', 'bet', 'resh'), ('kaf', 'dalet', 'kaf', 'nun-final'), ('kaf', 'dalet', 'kaf', 'resh'), ('bet', 'dalet', 'bet', 'nun-final'), ('bet', 'dalet', 'bet', 'resh'), ('bet', 'dalet', 'kaf', 'nun-final'), ('bet', 'dalet', 'kaf', 'resh')]
# Combi: ('kaf', 'dalet', 'bet', 'nun-final') Probability: 0.0
# Combi: ('kaf', 'dalet', 'bet', 'resh') Probability: 1.4471943186934543e-06
# Combi: ('kaf', 'dalet', 'kaf', 'nun-final') Probability: 0.0
# Combi: ('kaf', 'dalet', 'kaf', 'resh') Probability: 5.178450123975733e-08
# Combi: ('bet', 'dalet', 'bet', 'nun-final') Probability: 0.0
# Combi: ('bet', 'dalet', 'bet', 'resh') Probability: 7.946185235826864e-06
# Combi: ('bet', 'dalet', 'kaf', 'nun-final') Probability: 0.0
# Combi: ('bet', 'dalet', 'kaf', 'resh') Probability: 2.8433585862022693e-07
# Best word: bet_dalet_bet_resh
# בדבר
# test15
# ch: samekh
# code: 1505
# chr: ס
# ch: dalet
# code: 1491
# chr: ד
# ch: ayin
# code: 1506
# chr: ע
# ch: nun-medial
# code: 1504
# chr: נ
# ch: zayin
# code: 1494
# chr: ז
# ch: ayin
# code: 1506
# chr: ע
# ch: bet
# code: 1489
# chr: ב
# ch: nun-final
# code: 1503
# chr: ן
# ch: kaf
# code: 1499
# chr: כ
# ch: nun-final
# code: 1503
# chr: ן
# ch: nun-final
# code: 1503
# chr: ן
# ch: alef
# code: 1488
# chr: א
# ch: shin
# code: 1513
# chr: ש
# ch: tet
# code: 1496
# chr: ט
# ch: alef
# code: 1488
# chr: א
# ch: alef
# code: 1488
# chr: א
# ch: ayin
# code: 1506
# chr: ע
# ch: het
# code: 1495
# chr: ח
# ch: bet
# code: 1489
# chr: ב
# ch: bet
# code: 1489
# chr: ב
# ch: resh
# code: 1512
# chr: ר
# ch: he
# code: 1492
# chr: ה
# ch: resh
# code: 1512
# chr: ר
# ch: alef
# code: 1488
# chr: א
# ch: tet
# code: 1496
# chr: ט
# ch: shin
# code: 1513
# chr: ש
# Recognizing the following word:
# Candidates: []
# Combinations: [()]
# Combi: () Probability: 0
# Best word:
# Best?!: ['']
# Recognizing the following word:
# 5
# 35
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['gimel'] [0.89202297]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['gimel'] [0.89202297]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 26 recognition: ['gimel', 'yod'] [0.74643552, 0.11189376]
#
# Character found at position 25 :
# Recognizing the following character:
# Recognition result: ['pe-final', 'lamed'] [0.63596117, 0.23459379]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet', 'ayin', 'resh'] [0.39512625, 0.32192692, 0.18338647]
# ---------------------------------------------------
#
#
# Candidates: [['pe-final', 'lamed'], ['gimel'], ['tet', 'ayin', 'resh']]
# Combinations: [('pe-final', 'gimel', 'tet'), ('pe-final', 'gimel', 'ayin'), ('pe-final', 'gimel', 'resh'), ('lamed', 'gimel', 'tet'), ('lamed', 'gimel', 'ayin'), ('lamed', 'gimel', 'resh')]
# Combi: ('pe-final', 'gimel', 'tet') Probability: 0.0
# Combi: ('pe-final', 'gimel', 'ayin') Probability: 0.0
# Combi: ('pe-final', 'gimel', 'resh') Probability: 0.0
# Combi: ('lamed', 'gimel', 'tet') Probability: 0.0
# Combi: ('lamed', 'gimel', 'ayin') Probability: 2.0873019166314543e-05
# Combi: ('lamed', 'gimel', 'resh') Probability: 2.435990139317264e-06
# Best word: lamed_gimel_ayin
# Best?!: ['lamed', 'gimel', 'ayin']
# Recognizing the following word:
# 0
# 66
# 94
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final'] [0.99866104]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final'] [0.9955622]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem', 'bet', 'tet'] [0.59966874, 0.20458893, 0.17036059]
# ---------------------------------------------------
#
#
# Candidates: [['nun-final'], ['nun-final'], ['mem', 'bet', 'tet']]
# Combinations: [('nun-final', 'nun-final', 'mem'), ('nun-final', 'nun-final', 'bet'), ('nun-final', 'nun-final', 'tet')]
# Combi: ('nun-final', 'nun-final', 'mem') Probability: 0
# Combi: ('nun-final', 'nun-final', 'bet') Probability: 0
# Combi: ('nun-final', 'nun-final', 'tet') Probability: 0
# Best word: nun-final_nun-final_mem
# Best?!: ['nun-final', 'nun-final', 'mem']
# Recognizing the following word:
# 16
# 60
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['yod', 'he', 'resh'] [0.42256457, 0.29424855, 0.20874301]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'shin', 'tet'] [0.45935437, 0.36579639, 0.17322721]
# ---------------------------------------------------
#
#
# Candidates: [['yod', 'he', 'resh'], ['ayin', 'shin', 'tet']]
# Combinations: [('yod', 'ayin'), ('yod', 'shin'), ('yod', 'tet'), ('he', 'ayin'), ('he', 'shin'), ('he', 'tet'), ('resh', 'ayin'), ('resh', 'shin'), ('resh', 'tet')]
# Combi: ('yod', 'ayin') Probability: 0.0012190458377934826
# Combi: ('yod', 'shin') Probability: 0.0033064530942891715
# Combi: ('yod', 'tet') Probability: 3.945199714776852e-05
# Combi: ('he', 'ayin') Probability: 0.0012890008382016077
# Combi: ('he', 'shin') Probability: 0.0019253107089824309
# Combi: ('he', 'tet') Probability: 5.6258311692795396e-05
# Combi: ('resh', 'ayin') Probability: 0.002020510143694077
# Combi: ('resh', 'shin') Probability: 0.001645732068169926
# Combi: ('resh', 'tet') Probability: 1.9394148951497435e-06
# Best word: yod_shin
# יש
# Recognizing the following word:
# 5
# 53
# 90
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef'] [0.99582541]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'dalet', 'kaf', 'lamed'] [0.36388007, 0.19507994, 0.16419499, 0.081475541]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet', 'samekh'] [0.81993079, 0.098213054]
# ---------------------------------------------------
#
#
# Candidates: [['alef'], ['resh', 'dalet', 'kaf', 'lamed'], ['bet', 'samekh']]
# Combinations: [('alef', 'resh', 'bet'), ('alef', 'resh', 'samekh'), ('alef', 'dalet', 'bet'), ('alef', 'dalet', 'samekh'), ('alef', 'kaf', 'bet'), ('alef', 'kaf', 'samekh'), ('alef', 'lamed', 'bet'), ('alef', 'lamed', 'samekh')]
# Combi: ('alef', 'resh', 'bet') Probability: 0.0005479541596564212
# Combi: ('alef', 'resh', 'samekh') Probability: 2.1395855789053473e-07
# Combi: ('alef', 'dalet', 'bet') Probability: 0.00022628809483955984
# Combi: ('alef', 'dalet', 'samekh') Probability: 0.0
# Combi: ('alef', 'kaf', 'bet') Probability: 6.860903442221625e-05
# Combi: ('alef', 'kaf', 'samekh') Probability: 1.182879102044474e-06
# Combi: ('alef', 'lamed', 'bet') Probability: 0.0010910146610317918
# Combi: ('alef', 'lamed', 'samekh') Probability: 4.0236664298953115e-06
# Best word: alef_lamed_bet
# Best?!: ['alef', 'lamed', 'bet']
# Recognizing the following word:
# 5
# 41
# 85
# 111
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf', 'nun-medial', 'gimel'] [0.4856405, 0.18955739, 0.092702463]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet'] [0.99810517]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'resh', 'samekh', 'bet'] [0.40413755, 0.1792421, 0.15868948, 0.11793116]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet'] [0.99982435]
# ---------------------------------------------------
#
#
# Candidates: [['kaf', 'nun-medial', 'gimel'], ['bet'], ['ayin', 'resh', 'samekh', 'bet'], ['dalet']]
# Combinations: [('kaf', 'bet', 'ayin', 'dalet'), ('kaf', 'bet', 'resh', 'dalet'), ('kaf', 'bet', 'samekh', 'dalet'), ('kaf', 'bet', 'bet', 'dalet'), ('nun-medial', 'bet', 'ayin', 'dalet'), ('nun-medial', 'bet', 'resh', 'dalet'), ('nun-medial', 'bet', 'samekh', 'dalet'), ('nun-medial', 'bet', 'bet', 'dalet'), ('gimel', 'bet', 'ayin', 'dalet'), ('gimel', 'bet', 'resh', 'dalet'), ('gimel', 'bet', 'samekh', 'dalet'), ('gimel', 'bet', 'bet', 'dalet')]
# Combi: ('kaf', 'bet', 'ayin', 'dalet') Probability: 3.618359082905191e-06
# Combi: ('kaf', 'bet', 'resh', 'dalet') Probability: 3.2033935217511384e-07
# Combi: ('kaf', 'bet', 'samekh', 'dalet') Probability: 5.850448094512335e-07
# Combi: ('kaf', 'bet', 'bet', 'dalet') Probability: 6.371238383701728e-07
# Combi: ('nun-medial', 'bet', 'ayin', 'dalet') Probability: 8.937437282309766e-07
# Combi: ('nun-medial', 'bet', 'resh', 'dalet') Probability: 7.912461984900898e-08
# Combi: ('nun-medial', 'bet', 'samekh', 'dalet') Probability: 1.4450752874457793e-07
# Combi: ('nun-medial', 'bet', 'bet', 'dalet') Probability: 1.5737117892472815e-07
# Combi: ('gimel', 'bet', 'ayin', 'dalet') Probability: 1.445067708651846e-05
# Combi: ('gimel', 'bet', 'resh', 'dalet') Probability: 1.27934249485e-06
# Combi: ('gimel', 'bet', 'samekh', 'dalet') Probability: 2.336499343712322e-06
# Combi: ('gimel', 'bet', 'bet', 'dalet') Probability: 2.544487885657363e-06
# Best word: gimel_bet_ayin_dalet
# Best?!: ['gimel', 'bet', 'ayin', 'dalet']
# Recognizing the following word:
# 5
# 31
# 61
# 108
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het'] [0.99656612]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.99975926]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'dalet'] [0.68403506, 0.30331501]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['yod', 'resh', 'alef'] [0.67065465, 0.17183395, 0.13883643]
# ---------------------------------------------------
#
#
# Candidates: [['het'], ['ayin'], ['resh', 'dalet'], ['yod', 'resh', 'alef']]
# Combinations: [('het', 'ayin', 'resh', 'yod'), ('het', 'ayin', 'resh', 'resh'), ('het', 'ayin', 'resh', 'alef'), ('het', 'ayin', 'dalet', 'yod'), ('het', 'ayin', 'dalet', 'resh'), ('het', 'ayin', 'dalet', 'alef')]
# Combi: ('het', 'ayin', 'resh', 'yod') Probability: 0.0
# Combi: ('het', 'ayin', 'resh', 'resh') Probability: 0.0
# Combi: ('het', 'ayin', 'resh', 'alef') Probability: 0.0
# Combi: ('het', 'ayin', 'dalet', 'yod') Probability: 0.0
# Combi: ('het', 'ayin', 'dalet', 'resh') Probability: 0.0
# Combi: ('het', 'ayin', 'dalet', 'alef') Probability: 0.0
# Best word: het_ayin_resh_yod
# Best?!: ['het', 'ayin', 'resh', 'yod']
# Recognizing the following word:
# 5
# 84
# 116
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet'] [0.99947101]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'dalet'] [0.81460494, 0.16321367]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['mem', 'dalet', 'he', 'taw', 'samekh'] [0.25661618, 0.18708399, 0.13935184, 0.12824814, 0.10418519]
# Recognizing the following character:
# Window position 1 recognition: ['he', 'dalet', 'samekh', 'mem', 'qof', 'taw', 'resh'] [0.15760502, 0.15527557, 0.15360697, 0.13177651, 0.10652766, 0.10614777, 0.084585816]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['he'] [0.99418652]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 28 recognition: ['bet', 'mem'] [0.75776821, 0.18271185]
#
# Character found at position 27 :
# Recognizing the following character:
# Recognition result: ['mem', 'bet', 'mem-medial'] [0.67462289, 0.18093859, 0.11695171]
# ---------------------------------------------------
#
#
# Candidates: [['bet'], ['resh', 'dalet'], ['mem', 'bet', 'mem-medial'], ['he']]
# Combinations: [('bet', 'resh', 'mem', 'he'), ('bet', 'resh', 'bet', 'he'), ('bet', 'resh', 'mem-medial', 'he'), ('bet', 'dalet', 'mem', 'he'), ('bet', 'dalet', 'bet', 'he'), ('bet', 'dalet', 'mem-medial', 'he')]
# Combi: ('bet', 'resh', 'mem', 'he') Probability: 0.00015422207576275612
# Combi: ('bet', 'resh', 'bet', 'he') Probability: 4.58011525521201e-05
# Combi: ('bet', 'resh', 'mem-medial', 'he') Probability: 1.3229409927088784e-05
# Combi: ('bet', 'dalet', 'mem', 'he') Probability: 0.0002115230297936778
# Combi: ('bet', 'dalet', 'bet', 'he') Probability: 1.473672560808821e-05
# Combi: ('bet', 'dalet', 'mem-medial', 'he') Probability: 1.1924446751370218e-05
# Best word: bet_dalet_mem_he
# Best?!: ['bet', 'dalet', 'mem', 'he']
# Recognizing the following word:
# 5
# 58
# 110
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet'] [0.9835127]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef'] [0.99886239]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem'] [0.9339481]
# ---------------------------------------------------
#
#
# Candidates: [['bet'], ['alef'], ['mem']]
# Combinations: [('bet', 'alef', 'mem')]
# Combi: ('bet', 'alef', 'mem') Probability: 0.0
# Best word: bet_alef_mem
# Best?!: ['bet', 'alef', 'mem']
# test15
# Something empty somehow ended up here..
# ch: lamed
# code: 1500
# chr: ל
# ch: gimel
# code: 1490
# chr: ג
# ch: ayin
# code: 1506
# chr: ע
# ch: nun-final
# code: 1503
# chr: ן
# ch: nun-final
# code: 1503
# chr: ן
# ch: mem
# code: 1501
# chr: ם
# ch: alef
# code: 1488
# chr: א
# ch: lamed
# code: 1500
# chr: ל
# ch: bet
# code: 1489
# chr: ב
# ch: gimel
# code: 1490
# chr: ג
# ch: bet
# code: 1489
# chr: ב
# ch: ayin
# code: 1506
# chr: ע
# ch: dalet
# code: 1491
# chr: ד
# ch: het
# code: 1495
# chr: ח
# ch: ayin
# code: 1506
# chr: ע
# ch: resh
# code: 1512
# chr: ר
# ch: yod
# code: 1497
# chr: י
# ch: bet
# code: 1489
# chr: ב
# ch: dalet
# code: 1491
# chr: ד
# ch: mem
# code: 1501
# chr: ם
# ch: he
# code: 1492
# chr: ה
# ch: bet
# code: 1489
# chr: ב
# ch: alef
# code: 1488
# chr: א
# ch: mem
# code: 1501
# chr: ם
# Recognizing the following word:
# 5
# 54
# 113
# 125
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet'] [0.99868351]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-medial', 'ayin', 'yod'] [0.32018217, 0.2715022, 0.23303238]
# ...
#
# Character found at position 27 :
# Recognizing the following character:
# Recognition result: ['het'] [0.98351789]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet', 'het', 'shin'] [0.63570327, 0.13397197, 0.080533005]
# ---------------------------------------------------
#
#
# Candidates: [['het'], ['gimel', 'ayin'], ['bet', 'het', 'shin']]
# Combinations: [('het', 'gimel', 'bet'), ('het', 'gimel', 'het'), ('het', 'gimel', 'shin'), ('het', 'ayin', 'bet'), ('het', 'ayin', 'het'), ('het', 'ayin', 'shin')]
# Combi: ('het', 'gimel', 'bet') Probability: 0.00010986298794205316
# Combi: ('het', 'gimel', 'het') Probability: 0.0
# Combi: ('het', 'gimel', 'shin') Probability: 3.1034742356512187e-06
# Combi: ('het', 'ayin', 'bet') Probability: 0.0
# Combi: ('het', 'ayin', 'het') Probability: 0.0
# Combi: ('het', 'ayin', 'shin') Probability: 0.0
# Best word: het_gimel_bet
# Best?!: ['het', 'gimel', 'bet']
# Recognizing the following word:
# 5
# 41
# 74
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed'] [0.99589062]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef', 'ayin'] [0.55877674, 0.43720868]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet', 'resh', 'alef'] [0.78243774, 0.10867325, 0.10305023]
# ---------------------------------------------------
#
#
# Candidates: [['lamed'], ['alef', 'ayin'], ['dalet', 'resh', 'alef']]
# Combinations: [('lamed', 'alef', 'dalet'), ('lamed', 'alef', 'resh'), ('lamed', 'alef', 'alef'), ('lamed', 'ayin', 'dalet'), ('lamed', 'ayin', 'resh'), ('lamed', 'ayin', 'alef')]
# Combi: ('lamed', 'alef', 'dalet') Probability: 3.668615584259479e-05
# Combi: ('lamed', 'alef', 'resh') Probability: 0.0001324432405842829
# Combi: ('lamed', 'alef', 'alef') Probability: 1.3308020567125638e-06
# Combi: ('lamed', 'ayin', 'dalet') Probability: 4.9705379156917945e-05
# Combi: ('lamed', 'ayin', 'resh') Probability: 3.020887267726478e-05
# Combi: ('lamed', 'ayin', 'alef') Probability: 3.0263740894374502e-05
# Best word: lamed_alef_resh
# Best?!: ['lamed', 'alef', 'resh']
# test15
# ch: alef
# code: 1488
# chr: א
# ch: lamed
# code: 1500
# chr: ל
# ch: alef
# code: 1488
# chr: א
# ch: resh
# code: 1512
# chr: ר
# ch: het
# code: 1495
# chr: ח
# ch: gimel
# code: 1490
# chr: ג
# ch: bet
# code: 1489
# chr: ב
# ch: lamed
# code: 1500
# chr: ל
# ch: alef
# code: 1488
# chr: א
# ch: resh
# code: 1512
# chr: ר
# Recognizing the following word:
# 5
# 68
# 135
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet', 'kaf', 'nun-medial', 'gimel'] [0.34442458, 0.27163178, 0.15953249, 0.12755907]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'tet', 'shin'] [0.48368061, 0.38790178, 0.12668745]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['resh', 'tsadi-final'] [0.85616964, 0.080778189]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['resh', 'tsadi-final'] [0.85616964, 0.080778189]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 25 recognition: ['yod', 'resh', 'alef'] [0.33519736, 0.32155755, 0.30685106]
#
# Character found at position 24 :
# Recognizing the following character:
# Recognition result: ['bet', 'tet'] [0.54021251, 0.39556125]
# ---------------------------------------------------
#
#
# Candidates: [['bet', 'kaf', 'nun-medial', 'gimel'], ['ayin', 'tet', 'shin'], ['bet', 'tet'], ['resh', 'tsadi-final']]
# Combinations: [('bet', 'ayin', 'bet', 'resh'), ('bet', 'ayin', 'bet', 'tsadi-final'), ('bet', 'ayin', 'tet', 'resh'), ('bet', 'ayin', 'tet', 'tsadi-final'), ('bet', 'tet', 'bet', 'resh'), ('bet', 'tet', 'bet', 'tsadi-final'), ('bet', 'tet', 'tet', 'resh'), ('bet', 'tet', 'tet', 'tsadi-final'), ('bet', 'shin', 'bet', 'resh'), ('bet', 'shin', 'bet', 'tsadi-final'), ('bet', 'shin', 'tet', 'resh'), ('bet', 'shin', 'tet', 'tsadi-final'), ('kaf', 'ayin', 'bet', 'resh'), ('kaf', 'ayin', 'bet', 'tsadi-final'), ('kaf', 'ayin', 'tet', 'resh'), ('kaf', 'ayin', 'tet', 'tsadi-final'), ('kaf', 'tet', 'bet', 'resh'), ('kaf', 'tet', 'bet', 'tsadi-final'), ('kaf', 'tet', 'tet', 'resh'), ('kaf', 'tet', 'tet', 'tsadi-final'), ('kaf', 'shin', 'bet', 'resh'), ('kaf', 'shin', 'bet', 'tsadi-final'), ('kaf', 'shin', 'tet', 'resh'), ('kaf', 'shin', 'tet', 'tsadi-final'), ('nun-medial', 'ayin', 'bet', 'resh'), ('nun-medial', 'ayin', 'bet', 'tsadi-final'), ('nun-medial', 'ayin', 'tet', 'resh'), ('nun-medial', 'ayin', 'tet', 'tsadi-final'), ('nun-medial', 'tet', 'bet', 'resh'), ('nun-medial', 'tet', 'bet', 'tsadi-final'), ('nun-medial', 'tet', 'tet', 'resh'), ('nun-medial', 'tet', 'tet', 'tsadi-final'), ('nun-medial', 'shin', 'bet', 'resh'), ('nun-medial', 'shin', 'bet', 'tsadi-final'), ('nun-medial', 'shin', 'tet', 'resh'), ('nun-medial', 'shin', 'tet', 'tsadi-final'), ('gimel', 'ayin', 'bet', 'resh'), ('gimel', 'ayin', 'bet', 'tsadi-final'), ('gimel', 'ayin', 'tet', 'resh'), ('gimel', 'ayin', 'tet', 'tsadi-final'), ('gimel', 'tet', 'bet', 'resh'), ('gimel', 'tet', 'bet', 'tsadi-final'), ('gimel', 'tet', 'tet', 'resh'), ('gimel', 'tet', 'tet', 'tsadi-final'), ('gimel', 'shin', 'bet', 'resh'), ('gimel', 'shin', 'bet', 'tsadi-final'), ('gimel', 'shin', 'tet', 'resh'), ('gimel', 'shin', 'tet', 'tsadi-final')]
# Combi: ('bet', 'ayin', 'bet', 'resh') Probability: 4.893471613512401e-06
# Combi: ('bet', 'ayin', 'bet', 'tsadi-final') Probability: 0.0
# Combi: ('bet', 'ayin', 'tet', 'resh') Probability: 2.297367163612298e-07
# Combi: ('bet', 'ayin', 'tet', 'tsadi-final') Probability: 0.0
# Combi: ('bet', 'tet', 'bet', 'resh') Probability: 7.217101451180133e-07
# Combi: ('bet', 'tet', 'bet', 'tsadi-final') Probability: 0.0
# Combi: ('bet', 'tet', 'tet', 'resh') Probability: 0.0
# Combi: ('bet', 'tet', 'tet', 'tsadi-final') Probability: 0.0
# Combi: ('bet', 'shin', 'bet', 'resh') Probability: 8.126801473300104e-06
# Combi: ('bet', 'shin', 'bet', 'tsadi-final') Probability: 0.0
# Combi: ('bet', 'shin', 'tet', 'resh') Probability: 3.177539671370526e-07
# Combi: ('bet', 'shin', 'tet', 'tsadi-final') Probability: 0.0
# Combi: ('kaf', 'ayin', 'bet', 'resh') Probability: 4.4540823080798806e-07
# Combi: ('kaf', 'ayin', 'bet', 'tsadi-final') Probability: 0.0
# Combi: ('kaf', 'ayin', 'tet', 'resh') Probability: 2.0910844583942454e-08
# Combi: ('kaf', 'ayin', 'tet', 'tsadi-final') Probability: 0.0
# Combi: ('kaf', 'tet', 'bet', 'resh') Probability: 0.0
# Combi: ('kaf', 'tet', 'bet', 'tsadi-final') Probability: 0.0
# Combi: ('kaf', 'tet', 'tet', 'resh') Probability: 0.0
# Combi: ('kaf', 'tet', 'tet', 'tsadi-final') Probability: 0.0
# Combi: ('kaf', 'shin', 'bet', 'resh') Probability: 3.9139130152674466e-07
# Combi: ('kaf', 'shin', 'bet', 'tsadi-final') Probability: 0.0
# Combi: ('kaf', 'shin', 'tet', 'resh') Probability: 1.5303208669690226e-08
# Combi: ('kaf', 'shin', 'tet', 'tsadi-final') Probability: 0.0
# Combi: ('nun-medial', 'ayin', 'bet', 'resh') Probability: 1.1564715164626685e-06
# Combi: ('nun-medial', 'ayin', 'bet', 'tsadi-final') Probability: 0.0
# Combi: ('nun-medial', 'ayin', 'tet', 'resh') Probability: 5.429355470741653e-08
# Combi: ('nun-medial', 'ayin', 'tet', 'tsadi-final') Probability: 0.0
# Combi: ('nun-medial', 'tet', 'bet', 'resh') Probability: 6.961688600741558e-08
# Combi: ('nun-medial', 'tet', 'bet', 'tsadi-final') Probability: 0.0
# Combi: ('nun-medial', 'tet', 'tet', 'resh') Probability: 0.0
# Combi: ('nun-medial', 'tet', 'tet', 'tsadi-final') Probability: 0.0
# Combi: ('nun-medial', 'shin', 'bet', 'resh') Probability: 1.230294842288618e-05
# Combi: ('nun-medial', 'shin', 'bet', 'tsadi-final') Probability: 0.0
# Combi: ('nun-medial', 'shin', 'tet', 'resh') Probability: 4.810392725475485e-07
# Combi: ('nun-medial', 'shin', 'tet', 'tsadi-final') Probability: 0.0
# Combi: ('gimel', 'ayin', 'bet', 'resh') Probability: 6.0685494788448405e-06
# Combi: ('gimel', 'ayin', 'bet', 'tsadi-final') Probability: 0.0
# Combi: ('gimel', 'ayin', 'tet', 'resh') Probability: 2.849037943728399e-07
# Combi: ('gimel', 'ayin', 'tet', 'tsadi-final') Probability: 0.0
# Combi: ('gimel', 'tet', 'bet', 'resh') Probability: 0.0
# Combi: ('gimel', 'tet', 'bet', 'tsadi-final') Probability: 0.0
# Combi: ('gimel', 'tet', 'tet', 'resh') Probability: 0.0
# Combi: ('gimel', 'tet', 'tet', 'tsadi-final') Probability: 0.0
# Combi: ('gimel', 'shin', 'bet', 'resh') Probability: 2.819641690460522e-06
# Combi: ('gimel', 'shin', 'bet', 'tsadi-final') Probability: 0.0
# Combi: ('gimel', 'shin', 'tet', 'resh') Probability: 1.102466125193816e-07
# Combi: ('gimel', 'shin', 'tet', 'tsadi-final') Probability: 0.0
# Best word: nun-medial_shin_bet_resh
# נשבר
# Recognizing the following word:
# 5
# 60
# 92
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final', 'resh', 'waw'] [0.48302916, 0.31835553, 0.12685415]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.98594868]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het'] [0.83927459]
# ---------------------------------------------------
#
#
# Candidates: [['nun-final', 'resh', 'waw'], ['ayin'], ['het']]
# Combinations: [('nun-final', 'ayin', 'het'), ('resh', 'ayin', 'het'), ('waw', 'ayin', 'het')]
# Combi: ('nun-final', 'ayin', 'het') Probability: 0.0
# Combi: ('resh', 'ayin', 'het') Probability: 0.0
# Combi: ('waw', 'ayin', 'het') Probability: 0.0
# Best word: nun-final_ayin_het
# Best?!: ['nun-final', 'ayin', 'het']
# Recognizing the following word:
# 5
# 30
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet', 'ayin'] [0.49576175, 0.35005429]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.99201751]
# ---------------------------------------------------
#
#
# Candidates: [['tet', 'ayin'], ['resh']]
# Combinations: [('tet', 'resh'), ('ayin', 'resh')]
# Combi: ('tet', 'resh') Probability: 0.0014946266349757213
# Combi: ('ayin', 'resh') Probability: 0.0008693442248234733
# Best word: tet_resh
# Best?!: ['tet', 'resh']
# Recognizing the following word:
# 17
# 37
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.9948042]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf', 'ayin'] [0.5435195, 0.32140276]
# ---------------------------------------------------
#
#
# Candidates: [['resh'], ['kaf', 'ayin']]
# Combinations: [('resh', 'kaf'), ('resh', 'ayin')]
# Combi: ('resh', 'kaf') Probability: 0.0009999900258662819
# Combi: ('resh', 'ayin') Probability: 0.002020510143694077
# Best word: resh_ayin
# רע
# test15
# ch: nun-final
# code: 1503
# chr: ן
# ch: ayin
# code: 1506
# chr: ע
# ch: het
# code: 1495
# chr: ח
# ch: tet
# code: 1496
# chr: ט
# ch: resh
# code: 1512
# chr: ר
# Recognizing the following word:
# 5
# 58
# 80
# 120
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef', 'resh'] [0.805408, 0.085959353]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef', 'het'] [0.77967346, 0.10526164]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.99776614]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf', 'bet', 'mem'] [0.53128988, 0.22788122, 0.082027771]
# ---------------------------------------------------
#
#
# Candidates: [['alef', 'resh'], ['alef', 'het'], ['ayin'], ['kaf', 'bet', 'mem']]
# Combinations: [('alef', 'alef', 'ayin', 'kaf'), ('alef', 'alef', 'ayin', 'bet'), ('alef', 'alef', 'ayin', 'mem'), ('alef', 'het', 'ayin', 'kaf'), ('alef', 'het', 'ayin', 'bet'), ('alef', 'het', 'ayin', 'mem'), ('resh', 'alef', 'ayin', 'kaf'), ('resh', 'alef', 'ayin', 'bet'), ('resh', 'alef', 'ayin', 'mem'), ('resh', 'het', 'ayin', 'kaf'), ('resh', 'het', 'ayin', 'bet'), ('resh', 'het', 'ayin', 'mem')]
# Combi: ('alef', 'alef', 'ayin', 'kaf') Probability: 1.5930673310720866e-12
# Combi: ('alef', 'alef', 'ayin', 'bet') Probability: 3.04335975983111e-10
# Combi: ('alef', 'alef', 'ayin', 'mem') Probability: 0.0
# Combi: ('alef', 'het', 'ayin', 'kaf') Probability: 0.0
# Combi: ('alef', 'het', 'ayin', 'bet') Probability: 0.0
# Combi: ('alef', 'het', 'ayin', 'mem') Probability: 0.0
# Combi: ('resh', 'alef', 'ayin', 'kaf') Probability: 7.90618908244967e-10
# Combi: ('resh', 'alef', 'ayin', 'bet') Probability: 1.5103804615057155e-07
# Combi: ('resh', 'alef', 'ayin', 'mem') Probability: 0.0
# Combi: ('resh', 'het', 'ayin', 'kaf') Probability: 0.0
# Combi: ('resh', 'het', 'ayin', 'bet') Probability: 0.0
# Combi: ('resh', 'het', 'ayin', 'mem') Probability: 0.0
# Best word: resh_alef_ayin_bet
# Best?!: ['resh', 'alef', 'ayin', 'bet']
# Recognizing the following word:
# 5
# 42
# 71
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['yod'] [0.99157166]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet', 'pe'] [0.77132726, 0.096690446]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'dalet'] [0.50866234, 0.46404913]
# ---------------------------------------------------
#
#
# Candidates: [['yod'], ['bet', 'pe'], ['resh', 'dalet']]
# Combinations: [('yod', 'bet', 'resh'), ('yod', 'bet', 'dalet'), ('yod', 'pe', 'resh'), ('yod', 'pe', 'dalet')]
# Combi: ('yod', 'bet', 'resh') Probability: 6.815749430690673e-05
# Combi: ('yod', 'bet', 'dalet') Probability: 1.4709338306234756e-05
# Combi: ('yod', 'pe', 'resh') Probability: 1.1920586439773683e-05
# Combi: ('yod', 'pe', 'dalet') Probability: 2.522875436989138e-07
# Best word: yod_bet_resh
# Best?!: ['yod', 'bet', 'resh']
# test15
# ch: resh
# code: 1512
# chr: ר
# ch: alef
# code: 1488
# chr: א
# ch: ayin
# code: 1506
# chr: ע
# ch: bet
# code: 1489
# chr: ב
# ch: yod
# code: 1497
# chr: י
# ch: bet
# code: 1489
# chr: ב
# ch: resh
# code: 1512
# chr: ר
# Recognizing the following word:
# 5
# 68
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef', 'bet', 'tet'] [0.39866364, 0.33368859, 0.2201445]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het', 'mem'] [0.67865896, 0.24241732]
# ---------------------------------------------------
#
#
# Candidates: [['alef', 'bet', 'tet'], ['het', 'mem']]
# Combinations: [('alef', 'het'), ('alef', 'mem'), ('bet', 'het'), ('bet', 'mem'), ('tet', 'het'), ('tet', 'mem')]
# Combi: ('alef', 'het') Probability: 0.0010848890547357527
# Combi: ('alef', 'mem') Probability: 0.0
# Combi: ('bet', 'het') Probability: 0.0007309406941135452
# Combi: ('bet', 'mem') Probability: 0.0
# Combi: ('tet', 'het') Probability: 0.00023914026159611537
# Combi: ('tet', 'mem') Probability: 0.0
# Best word: alef_het
# Best?!: ['alef', 'het']
# test15
# ch: alef
# code: 1488
# chr: א
# ch: het
# code: 1495
# chr: ח
