# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *

# %%
path = 'image-data/test7.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image)
# Out:
# Average word height and width: 42.7826086957 40.2753623188
# [178.958549025704, 7]
# [276.01291215214536, 8]
# [374.37640337702828, 10]
# [473.46429425556693, 11]
# [574.29642259252137, 9]
# [-100, 1]
# [680.61700515462769, 7]
# [772.78946131344549, 7]
# [862.57059468923853, 6]
# [956.73354023412867, 2]
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['samekh', 'bet', 'tet', 'mem'] [0.35782412, 0.27823818, 0.13995978, 0.13420029]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.93293995]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem'] [0.92420471]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he', 'het'] [0.64070177, 0.27984476]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'het', 'nun medial', 'qof'] [0.35021299, 0.27462566, 0.15691274, 0.13338403]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['yod'] [0.98262042]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.98790526]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun medial', 'ayin'] [0.42667753, 0.40043521]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['gimel', 'yod'] [0.79333007, 0.16872682]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'nun final'] [0.82161403, 0.14813112]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final', 'resh'] [0.57162571, 0.28069037]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'nun final'] [0.73641521, 0.1099764]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef'] [0.90484518]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'nun final'] [0.48586607, 0.48554555]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet'] [0.98802584]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['bet', 'resh', 'kaf'] [0.70891887, 0.18543091, 0.094016537]
#
# Character found at position -1 :
# Recognizing the following character:
# Recognition result: ['bet', 'resh', 'kaf'] [0.70891887, 0.18543091, 0.094016537]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 17 recognition: ['kaf', 'bet'] [0.59245718, 0.28649276]
# Recognizing the following character:
# Window position 18 recognition: ['bet', 'kaf'] [0.58917534, 0.40839058]
# Recognizing the following character:
# Window position 19 recognition: ['bet', 'kaf'] [0.57120198, 0.42403337]
# Recognizing the following character:
# Window position 20 recognition: ['bet'] [0.99099696]
#
# Character found at position 0 :
#
# Character found at position 19 :
# Recognizing the following character:
# Recognition result: ['bet', 'kaf'] [0.57120198, 0.42403337]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed'] [0.99985361]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['nun final', 'tsadi final'] [0.52965534, 0.33352768]
# Recognizing the following character:
# Window position 1 recognition: ['lamed', 'nun final'] [0.6070286, 0.24074835]
# Recognizing the following character:
# Window position 2 recognition: ['nun final', 'het', 'tsadi final'] [0.5145303, 0.24093643, 0.11753036]
#
# Character found at position 0 :
#
# Character found at position 1 :
# Recognizing the following character:
# Recognition result: ['lamed', 'nun final'] [0.6070286, 0.24074835]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 21 recognition: ['het', 'mem', 'resh'] [0.64302135, 0.16560206, 0.1373502]
# Recognizing the following character:
# Window position 22 recognition: ['qof', 'kaf', 'mem', 'bet'] [0.44733012, 0.16083962, 0.11126159, 0.081306525]
#
# Character found at position 0 :
#
# Character found at position 21 :
# Recognizing the following character:
# Recognition result: ['het', 'mem', 'resh'] [0.64302135, 0.16560206, 0.1373502]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'lamed'] [0.46026376, 0.42012012]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'nun medial', 'het'] [0.44439137, 0.28382358, 0.16444881]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.92003274]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed', 'mem'] [0.80540812, 0.14043935]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.8958658]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['gimel', 'shin', 'tet'] [0.27202228, 0.26398739, 0.22582904]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['dalet', 'lamed', 'resh'] [0.72549367, 0.10878696, 0.093451492]
#
# Character found at position -1 :
# Recognizing the following character:
# Recognition result: ['dalet', 'lamed', 'resh'] [0.72549367, 0.10878696, 0.093451492]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 17 recognition: ['ayin', 'het'] [0.85870683, 0.12182839]
#
# Character found at position 0 :
#
# Character found at position 16 :
# Recognizing the following character:
# Recognition result: ['ayin'] [0.91303253]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'resh'] [0.51226079, 0.39805219]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf', 'het', 'taw'] [0.64534789, 0.23298067, 0.10661241]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf', 'dalet'] [0.57860112, 0.37971544]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['taw', 'samekh', 'mem'] [0.44168046, 0.35880435, 0.082057655]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'nun final'] [0.62271756, 0.30220306]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final', 'qof'] [0.5934701, 0.27726606]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het'] [0.90942276]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet'] [0.99802566]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem'] [0.86998278]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.90572143]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'shin'] [0.7159546, 0.27396899]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['resh'] [0.99966526]
#
# Character found at position -1 :
# Recognizing the following character:
# Recognition result: ['resh'] [0.99966526]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 18 recognition: ['alef', 'gimel', 'ayin'] [0.55551958, 0.22370483, 0.22019251]
#
# Character found at position 0 :
#
# Character found at position 17 :
# Recognizing the following character:
# Recognition result: ['ayin', 'alef'] [0.63410795, 0.33115444]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['he', 'dalet', 'mem'] [0.68089539, 0.14365597, 0.12156756]
# Recognizing the following character:
# Window position 1 recognition: ['dalet', 'he', 'mem'] [0.4605836, 0.44515282, 0.092550747]
# Recognizing the following character:
# Window position 2 recognition: ['mem', 'dalet'] [0.84219342, 0.08750543]
#
# Character found at position 0 :
#
# Character found at position 1 :
# Recognizing the following character:
# Recognition result: ['dalet', 'he', 'mem'] [0.4605836, 0.44515282, 0.092550747]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 20 recognition: ['kaf'] [0.91327262]
#
# Character found at position 0 :
#
# Character found at position 19 :
# Recognizing the following character:
# Recognition result: ['kaf', 'bet', 'resh'] [0.40859997, 0.21088599, 0.20913425]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['yod', 'waw', 'lamed', 'ayin'] [0.41092193, 0.21042633, 0.14104337, 0.089175344]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['resh', 'he'] [0.80178601, 0.17808607]
#
# Character found at position -1 :
# Recognizing the following character:
# Recognition result: ['resh', 'he'] [0.80178601, 0.17808607]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 20 recognition: ['nun medial', 'ayin'] [0.51015097, 0.37152165]
# Recognizing the following character:
# Window position 21 recognition: ['ayin', 'nun medial'] [0.44262734, 0.41923621]
# Recognizing the following character:
# Window position 22 recognition: ['nun medial', 'ayin'] [0.82081556, 0.13683939]
#
# Character found at position 0 :
#
# Character found at position 21 :
# Recognizing the following character:
# Recognition result: ['ayin', 'nun medial'] [0.44262734, 0.41923621]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet'] [0.96682203]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Recognizing the following word:
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['resh'] [0.9901861]
#
# Character found at position -1 :
# Recognizing the following character:
# Recognition result: ['resh'] [0.9901861]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 15 recognition: ['alef'] [0.99644983]
#
# Character found at position 0 :
#
# Character found at position 14 :
# Recognizing the following character:
# Recognition result: ['alef'] [0.8973999]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['qof'] [0.9745453]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['nun medial', 'tsadi final', 'lamed'] [0.56983972, 0.19390576, 0.16619633]
# Recognizing the following character:
# Window position 1 recognition: ['lamed', 'tsadi final'] [0.85061216, 0.14590794]
#
# Character found at position 0 :
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['nun medial', 'tsadi final', 'lamed'] [0.56983972, 0.19390576, 0.16619633]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 19 recognition: ['bet', 'kaf'] [0.64324313, 0.35618994]
# Recognizing the following character:
# Window position 20 recognition: ['kaf'] [0.99537814]
#
# Character found at position 0 :
#
# Character found at position 19 :
# Recognizing the following character:
# Recognition result: ['bet', 'kaf'] [0.64324313, 0.35618994]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['waw'] [0.91491413]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet'] [0.82661933]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet'] [0.96101737]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet'] [0.97119945]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed'] [0.99994481]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['resh', 'gimel'] [0.76875484, 0.12222142]
#
# Character found at position -1 :
# Recognizing the following character:
# Recognition result: ['resh', 'gimel'] [0.76875484, 0.12222142]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 15 recognition: ['kaf'] [0.98853499]
#
# Character found at position 0 :
#
# Character found at position 14 :
# Recognizing the following character:
# Recognition result: ['kaf', 'bet'] [0.83214611, 0.15193085]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he', 'samekh', 'shin'] [0.47466418, 0.30022725, 0.081383899]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final'] [0.93815815]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['samekh', 'nun final', 'he'] [0.56344378, 0.19074632, 0.18763421]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['bet', 'mem', 'taw'] [0.59593606, 0.20932016, 0.11155541]
# Recognizing the following character:
# Window position 1 recognition: ['taw', 'dalet'] [0.73977685, 0.13347062]
#
# Character found at position 0 :
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['bet', 'mem', 'taw'] [0.59593606, 0.20932016, 0.11155541]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 16 recognition: ['bet', 'kaf'] [0.67903721, 0.25900018]
# Recognizing the following character:
# Window position 17 recognition: ['bet'] [0.89993978]
#
# Character found at position 0 :
#
# Character found at position 16 :
# Recognizing the following character:
# Recognition result: ['bet', 'kaf'] [0.67903721, 0.25900018]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final', 'waw'] [0.87771571, 0.10143103]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he', 'dalet', 'bet', 'yod'] [0.36453214, 0.32852995, 0.18171337, 0.087621562]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['taw', 'dalet', 'bet'] [0.37671083, 0.37265202, 0.099439897]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final'] [0.84795469]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet', 'bet', 'kaf'] [0.51270682, 0.25071502, 0.13410659]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['waw', 'yod'] [0.61397034, 0.38494855]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['yod', 'waw'] [0.77657622, 0.20304932]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'lamed'] [0.74632007, 0.19543426]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet', 'taw', 'resh', 'he'] [0.40744531, 0.18923517, 0.13998882, 0.11158212]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het', 'taw'] [0.72392941, 0.18828361]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final', 'ayin', 'zayin'] [0.39943188, 0.31312177, 0.27469128]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['shin'] [0.99941075]
# ---------------------------------------------------
#
#
# Recognizing the following word:
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het'] [0.91620797]
# ---------------------------------------------------
