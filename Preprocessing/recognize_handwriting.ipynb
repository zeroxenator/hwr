# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
path = 'image-data/test5.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image)
# Out:
# [226.7024698407351, 21]
# [-100, 1]
# [319.3643442659485, 28]
# [411.08865085528106, 24]
# [507.48382071802166, 31]
# [601.515491488843, 26]
# [605.1668744247512, 25]
# [693.9010908418267, 33]
# [788.1630806702673, 24]
# [-100, 1]
# [884.5726540139716, 15]
# [969.9413258051798, 10]
# [1047.3426132944455, 4]
# Recognizing the following word:
# [[   4   55   16   35  371]
#  [  19   40   87   42 1966]
#  [ 102    0   40   77 1409]
#  [ 143   37   22   34  486]]
# Average width: 39.308035714285715
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-0405febc17d1> in <module>()
# ----> 1 recognize_handwriting(image)
#
# ~\Documents\GitHub\handwriting_recognition\Preprocessing\recognize_handwriting.py in recognize_handwriting(image)
#     488             # extract the characters in the word
#     489             #characters = extract_characters(cv2.morphologyEx(word, cv2.MORPH_CLOSE, kernel), avg_width)
# --> 490             answer = recognize_word(cv2.morphologyEx(word, cv2.MORPH_CLOSE, kernel), avg_width)
#     491             print("Answer:", answer)
#     492             # recognize the characters in the word
#
# ~\Documents\GitHub\handwriting_recognition\Preprocessing\recognize_word.py in recognize_word(word, avg_width)
#     148     for char in chars:
#     149         #char = word[stat[1]:stat[1] + stat[3], stat[0]:stat[0]+stat[2]]
# --> 150         predictions, scores = recognize_character(char)
#     151         char_proposals.append(predictions)
#     152     #print(tuple(char_proposals))
#
# ~\Documents\GitHub\handwriting_recognition\Preprocessing\recognize_character_cnn.py in recognize_character(char)
#      16     templates = [string.split('.')[0].lower() for string in os.listdir('templates')]
#      17     dict_chars = dict(zip(templates, range(len(templates))))
# ---> 18     top_chars = [dict_chars[char.split(' ')[0]] for char in top_chars]
#      19     # print(top_chars)
#      20
#
# ~\Documents\GitHub\handwriting_recognition\Preprocessing\recognize_character_cnn.py in <listcomp>(.0)
#      16     templates = [string.split('.')[0].lower() for string in os.listdir('templates')]
#      17     dict_chars = dict(zip(templates, range(len(templates))))
# ---> 18     top_chars = [dict_chars[char.split(' ')[0]] for char in top_chars]
#      19     # print(top_chars)
#      20
#
# KeyError: 'nun'
