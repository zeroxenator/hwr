# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *
# Out:
# Using TensorFlow backend.

# %%
path = 'image-data/test7.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image, path, plot = False)
# Out:
# Average word height and width: 46.75609756097561 48.853658536585364
# [302.6832826893371, 5]
# [396.318250756607, 8]
# [493.17810320260526, 10]
# [592.8281150630826, 8]
# [692.9997894172499, 7]
# [793.5702176033146, 7]
# [889.809769137882, 5]
# [982.0532900447353, 2]
# [-100, 1]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 300)               399600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 27)                8127
# =================================================================
# Total params: 407,727
# Trainable params: 407,727
# Non-trainable params: 0
# _________________________________________________________________
# LSTM model: None
# Recognizing the following word:
# -----CNN:-------
# 4
# 29
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf jpg'] [0.9999975]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['waw jpg'] [0.99994016]
# ---------------------------------------------------
#
#
# Candidates: [['kaf'], ['waw']]
# Combinations: [('kaf', 'waw')]
# Combi: ('kaf', 'waw') Probability: 0.06432064638090977
# Best word: kaf_waw
# Final sequence: ['kaf', 'waw']
# Confidences: [0.9999975, 0.99994016]
# -----LSTM:-------
# N chars: 2
# orig shape: (50, 62)
# Idx: [14 24]
# Idx: [7]
# Idx: [24]
# Word preds: ['pe', 'waw']
# Word probs: [0.369907945394516, 0.8997498154640198]
# ch preds: ['kaf', 'waw']
# ch probs: [0.9912940859794617, 0.9998821020126343]
# Final output: ['kaf', 'waw']
# Recognizing the following word:
# -----CNN:-------
# 4
# 40
# 61
# 104
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['yod jpg'] [0.9560795]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he jpg', 'taw jpg'] [0.8699404, 0.12980871]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['waw jpg', 'nun-final jpg'] [0.79053694, 0.20938496]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tsadi-medial jpg', 'he jpg'] [0.8520519, 0.09492362]
# ---------------------------------------------------
#
#
# Candidates: [['yod'], ['he'], ['waw'], ['tsadi-medial']]
# Combinations: [('yod', 'he', 'waw', 'tsadi-medial')]
# Combi: ('yod', 'he', 'waw', 'tsadi-medial') Probability: 0.0
# Best word: yod_he_waw_tsadi-medial
# Final sequence: ['yod', 'he', 'waw', 'tsadi-medial']
# Confidences: [0.9560795, 0.8699404, 0.79053694, 0.8520519]
# -----LSTM:-------
# N chars: 4
# orig shape: (58, 133)
# Idx: [ 3  5  6 17]
# Idx: [25]
# Idx: [5]
# Idx: [24]
# Idx: [5]
# Word preds: ['dalet', 'he', 'het', 'resh']
# Word probs: [0.04469966143369675, 0.3518923819065094, 0.9985376596450806, 0.9990718364715576]
# ch preds: ['yod', 'he', 'waw', 'he']
# ch probs: [0.6628981232643127, 0.9955822825431824, 0.9919667840003967, 0.9994202852249146]
# Empty position: 0
# LSTM:  yod 0.6628981232643127
# CNN:  yod 0.9560795
# Empty position: 2
# LSTM:  waw 0.9919667840003967
# CNN:  waw 0.79053694
# Final output: ['yod', 'he', 'waw', 'he']
# Recognizing the following word:
# -----CNN:-------
# 13
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem jpg'] [0.8836064]
# ---------------------------------------------------
#
#
# Candidates: [['mem']]
# Combinations: [('mem',)]
# Combi: ('mem',) Probability: 0
# Best word: mem
# Final sequence: ['mem']
# Confidences: [0.8836064]
# -----LSTM:-------
# N chars: 1
# orig shape: (52, 76)
# Idx: [19]
# Idx: [6]
# Word preds: ['shin']
# Word probs: [0.6965409517288208]
# ch preds: ['het']
# ch probs: [0.24634137749671936]
# Empty position: 0
# LSTM:  het 0.24634137749671936
# CNN:  mem 0.8836064
# Final output: ['mem']
# Recognizing the following word:
# -----CNN:-------
# 4
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed jpg'] [0.9637554]
# ---------------------------------------------------
#
#
# Candidates: [['lamed']]
# Combinations: [('lamed',)]
# Combi: ('lamed',) Probability: 0.09917491749174917
# Best word: lamed
# Final sequence: ['lamed']
# Confidences: [0.9637554]
# -----LSTM:-------
# N chars: 1
# orig shape: (47, 43)
# Idx: [14]
# Idx: [1]
# Word preds: ['pe']
# Word probs: [0.7600572109222412]
# ch preds: ['ayin']
# ch probs: [0.704636812210083]
# Empty position: 0
# LSTM:  ayin 0.704636812210083
# CNN:  lamed 0.9637554
# Final output: ['lamed']
# test7
# ch: kaf
# code: 1499
# chr: כ
# ch: waw
# code: 1493
# chr: ו
# ch: yod
# code: 1497
# chr: י
# ch: he
# code: 1492
# chr: ה
# ch: waw
# code: 1493
# chr: ו
# ch: he
# code: 1492
# chr: ה
# ch: mem
# code: 1501
# chr: ם
# ch: lamed
# code: 1500
# chr: ל
# Recognizing the following word:
# -----CNN:-------
# 4
# 39
# 60
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-medial jpg'] [0.9594702]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['waw jpg'] [0.9935866]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh jpg'] [0.9979235]
# ---------------------------------------------------
#
#
# Candidates: [['nun-medial'], ['waw'], ['resh']]
# Combinations: [('nun-medial', 'waw', 'resh')]
# Ngram freq nun-medial_waw_resh : 8.716495968620615e-05
# Combi: ('nun-medial', 'waw', 'resh') Probability: 0.00019755132743775255
# Best word: nun-medial_waw_resh
# Final sequence: ['nun-medial', 'waw', 'resh']
# Confidences: [0.9594702, 0.9935866, 0.9979235]
# -----LSTM:-------
# N chars: 3
# orig shape: (54, 111)
# Idx: [ 2  4 17]
# Idx: [13]
# Idx: [24]
# Idx: [17]
# Word preds: ['bet', 'gimel', 'resh']
# Word probs: [0.2619055211544037, 0.3718535602092743, 0.9407562613487244]
# ch preds: ['nun-medial', 'waw', 'resh']
# ch probs: [0, 0.9059115052223206, 0.6359928250312805]
# Empty position: 0
# LSTM:  nun-medial 0
# CNN:  nun-medial 0
# Empty position: 1
# LSTM:  waw 0.9059115052223206
# CNN:  waw 0.9935866
# Final output: ['gimel', 'waw', 'resh']
# Recognizing the following word:
# -----CNN:-------
# 4
# 12
# 53
# 90
# 94
# 117
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh jpg', 'lamed jpg'] [0.64058024, 0.3352691]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-medial jpg'] [0.9904337]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf jpg'] [0.9961333]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh jpg', 'dalet jpg'] [0.5636458, 0.43207115]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tsadi-medial jpg', 'nun-final jpg'] [0.87150574, 0.12122146]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem jpg', 'resh jpg', 'kaf jpg'] [0.5767123, 0.28476414, 0.117284074]
# ---------------------------------------------------
#
#
# Candidates: [['resh'], ['nun-medial'], ['kaf'], ['resh'], ['tsadi-medial'], ['mem']]
# Combinations: [('resh', 'nun-medial', 'kaf', 'resh', 'tsadi-medial', 'mem')]
# Combi: ('resh', 'nun-medial', 'kaf', 'resh', 'tsadi-medial', 'mem') Probability: 0
# Best word: resh_nun-medial_kaf_resh_tsadi-medial_mem
# Final sequence: ['resh', 'nun-medial', 'kaf', 'resh', 'tsadi-medial', 'mem']
# Confidences: [0.64058024, 0.9904337, 0.9961333, 0.5636458, 0.87150574, 0.5767123]
# -----LSTM:-------
# N chars: 6
# orig shape: (69, 158)
# Idx: [ 1  2  5  6  9 21]
# Idx: [25]
# Idx: [2]
# Idx: [7]
# Idx: [24]
# Idx: [2]
# Idx: [25]
# Word preds: ['ayin', 'bet', 'he', 'het', 'lamed', 'tet']
# Word probs: [0.0008825730765238404, 0.002445212099701166, 0.006077997386455536, 0.951296865940094, 0.9911053776741028, 0.9994115829467773]
# ch preds: ['yod', 'bet', 'kaf', 'waw', 'bet', 'yod']
# ch probs: [0.6300567984580994, 0.9901753067970276, 0.6807684898376465, 0.34545040130615234, 0.9936218857765198, 0.36267611384391785]
# Empty position: 0
# LSTM:  yod 0.6300567984580994
# CNN:  resh 0.64058024
# Empty position: 3
# LSTM:  waw 0.34545040130615234
# CNN:  resh 0.5636458
# Empty position: 5
# LSTM:  yod 0.36267611384391785
# CNN:  mem 0.5767123
# Final output: ['resh', 'bet', 'kaf', 'resh', 'bet', 'mem']
# Recognizing the following word:
# -----CNN:-------
# 4
# 38
# 88
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['alef jpg'] [0.9986507]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['shin jpg', 'tet jpg'] [0.7278419, 0.2660316]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet jpg', 'resh jpg'] [0.87095714, 0.11515299]
# ---------------------------------------------------
#
#
# Candidates: [['alef'], ['shin'], ['dalet']]
# Combinations: [('alef', 'shin', 'dalet')]
# Combi: ('alef', 'shin', 'dalet') Probability: 6.1551629696382865e-06
# Best word: alef_shin_dalet
# Final sequence: ['alef', 'shin', 'dalet']
# Confidences: [0.9986507, 0.7278419, 0.87095714]
# -----LSTM:-------
# N chars: 3
# orig shape: (56, 135)
# Idx: [ 0 19 25]
# Idx: [0]
# Idx: [19]
# Idx: [3]
# Word preds: ['alef', 'shin', 'yod']
# Word probs: [0.15112470090389252, 0.17750152945518494, 0.9618443250656128]
# ch preds: ['alef', 'shin', 'dalet']
# ch probs: [0.999477207660675, 0.9998407363891602, 0.9185105562210083]
# Empty position: 2
# LSTM:  dalet 0.9185105562210083
# CNN:  dalet 0.87095714
# Final output: ['alef', 'shin', 'dalet']
# Recognizing the following word:
# -----CNN:-------
# 4
# 73
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet jpg'] [0.93992704]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 2 recognition: ['dalet jpg'] [0.9763174]
# Recognizing the following character:
# Recognition result: ['dalet jpg'] [0.9763174]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 27 recognition: ['bet jpg', 'kaf jpg'] [0.71415204, 0.27069575]
# Recognizing the following character:
# Recognition result: ['bet jpg', 'kaf jpg'] [0.71415204, 0.27069575]
# ---------------------------------------------------
#
#
# Candidates: [['dalet'], ['bet'], ['dalet']]
# Combinations: [('dalet', 'bet', 'dalet')]
# Combi: ('dalet', 'bet', 'dalet') Probability: 4.470067985995771e-05
# Best word: dalet_bet_dalet
# Final sequence: ['dalet', 'bet', 'dalet']
# Confidences: [0.93992704, 0.71415204, 0.9763174]
# -----LSTM:-------
# N chars: 3
# orig shape: (53, 114)
# Idx: [ 2  3 17]
# Idx: [17]
# Idx: [14]
# Idx: [17]
# Word preds: ['bet', 'dalet', 'resh']
# Word probs: [0.9923243522644043, 0.9991745352745056, 0.9998815059661865]
# ch preds: ['resh', 'pe', 'resh']
# ch probs: [0.426653116941452, 0.5440948009490967, 0.5079275965690613]
# Final output: ['resh', 'bet', 'resh']
# test7
# ch: gimel
# code: 1490
# chr: ג
# ch: waw
# code: 1493
# chr: ו
# ch: resh
# code: 1512
# chr: ר
# ch: resh
# code: 1512
# chr: ר
# ch: bet
# code: 1489
# chr: ב
# ch: kaf
# code: 1499
# chr: כ
# ch: resh
# code: 1512
# chr: ר
# ch: bet
# code: 1489
# chr: ב
# ch: mem
# code: 1501
# chr: ם
# ch: alef
# code: 1488
# chr: א
# ch: shin
# code: 1513
# chr: ש
# ch: dalet
# code: 1491
# chr: ד
# ch: resh
# code: 1512
# chr: ר
# ch: bet
# code: 1489
# chr: ב
# ch: resh
# code: 1512
# chr: ר
# Recognizing the following word:
# -----CNN:-------
# 4
# 75
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed jpg'] [1.0]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 2 recognition: ['tsadi-medial jpg'] [0.9523998]
# Recognizing the following character:
# Recognition result: ['tsadi-medial jpg'] [0.9523998]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 29 recognition: ['taw jpg'] [0.99999106]
# Recognizing the following character:
# Recognition result: ['taw jpg'] [0.99999106]
# ---------------------------------------------------
#
#
# Candidates: [['lamed'], ['taw'], ['tsadi-medial']]
# Combinations: [('lamed', 'taw', 'tsadi-medial')]
# Combi: ('lamed', 'taw', 'tsadi-medial') Probability: 0.0
# Best word: lamed_taw_tsadi-medial
# Final sequence: ['lamed', 'taw', 'tsadi-medial']
# Confidences: [1.0, 0.99999106, 0.9523998]
# -----LSTM:-------
# N chars: 3
# orig shape: (104, 111)
# Idx: [ 2 19 20]
# Idx: [18]
# Idx: [6]
# Idx: [23]
# Word preds: ['bet', 'shin', 'taw']
# Word probs: [0.12873676419258118, 0.14254574477672577, 0.7287306785583496]
# ch preds: ['samekh', 'het', 'tsadi-medial']
# ch probs: [0.09704086929559708, 0.05581231042742729, 0]
# Empty position: 0
# LSTM:  samekh 0.09704086929559708
# CNN:  lamed 1.0
# Empty position: 2
# LSTM:  tsadi-medial 0
# CNN:  tsadi-medial 0
# Final output: ['lamed', 'taw', 'shin']
# test7
# ch: lamed
# code: 1500
# chr: ל
# ch: taw
# code: 1514
# chr: ת
# ch: shin
# code: 1513
# chr: ש
# Recognizing the following word:
# -----CNN:-------
# 4
# 14
# 78
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-medial jpg'] [0.99980575]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed jpg'] [0.9997484]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final jpg'] [0.96067697]
# ---------------------------------------------------
#
#
# Candidates: [['nun-medial'], ['lamed'], ['nun-final']]
# Combinations: [('nun-medial', 'lamed', 'nun-final')]
# Combi: ('nun-medial', 'lamed', 'nun-final') Probability: 0.0
# Best word: nun-medial_lamed_nun-final
# Final sequence: ['nun-medial', 'lamed', 'nun-final']
# Confidences: [0.99980575, 0.9997484, 0.96067697]
# -----LSTM:-------
# N chars: 3
# orig shape: (94, 124)
# Idx: [ 6  9 13]
# Idx: [2]
# Idx: [9]
# Idx: [24]
# Word preds: ['het', 'lamed', 'nun-medial']
# Word probs: [0.7428971529006958, 0.9689441919326782, 0.9925501346588135]
# ch preds: ['bet', 'lamed', 'waw']
# ch probs: [0.9661797285079956, 0.060069311410188675, 0.9841469526290894]
# Empty position: 0
# LSTM:  bet 0.9661797285079956
# CNN:  nun-medial 0
# Empty position: 2
# LSTM:  waw 0.9841469526290894
# CNN:  nun-final 0.96067697
# Final output: ['bet', 'lamed', 'waw']
# Recognizing the following word:
# -----CNN:-------
# 15
# 64
# 93
# 117
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet jpg'] [0.91509986]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed jpg', 'waw jpg'] [0.828689, 0.15537755]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf jpg'] [0.9889631]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem jpg'] [0.99944216]
# ---------------------------------------------------
#
#
# Candidates: [['tet'], ['lamed'], ['kaf'], ['mem']]
# Combinations: [('tet', 'lamed', 'kaf', 'mem')]
# Combi: ('tet', 'lamed', 'kaf', 'mem') Probability: 0.0
# Best word: tet_lamed_kaf_mem
# Final sequence: ['tet', 'lamed', 'kaf', 'mem']
# Confidences: [0.91509986, 0.828689, 0.9889631, 0.99944216]
# -----LSTM:-------
# N chars: 4
# orig shape: (78, 164)
# Idx: [ 2  5 19 20]
# Idx: [19]
# Idx: [24]
# Idx: [2]
# Idx: [5]
# Word preds: ['bet', 'he', 'shin', 'taw']
# Word probs: [0.10912059247493744, 0.17336295545101166, 0.26039600372314453, 0.946366548538208]
# ch preds: ['shin', 'waw', 'bet', 'he']
# ch probs: [0.9736472964286804, 0.9996821880340576, 0.4590948224067688, 0.6693916320800781]
# Empty position: 1
# LSTM:  waw 0.9996821880340576
# CNN:  lamed 0.828689
# Final output: ['shin', 'waw', 'bet', 'he']
# Recognizing the following word:
# -----CNN:-------
# 4
# 45
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 2 recognition: ['dalet jpg', 'resh jpg'] [0.6702424, 0.32752597]
# Recognizing the following character:
# Window position 3 recognition: ['dalet jpg'] [0.9871912]
# Recognizing the following character:
# Recognition result: ['dalet jpg'] [0.9871912]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 28 recognition: ['tsadi-medial jpg'] [0.9999331]
# Recognizing the following character:
# Recognition result: ['tsadi-medial jpg'] [0.9999331]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tsadi-final jpg'] [0.9286303]
# ---------------------------------------------------
#
#
# Candidates: [['tsadi-medial'], ['dalet'], ['tsadi-final']]
# Combinations: [('tsadi-medial', 'dalet', 'tsadi-final')]
# Combi: ('tsadi-medial', 'dalet', 'tsadi-final') Probability: 0.0
# Best word: tsadi-medial_dalet_tsadi-final
# Final sequence: ['tsadi-medial', 'dalet', 'tsadi-final']
# Confidences: [0.9999331, 0.9871912, 0.9286303]
# -----LSTM:-------
# N chars: 3
# orig shape: (77, 117)
# Idx: [ 0 17 23]
# Idx: [22]
# Idx: [3]
# Idx: [22]
# Word preds: ['alef', 'resh', 'tsadi-medial']
# Word probs: [0.876700758934021, 0.9530765414237976, 0.99906986951828]
# ch preds: ['tsadi-final', 'dalet', 'tsadi-final']
# ch probs: [0, 0.3916473984718323, 0.9641490578651428]
# Empty position: 0
# LSTM:  tsadi-final 0
# CNN:  tsadi-medial 0
# Empty position: 2
# LSTM:  tsadi-final 0.9641490578651428
# CNN:  tsadi-final 0.9286303
# Final output: ['tsadi-medial', 'dalet', 'tsadi-final']
# Recognizing the following word:
# -----CNN:-------
# 4
# 42
# 49
# 73
# 111
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf jpg', 'resh jpg'] [0.60876983, 0.37489522]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem jpg'] [0.97465026]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final jpg'] [0.9995771]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf jpg'] [0.9217932]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem jpg', 'dalet jpg', 'tsadi-medial jpg', 'resh jpg'] [0.41911146, 0.21122588, 0.17203376, 0.13965327]
# ---------------------------------------------------
#
#
# Candidates: [['kaf'], ['mem'], ['nun-final'], ['kaf'], ['mem']]
# Combinations: [('kaf', 'mem', 'nun-final', 'kaf', 'mem')]
# Combi: ('kaf', 'mem', 'nun-final', 'kaf', 'mem') Probability: 0.0
# Best word: kaf_mem_nun-final_kaf_mem
# Final sequence: ['kaf', 'mem', 'nun-final', 'kaf', 'mem']
# Confidences: [0.60876983, 0.97465026, 0.9995771, 0.9217932, 0.41911146]
# -----LSTM:-------
# N chars: 5
# orig shape: (67, 168)
# Idx: [ 2  5 10 18 21]
# Idx: [17]
# Idx: [2]
# Idx: [0]
# Idx: [2]
# Idx: [2]
# Word preds: ['bet', 'he', 'mem', 'samekh', 'tet']
# Word probs: [0.021172890439629555, 0.04759873449802399, 0.11021861433982849, 0.8154621124267578, 0.9949885010719299]
# ch preds: ['resh', 'bet', 'alef', 'bet', 'bet']
# ch probs: [0.6832924485206604, 0.12734699249267578, 0.8986288905143738, 0.481521874666214, 0.8776596784591675]
# Empty position: 0
# LSTM:  resh 0.6832924485206604
# CNN:  kaf 0.60876983
# Empty position: 2
# LSTM:  alef 0.8986288905143738
# CNN:  nun-final 0.9995771
# Final output: ['resh', 'bet', 'nun-final', 'bet', 'bet']
# Recognizing the following word:
# -----CNN:-------
# 4
# 20
# 74
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf jpg'] [0.9880801]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed jpg'] [0.94123876]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet jpg', 'kaf jpg'] [0.51684946, 0.43690935]
# ---------------------------------------------------
#
#
# Candidates: [['kaf'], ['lamed'], ['bet']]
# Combinations: [('kaf', 'lamed', 'bet')]
# Combi: ('kaf', 'lamed', 'bet') Probability: 0.0006549649505035379
# Best word: kaf_lamed_bet
# Final sequence: ['kaf', 'lamed', 'bet']
# Confidences: [0.9880801, 0.94123876, 0.51684946]
# -----LSTM:-------
# N chars: 3
# orig shape: (54, 102)
# Idx: [ 2 10 11]
# Idx: [2]
# Idx: [21]
# Idx: [18]
# Word preds: ['bet', 'mem', 'mem-medial']
# Word probs: [0.11108233034610748, 0.12875840067863464, 0.6433077454566956]
# ch preds: ['bet', 'tet', 'samekh']
# ch probs: [0.9966596364974976, 0.08220960944890976, 0.10931621491909027]
# Empty position: 1
# LSTM:  tet 0.08220960944890976
# CNN:  lamed 0.94123876
# Empty position: 2
# LSTM:  samekh 0.10931621491909027
# CNN:  bet 0.51684946
# Final output: ['bet', 'lamed', 'bet']
# test7
# ch: bet
# code: 1489
# chr: ב
# ch: lamed
# code: 1500
# chr: ל
# ch: waw
# code: 1493
# chr: ו
# ch: shin
# code: 1513
# chr: ש
# ch: waw
# code: 1493
# chr: ו
# ch: bet
# code: 1489
# chr: ב
# ch: he
# code: 1492
# chr: ה
# ch: tsadi-medial
# code: 1510
# chr: צ
# ch: dalet
# code: 1491
# chr: ד
# ch: tsadi-final
# code: 1509
# chr: ץ
# ch: resh
# code: 1512
# chr: ר
# ch: bet
# code: 1489
# chr: ב
# ch: nun-final
# code: 1503
# chr: ן
# ch: bet
# code: 1489
# chr: ב
# ch: bet
# code: 1489
# chr: ב
# ch: bet
# code: 1489
# chr: ב
# ch: lamed
# code: 1500
# chr: ל
# ch: bet
# code: 1489
# chr: ב
# Recognizing the following word:
# -----CNN:-------
# 4
# 49
# 98
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem jpg'] [0.9855869]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet jpg'] [0.9999465]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he jpg'] [0.9866328]
# ---------------------------------------------------
#
#
# Candidates: [['mem'], ['tet'], ['he']]
# Combinations: [('mem', 'tet', 'he')]
# Combi: ('mem', 'tet', 'he') Probability: 0.0
# Best word: mem_tet_he
# Final sequence: ['mem', 'tet', 'he']
# Confidences: [0.9855869, 0.9999465, 0.9866328]
# -----LSTM:-------
# N chars: 3
# orig shape: (55, 136)
# Idx: [ 5  6 21]
# Idx: [6]
# Idx: [21]
# Idx: [5]
# Word preds: ['he', 'het', 'tet']
# Word probs: [0.8557302355766296, 0.8966832160949707, 0.9968798160552979]
# ch preds: ['het', 'tet', 'he']
# ch probs: [0.9601464867591858, 0.9179031848907471, 0.9992539286613464]
# Final output: ['het', 'tet', 'he']
# Recognizing the following word:
# -----CNN:-------
# 4
# 39
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 2 recognition: ['he jpg', 'resh jpg'] [0.577897, 0.36620146]
# Recognizing the following character:
# Window position 3 recognition: ['he jpg'] [0.99642736]
# Recognizing the following character:
# Recognition result: ['he jpg'] [0.99642736]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 29 recognition: ['nun-medial jpg'] [0.9896919]
# Recognizing the following character:
# Recognition result: ['nun-medial jpg'] [0.9896919]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf jpg'] [0.9438847]
# ---------------------------------------------------
#
#
# Candidates: [['nun-medial'], ['he'], ['kaf']]
# Combinations: [('nun-medial', 'he', 'kaf')]
# Combi: ('nun-medial', 'he', 'kaf') Probability: 0.00011281259390798948
# Best word: nun-medial_he_kaf
# Final sequence: ['nun-medial', 'he', 'kaf']
# Confidences: [0.9896919, 0.99642736, 0.9438847]
# -----LSTM:-------
# N chars: 3
# orig shape: (52, 138)
# Idx: [ 0 13 17]
# Idx: [13]
# Idx: [24]
# Idx: [17]
# Word preds: ['alef', 'nun-medial', 'resh']
# Word probs: [0.3744962513446808, 0.4736851155757904, 0.49648919701576233]
# ch preds: ['nun-medial', 'waw', 'resh']
# ch probs: [0, 0.2879451513290405, 0.41576847434043884]
# Empty position: 1
# LSTM:  waw 0.2879451513290405
# CNN:  he 0.99642736
# Final output: ['nun-medial', 'he', 'resh']
# Recognizing the following word:
# -----CNN:-------
# 4
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 2 recognition: ['he jpg'] [0.98267996]
# Recognizing the following character:
# Recognition result: ['he jpg'] [0.98267996]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 30 recognition: ['ayin jpg'] [0.99997234]
# Recognizing the following character:
# Recognition result: ['ayin jpg'] [0.99997234]
# ---------------------------------------------------
#
#
# Candidates: [['ayin'], ['he']]
# Combinations: [('ayin', 'he')]
# Combi: ('ayin', 'he') Probability: 0.004082053102029611
# Best word: ayin_he
# Final sequence: ['ayin', 'he']
# Confidences: [0.99997234, 0.98267996]
# -----LSTM:-------
# N chars: 2
# orig shape: (56, 111)
# Idx: [1 5]
# Idx: [1]
# Idx: [5]
# Word preds: ['ayin', 'he']
# Word probs: [0.9907209873199463, 0.9945963025093079]
# ch preds: ['ayin', 'he']
# ch probs: [0.25594958662986755, 0.3148497939109802]
# Final output: ['ayin', 'he']
# Recognizing the following word:
# -----CNN:-------
# 20
# 43
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 2 recognition: ['resh jpg'] [0.99998796]
# Recognizing the following character:
# Recognition result: ['resh jpg'] [0.99998796]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 28 recognition: ['tsadi-final jpg', 'tsadi-medial jpg'] [0.87948835, 0.096426904]
# Recognizing the following character:
# Recognition result: ['tsadi-final jpg', 'tsadi-medial jpg'] [0.87948835, 0.096426904]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['zayin jpg'] [0.93395406]
# ---------------------------------------------------
#
#
# Candidates: [['tsadi-final'], ['resh'], ['zayin']]
# Combinations: [('tsadi-final', 'resh', 'zayin')]
# Combi: ('tsadi-final', 'resh', 'zayin') Probability: 0.0
# Best word: tsadi-final_resh_zayin
# Final sequence: ['tsadi-final', 'resh', 'zayin']
# Confidences: [0.87948835, 0.99998796, 0.93395406]
# -----LSTM:-------
# N chars: 3
# orig shape: (47, 119)
# Idx: [ 0 17 19]
# Idx: [26]
# Idx: [25]
# Idx: [1]
# Word preds: ['alef', 'resh', 'shin']
# Word probs: [0.27567851543426514, 0.6275644898414612, 0.8288236856460571]
# ch preds: ['zayin', 'yod', 'ayin']
# ch probs: [0.24921569228172302, 0.2721306383609772, 0.4882137179374695]
# Empty position: 0
# LSTM:  zayin 0.24921569228172302
# CNN:  tsadi-final 0
# Empty position: 1
# LSTM:  yod 0.2721306383609772
# CNN:  resh 0.99998796
# Final output: ['zayin', 'resh', 'zayin']
# Recognizing the following word:
# -----CNN:-------
# 4
# 60
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin jpg', 'shin jpg'] [0.4998586, 0.49954787]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed jpg', 'tsadi-medial jpg'] [0.719004, 0.27832496]
# ---------------------------------------------------
#
#
# Candidates: [['ayin'], ['lamed']]
# Combinations: [('ayin', 'lamed')]
# Ngram freq ayin_lamed : 0.01547178034430159
# Combi: ('ayin', 'lamed') Probability: 0.021750999522796004
# Best word: ayin_lamed
# Final sequence: ['ayin', 'lamed']
# Confidences: [0.4998586, 0.719004]
# -----LSTM:-------
# N chars: 2
# orig shape: (47, 133)
# Idx: [ 1 19]
# Idx: [19]
# Idx: [1]
# Word preds: ['ayin', 'shin']
# Word probs: [0.991675853729248, 0.9998639822006226]
# ch preds: ['shin', 'ayin']
# ch probs: [0.9998706579208374, 0.6812031269073486]
# Final output: ['shin', 'ayin']
# test7
# ch: het
# code: 1495
# chr: ח
# ch: tet
# code: 1496
# chr: ט
# ch: he
# code: 1492
# chr: ה
# ch: nun-medial
# code: 1504
# chr: נ
# ch: he
# code: 1492
# chr: ה
# ch: resh
# code: 1512
# chr: ר
# ch: ayin
# code: 1506
# chr: ע
# ch: he
# code: 1492
# chr: ה
# ch: zayin
# code: 1494
# chr: ז
# ch: resh
# code: 1512
# chr: ר
# ch: zayin
# code: 1494
# chr: ז
# ch: shin
# code: 1513
# chr: ש
# ch: ayin
# code: 1506
# chr: ע
# Recognizing the following word:
# -----CNN:-------
# 4
# 7
# 22
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final jpg'] [0.9998832]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['gimel jpg', 'lamed jpg'] [0.7175042, 0.28242132]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet jpg', 'kaf jpg'] [0.9127803, 0.08692032]
# ---------------------------------------------------
#
#
# Candidates: [['nun-final'], ['gimel'], ['bet']]
# Combinations: [('nun-final', 'gimel', 'bet')]
# Combi: ('nun-final', 'gimel', 'bet') Probability: 0.0
# Best word: nun-final_gimel_bet
# Final sequence: ['nun-final', 'gimel', 'bet']
# Confidences: [0.9998832, 0.7175042, 0.9127803]
# -----LSTM:-------
# N chars: 3
# orig shape: (92, 49)
# Idx: [ 7 13 14]
# Idx: [4]
# Idx: [25]
# Idx: [7]
# Word preds: ['kaf', 'nun-medial', 'pe']
# Word probs: [0.09288769215345383, 0.10669968277215958, 0.6460956931114197]
# ch preds: ['gimel', 'yod', 'kaf']
# ch probs: [0.3024488687515259, 0.2949516773223877, 0.7670143842697144]
# Empty position: 0
# LSTM:  gimel 0.3024488687515259
# CNN:  nun-final 0
# Empty position: 1
# LSTM:  yod 0.2949516773223877
# CNN:  gimel 0.7175042
# Final output: ['gimel', 'gimel', 'kaf']
# Recognizing the following word:
# -----CNN:-------
# Candidates: []
# Combinations: [()]
# Combi: () Probability: 0
# Best word:
# Final sequence: ['']
# Confidences: []
# -----LSTM:-------
# N chars: 0
# Recognizing the following word:
# -----CNN:-------
# 4
# 38
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 2 recognition: ['dalet jpg', 'resh jpg', 'tsadi-medial jpg'] [0.42488366, 0.30002323, 0.11808106]
# Recognizing the following character:
# Window position 3 recognition: ['tsadi-medial jpg'] [0.9939044]
# Recognizing the following character:
# Recognition result: ['tsadi-medial jpg'] [0.9939044]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['qof jpg'] [0.9933206]
# ---------------------------------------------------
#
#
# Candidates: [['tsadi-medial'], ['qof']]
# Combinations: [('tsadi-medial', 'qof')]
# Combi: ('tsadi-medial', 'qof') Probability: 0
# Best word: tsadi-medial_qof
# Final sequence: ['tsadi-medial', 'qof']
# Confidences: [0.9939044, 0.9933206]
# -----LSTM:-------
# N chars: 2
# orig shape: (72, 110)
# Idx: [ 0 17]
# Idx: [3]
# Idx: [22]
# Word preds: ['alef', 'resh']
# Word probs: [0.9999310970306396, 0.9999932050704956]
# ch preds: ['dalet', 'tsadi-final']
# ch probs: [0.25801220536231995, 0.9985674619674683]
# Empty position: 1
# LSTM:  tsadi-final 0.9985674619674683
# CNN:  qof 0.9933206
# Final output: ['resh', 'tsadi-final']
# Recognizing the following word:
# -----CNN:-------
# 23
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['gimel jpg', 'mem jpg', 'dalet jpg'] [0.45661756, 0.4011698, 0.080336854]
# ---------------------------------------------------
#
#
# Candidates: [['gimel']]
# Combinations: [('gimel',)]
# Combi: ('gimel',) Probability: 0.01089108910891089
# Best word: gimel
# Final sequence: ['gimel']
# Confidences: [0.45661756]
# -----LSTM:-------
# N chars: 1
# orig shape: (47, 80)
# Idx: [17]
# Idx: [17]
# Word preds: ['resh']
# Word probs: [0.9110082983970642]
# ch preds: ['resh']
# ch probs: [0.6761361360549927]
# Final output: ['resh']
# Recognizing the following word:
# -----CNN:-------
# 4
# 18
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf jpg', 'nun-medial jpg'] [0.79862493, 0.20129335]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final jpg', 'waw jpg', 'kaf jpg'] [0.43392363, 0.34012038, 0.2209947]
# ---------------------------------------------------
#
#
# Candidates: [['kaf'], ['nun-final']]
# Combinations: [('kaf', 'nun-final')]
# Ngram freq kaf_nun-final : 0.00141643059490085
# Combi: ('kaf', 'nun-final') Probability: 0.0
# Best word: kaf_nun-final
# Final sequence: ['kaf', 'nun-final']
# Confidences: [0.79862493, 0.43392363]
# -----LSTM:-------
# N chars: 2
# orig shape: (54, 54)
# Idx: [ 2 24]
# Idx: [21]
# Idx: [8]
# Word preds: ['bet', 'waw']
# Word probs: [0.521504819393158, 0.6197296977043152]
# ch preds: ['tet', 'kaf-final']
# ch probs: [0.9961870312690735, 0.9723861217498779]
# Empty position: 0
# LSTM:  tet 0.9961870312690735
# CNN:  kaf 0.79862493
# Empty position: 1
# LSTM:  kaf-final 0.9723861217498779
# CNN:  nun-final 0.43392363
# Final output: ['tet', 'kaf-final']
# Recognizing the following word:
# -----CNN:-------
# 4
# 17
# 49
# 94
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf-final jpg'] [0.9982047]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['mem-medial jpg', 'kaf jpg'] [0.7728105, 0.21114372]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['shin jpg', 'bet jpg'] [0.5700201, 0.3887794]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 2 recognition: ['lamed jpg', 'tsadi-final jpg'] [0.5839019, 0.3283533]
# Recognizing the following character:
# Window position 3 recognition: ['lamed jpg', 'samekh jpg'] [0.80197066, 0.17802697]
# Recognizing the following character:
# Recognition result: ['lamed jpg', 'samekh jpg'] [0.80197066, 0.17802697]
# ---------------------------------------------------
#
#
# Candidates: [['kaf-final'], ['mem-medial'], ['shin'], ['lamed']]
# Combinations: [('kaf-final', 'mem-medial', 'shin', 'lamed')]
# Combi: ('kaf-final', 'mem-medial', 'shin', 'lamed') Probability: 0.0
# Best word: kaf-final_mem-medial_shin_lamed
# Final sequence: ['kaf-final', 'mem-medial', 'shin', 'lamed']
# Confidences: [0.9982047, 0.7728105, 0.5700201, 0.80197066]
# -----LSTM:-------
# N chars: 4
# orig shape: (50, 124)
# Idx: [ 9 16 19 21]
# Idx: [16]
# Idx: [2]
# Idx: [2]
# Idx: [23]
# Word preds: ['lamed', 'qof', 'shin', 'tet']
# Word probs: [0.0010548869613558054, 0.04352704808115959, 0.9822373986244202, 0.9913893342018127]
# ch preds: ['qof', 'bet', 'bet', 'tsadi-medial']
# ch probs: [0.8887143731117249, 0.9889709949493408, 0.23998333513736725, 0]
# Empty position: 1
# LSTM:  bet 0.9889709949493408
# CNN:  mem-medial 0.7728105
# Empty position: 2
# LSTM:  bet 0.23998333513736725
# CNN:  shin 0.5700201
# Empty position: 3
# LSTM:  tsadi-medial 0
# CNN:  lamed 0.80197066
# Final output: ['qof', 'bet', 'shin', 'lamed']
# Recognizing the following word:
# -----CNN:-------
# 4
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 2 recognition: ['tsadi-medial jpg', 'nun-medial jpg'] [0.8701008, 0.12873292]
# Recognizing the following character:
# Recognition result: ['tsadi-medial jpg', 'nun-medial jpg'] [0.8701008, 0.12873292]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 28 recognition: ['kaf jpg', 'bet jpg'] [0.6844977, 0.31486848]
# Recognizing the following character:
