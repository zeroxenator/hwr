# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *

# %%
path = 'image-data/test7.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image, "")
# Out:
# Average word height and width: 42.7826086957 40.2753623188
# [178.958549025704, 7]
# [276.01291215214536, 8]
# [374.37640337702828, 10]
# [473.46429425556693, 11]
# [574.29642259252137, 9]
# [-100, 1]
# [680.61700515462769, 7]
# [772.78946131344549, 7]
# [862.57059468923853, 6]
# [956.73354023412867, 2]
# Recognizing the following word:
# 5
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['samekh', 'tet', 'mem'] [0.69920486, 0.092736945, 0.083170094]
# ---------------------------------------------------
#
#
# Candidates: [['samekh', 'tet', 'mem']]
# Combinations: [('samekh',), ('tet',), ('mem',)]
# Combi: ('samekh',) Frequency: 0
# Combi: ('tet',) Frequency: 0
# Combi: ('mem',) Frequency: 0
# Best word: samekh
# Recognizing the following word:
# 5
# 62
# 105
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['waw'] [0.91258043]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['qof', 'dalet', 'he'] [0.53420728, 0.25549763, 0.11153055]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he'] [0.99976534]
# ---------------------------------------------------
#
#
# Candidates: [['waw'], ['qof', 'dalet', 'he'], ['he']]
# Combinations: [('waw', 'qof', 'he'), ('waw', 'dalet', 'he'), ('waw', 'he', 'he')]
# Combi: ('waw', 'qof', 'he') Frequency: 0.04076625609203473
# Combi: ('waw', 'dalet', 'he') Frequency: 0.04076625609203473
# Combi: ('waw', 'he', 'he') Frequency: 0.04076625609203473
# Best word: waw_qof_he
# Recognizing the following word:
# 14
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final', 'resh'] [0.63218766, 0.24082184]
# ---------------------------------------------------
#
#
# Candidates: [['nun final', 'resh']]
# Combinations: [('nun final',), ('resh',)]
# Combi: ('nun final',) Frequency: 0
# Combi: ('resh',) Frequency: 0
# Best word: nun final
# Recognizing the following word:
# Candidates: []
# Combinations: [()]
# Combi: () Frequency: 0
# Best word:
# Recognizing the following word:
# 5
# 40
# 61
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'nun final'] [0.88020712, 0.10711721]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final'] [0.94634515]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'alef', 'dalet'] [0.73718947, 0.12968275, 0.080295943]
# ---------------------------------------------------
#
#
# Candidates: [['ayin', 'nun final'], ['nun final'], ['resh', 'alef', 'dalet']]
# Combinations: [('ayin', 'nun final', 'resh'), ('ayin', 'nun final', 'alef'), ('ayin', 'nun final', 'dalet'), ('nun final', 'nun final', 'resh'), ('nun final', 'nun final', 'alef'), ('nun final', 'nun final', 'dalet')]
# Combi: ('ayin', 'nun final', 'resh') Frequency: 0
# Combi: ('ayin', 'nun final', 'alef') Frequency: 0
# Combi: ('ayin', 'nun final', 'dalet') Frequency: 0
# Combi: ('nun final', 'nun final', 'resh') Frequency: 0
# Combi: ('nun final', 'nun final', 'alef') Frequency: 0
# Combi: ('nun final', 'nun final', 'dalet') Frequency: 0
# Best word: ayin_nun final_resh
# Recognizing the following word:
# 13
# 54
# 95
# 118
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['yod', 'alef'] [0.86952204, 0.090062842]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet'] [0.9929294]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh'] [0.97371066]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he', 'ayin', 'kaf'] [0.77598327, 0.086169973, 0.080773756]
# ---------------------------------------------------
#
#
# Candidates: [['yod', 'alef'], ['tet'], ['resh'], ['he', 'ayin', 'kaf']]
# Combinations: [('yod', 'tet', 'resh', 'he'), ('yod', 'tet', 'resh', 'ayin'), ('yod', 'tet', 'resh', 'kaf'), ('alef', 'tet', 'resh', 'he'), ('alef', 'tet', 'resh', 'ayin'), ('alef', 'tet', 'resh', 'kaf')]
# Combi: ('yod', 'tet', 'resh', 'he') Frequency: 0
# Combi: ('yod', 'tet', 'resh', 'ayin') Frequency: 0
# Combi: ('yod', 'tet', 'resh', 'kaf') Frequency: 0
# Combi: ('alef', 'tet', 'resh', 'he') Frequency: 0
# Combi: ('alef', 'tet', 'resh', 'ayin') Frequency: 0
# Combi: ('alef', 'tet', 'resh', 'kaf') Frequency: 0
# Best word: yod_tet_resh_he
# Recognizing the following word:
# 5
# 39
# 89
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.99114323]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet'] [0.99841261]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet'] [0.91256744]
# ---------------------------------------------------
#
#
# Candidates: [['ayin'], ['tet'], ['dalet']]
# Combinations: [('ayin', 'tet', 'dalet')]
# Combi: ('ayin', 'tet', 'dalet') Frequency: 0
# Best word: ayin_tet_dalet
# Recognizing the following word:
# 5
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['bet', 'resh', 'kaf'] [0.70891887, 0.18543091, 0.094016537]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['bet', 'resh', 'kaf'] [0.70891887, 0.18543091, 0.094016537]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 25 recognition: ['bet'] [0.99994719]
#
# Character found at position 24 :
# Recognizing the following character:
# Recognition result: ['bet'] [0.95855236]
# ---------------------------------------------------
#
#
# Candidates: [['bet', 'resh', 'kaf'], ['bet']]
# Combinations: [('bet', 'bet'), ('resh', 'bet'), ('kaf', 'bet')]
# Combi: ('bet', 'bet') Frequency: 0
# Combi: ('resh', 'bet') Frequency: 0
# Combi: ('kaf', 'bet') Frequency: 0
# Best word: bet_bet
# Recognizing the following word:
# 5
# 77
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['lamed'] [0.99998546]
# ---------------------------------------------------
#
#
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['nun final', 'tsadi final'] [0.52965534, 0.33352768]
# Recognizing the following character:
# Window position 1 recognition: ['lamed', 'nun final'] [0.6070286, 0.24074835]
# Recognizing the following character:
# Window position 2 recognition: ['nun final', 'het', 'tsadi final'] [0.5145303, 0.24093643, 0.11753036]
#
# Character found at position 1 :
# Recognizing the following character:
# Recognition result: ['qof', 'kaf final'] [0.56060487, 0.42782348]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 29 recognition: ['tet'] [0.89551693]
#
# Character found at position 28 :
# Recognizing the following character:
# Recognition result: ['mem', 'tet'] [0.83967143, 0.13006394]
# ---------------------------------------------------
#
#
# Candidates: [['lamed'], ['qof', 'kaf final'], ['mem', 'tet']]
# Combinations: [('lamed', 'qof', 'mem'), ('lamed', 'qof', 'tet'), ('lamed', 'kaf final', 'mem'), ('lamed', 'kaf final', 'tet')]
# Combi: ('lamed', 'qof', 'mem') Frequency: 0.013500088202637792
# Combi: ('lamed', 'qof', 'tet') Frequency: 0.013500088202637792
# Combi: ('lamed', 'kaf final', 'mem') Frequency: 0.013500088202637792
# Combi: ('lamed', 'kaf final', 'tet') Frequency: 0.013500088202637792
# Best word: lamed_qof_mem
# Recognizing the following word:
# 5
# 16
# 78
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.74755263]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'lamed', 'nun final'] [0.57771313, 0.26483759, 0.082741231]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final'] [0.95413643]
# ---------------------------------------------------
#
#
# Candidates: [['ayin'], ['ayin', 'lamed', 'nun final'], ['nun final']]
# Combinations: [('ayin', 'ayin', 'nun final'), ('ayin', 'lamed', 'nun final'), ('ayin', 'nun final', 'nun final')]
# Combi: ('ayin', 'ayin', 'nun final') Frequency: 0
# Combi: ('ayin', 'lamed', 'nun final') Frequency: 0
# Combi: ('ayin', 'nun final', 'nun final') Frequency: 0
# Best word: ayin_ayin_nun final
# Recognizing the following word:
# 17
# 65
# 119
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['bet', 'qof'] [0.55990952, 0.36667448]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['resh', 'kaf', 'dalet'] [0.69013488, 0.1292123, 0.12037686]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het'] [0.92100567]
# ---------------------------------------------------
#
#
# Candidates: [['bet', 'qof'], ['resh', 'kaf', 'dalet'], ['het']]
# Combinations: [('bet', 'resh', 'het'), ('bet', 'kaf', 'het'), ('bet', 'dalet', 'het'), ('qof', 'resh', 'het'), ('qof', 'kaf', 'het'), ('qof', 'dalet', 'het')]
# Combi: ('bet', 'resh', 'het') Frequency: 0.0069565939254324525
# Combi: ('bet', 'kaf', 'het') Frequency: 0.0069565939254324525
# Combi: ('bet', 'dalet', 'het') Frequency: 0.0069565939254324525
# Combi: ('qof', 'resh', 'het') Frequency: 0
# Combi: ('qof', 'kaf', 'het') Frequency: 0
# Combi: ('qof', 'dalet', 'het') Frequency: 0
# Best word: bet_resh_het
# Recognizing the following word:
# 5
# 46
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['dalet', 'lamed', 'resh'] [0.72549367, 0.10878696, 0.093451492]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['dalet', 'lamed', 'resh'] [0.72549367, 0.10878696, 0.093451492]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 24 recognition: ['ayin', 'alef'] [0.78708577, 0.090698175]
#
# Character found at position 23 :
# Recognizing the following character:
# Recognition result: ['het', 'tsadi final', 'alef'] [0.56505162, 0.1850493, 0.17339383]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tsadi final'] [0.98100567]
# ---------------------------------------------------
#
#
# Candidates: [['dalet', 'lamed', 'resh'], ['het', 'tsadi final', 'alef'], ['tsadi final']]
# Combinations: [('dalet', 'het', 'tsadi final'), ('dalet', 'tsadi final', 'tsadi final'), ('dalet', 'alef', 'tsadi final'), ('lamed', 'het', 'tsadi final'), ('lamed', 'tsadi final', 'tsadi final'), ('lamed', 'alef', 'tsadi final'), ('resh', 'het', 'tsadi final'), ('resh', 'tsadi final', 'tsadi final'), ('resh', 'alef', 'tsadi final')]
# Combi: ('dalet', 'het', 'tsadi final') Frequency: 0.030692165876301847
# Combi: ('dalet', 'tsadi final', 'tsadi final') Frequency: 0.030692165876301847
# Combi: ('dalet', 'alef', 'tsadi final') Frequency: 0.030692165876301847
# Combi: ('lamed', 'het', 'tsadi final') Frequency: 0.013500088202637792
# Combi: ('lamed', 'tsadi final', 'tsadi final') Frequency: 0.013500088202637792
# Combi: ('lamed', 'alef', 'tsadi final') Frequency: 0.013500088202637792
# Combi: ('resh', 'het', 'tsadi final') Frequency: 0.0068317612510247075
# Combi: ('resh', 'tsadi final', 'tsadi final') Frequency: 0.0068317612510247075
# Combi: ('resh', 'alef', 'tsadi final') Frequency: 0.0068317612510247075
# Best word: dalet_het_tsadi final
# Recognizing the following word:
# 5
# 43
# 74
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['samekh', 'taw', 'he'] [0.68927342, 0.098087363, 0.097768709]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['kaf', 'bet'] [0.60165429, 0.39081192]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['dalet', 'taw'] [0.72443771, 0.21990363]
# ---------------------------------------------------
#
#
# Candidates: [['samekh', 'taw', 'he'], ['kaf', 'bet'], ['dalet', 'taw']]
# Combinations: [('samekh', 'kaf', 'dalet'), ('samekh', 'kaf', 'taw'), ('samekh', 'bet', 'dalet'), ('samekh', 'bet', 'taw'), ('taw', 'kaf', 'dalet'), ('taw', 'kaf', 'taw'), ('taw', 'bet', 'dalet'), ('taw', 'bet', 'taw'), ('he', 'kaf', 'dalet'), ('he', 'kaf', 'taw'), ('he', 'bet', 'dalet'), ('he', 'bet', 'taw')]
# Combi: ('samekh', 'kaf', 'dalet') Frequency: 0
# Combi: ('samekh', 'kaf', 'taw') Frequency: 0
# Combi: ('samekh', 'bet', 'dalet') Frequency: 0
# Combi: ('samekh', 'bet', 'taw') Frequency: 0
# Combi: ('taw', 'kaf', 'dalet') Frequency: 0.017279726883126345
# Combi: ('taw', 'kaf', 'taw') Frequency: 0.017279726883126345
# Combi: ('taw', 'bet', 'dalet') Frequency: 0.017279726883126345
# Combi: ('taw', 'bet', 'taw') Frequency: 0.017279726883126345
# Combi: ('he', 'kaf', 'dalet') Frequency: 0
# Combi: ('he', 'kaf', 'taw') Frequency: 0
# Combi: ('he', 'bet', 'dalet') Frequency: 0
# Combi: ('he', 'bet', 'taw') Frequency: 0
# Best word: taw_kaf_dalet
# Recognizing the following word:
# 20
# 73
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin', 'nun final'] [0.69708782, 0.24553537]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final', 'ayin'] [0.75315952, 0.24550816]
# ---------------------------------------------------
#
#
# Candidates: [['ayin', 'nun final'], ['nun final', 'ayin']]
# Combinations: [('ayin', 'nun final'), ('ayin', 'ayin'), ('nun final', 'nun final'), ('nun final', 'ayin')]
# Combi: ('ayin', 'nun final') Frequency: 0
# Combi: ('ayin', 'ayin') Frequency: 0
# Combi: ('nun final', 'nun final') Frequency: 0
# Combi: ('nun final', 'ayin') Frequency: 0
# Best word: ayin_nun final
# Recognizing the following word:
# 5
# 50
# 99
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['het'] [0.95589614]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['tet'] [0.98306918]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['he', 'mem', 'qof'] [0.58885366, 0.26390326, 0.11815829]
# ---------------------------------------------------
#
#
# Candidates: [['het'], ['tet'], ['he', 'mem', 'qof']]
# Combinations: [('het', 'tet', 'he'), ('het', 'tet', 'mem'), ('het', 'tet', 'qof')]
# Combi: ('het', 'tet', 'he') Frequency: 0.0069565939254324525
# Combi: ('het', 'tet', 'mem') Frequency: 0.0069565939254324525
# Combi: ('het', 'tet', 'qof') Frequency: 0.0069565939254324525
# Best word: het_tet_he
# Recognizing the following word:
# 5
# 61
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun final', 'ayin'] [0.61887139, 0.35927001]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.93424404]
# ---------------------------------------------------
#
#
# Candidates: [['nun final', 'ayin'], ['ayin']]
# Combinations: [('nun final', 'ayin'), ('ayin', 'ayin')]
# Combi: ('nun final', 'ayin') Frequency: 0
# Combi: ('ayin', 'ayin') Frequency: 0
# Best word: nun final_ayin
# Recognizing the following word:
# 44
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['resh'] [0.99966526]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['resh'] [0.99966526]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 25 recognition: ['ayin'] [0.99619138]
#
# Character found at position 24 :
# Recognizing the following character:
# Recognition result: ['alef', 'ayin'] [0.58300614, 0.3455357]
# ---------------------------------------------------
#
#
# Candidates: [['resh'], ['alef', 'ayin']]
# Combinations: [('resh', 'alef'), ('resh', 'ayin')]
# Combi: ('resh', 'alef') Frequency: 0
# Combi: ('resh', 'ayin') Frequency: 0
# Best word: resh_alef
# Recognizing the following word:
# 5
# 40
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['he', 'dalet', 'mem'] [0.68089539, 0.14365597, 0.12156756]
# Recognizing the following character:
# Window position 1 recognition: ['dalet', 'he', 'mem'] [0.4605836, 0.44515282, 0.092550747]
# Recognizing the following character:
# Window position 2 recognition: ['mem', 'dalet'] [0.84219342, 0.08750543]
#
# Character found at position 1 :
# Recognizing the following character:
# Recognition result: ['kaf', 'mem'] [0.79110056, 0.10664723]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 27 recognition: ['kaf'] [0.91477817]
#
# Character found at position 26 :
# Recognizing the following character:
# Recognition result: ['kaf'] [0.88997936]
# ---------------------------------------------------
#
#
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['qof', 'ayin', 'tet'] [0.67070711, 0.16525975, 0.11920185]
# ---------------------------------------------------
#
#
# Candidates: [['kaf', 'mem'], ['kaf'], ['qof', 'ayin', 'tet']]
# Combinations: [('kaf', 'kaf', 'qof'), ('kaf', 'kaf', 'ayin'), ('kaf', 'kaf', 'tet'), ('mem', 'kaf', 'qof'), ('mem', 'kaf', 'ayin'), ('mem', 'kaf', 'tet')]
# Combi: ('kaf', 'kaf', 'qof') Frequency: 0
# Combi: ('kaf', 'kaf', 'ayin') Frequency: 0
# Combi: ('kaf', 'kaf', 'tet') Frequency: 0
# Combi: ('mem', 'kaf', 'qof') Frequency: 0.011980287575188433
# Combi: ('mem', 'kaf', 'ayin') Frequency: 0.011980287575188433
# Combi: ('mem', 'kaf', 'tet') Frequency: 0.011980287575188433
# Best word: mem_kaf_qof
# Recognizing the following word:
# 5
# Component is big: use sliding window!
# Initial window:
# Recognizing the following character:
# Window position 0 recognition: ['resh', 'he'] [0.80178601, 0.17808607]
#
# Character found at position 0 :
# Recognizing the following character:
# Recognition result: ['resh', 'he'] [0.80178601, 0.17808607]
# ---------------------------------------------------
#
# Recognizing the following character:
# Window position 27 recognition: ['ayin'] [0.99736291]
#
# Character found at position 26 :
# Recognizing the following character:
# Recognition result: ['ayin'] [0.99984002]
# ---------------------------------------------------
#
#
# Candidates: [['resh', 'he'], ['ayin']]
# Combinations: [('resh', 'ayin'), ('he', 'ayin')]
# Combi: ('resh', 'ayin') Frequency: 0
# Combi: ('he', 'ayin') Frequency: 0
# Best word: resh_ayin
# Best is in names!
# רע
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-3-7412c1c25c4b> in <module>()
# ----> 1 recognize_handwriting(image, "")
#
# ~\Desktop\AI\BlockD\handwritingRecognition\hwr\Preprocessing\recognize_handwriting.py in recognize_handwriting(image, path)
#     379             recognized_word = recognize_word(cv2.morphologyEx(word, cv2.MORPH_CLOSE, kernel), avg_width)
#     380             recognized_words.append(recognized_word)
# --> 381         write_line_to_file(recognized_words, path)
#     382
#
# ~\Desktop\AI\BlockD\handwritingRecognition\hwr\Preprocessing\recognize_handwriting.py in write_line_to_file(words, path)
#     337     f= open("recog_output/" + name + ".txt" ,"a+")
#     338     for word in words:
# --> 339         f.write(word + " ")
#     340     f.write("\n")
#     341
#
# c:\users\paul\appdata\local\programs\python\python36\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 0-1: character maps to <undefined>
