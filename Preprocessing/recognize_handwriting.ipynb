# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *

# %%
path = 'image-data/test11.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image)
# Out:
# [[     6      0   1003    877 504655]
#  [     0      0   1031    877 339707]
#  [   679      1      2      3      4]
#  ...,
#  [   161    840      1      2      2]
#  [   153    843      1      1      1]
#  [   161    844      1      1      1]]
# [157.69495106228115, 2]
# [224.08744394618833, 1]
# [268.80705161996673, 2]
# [377.51418918351476, 10]
# [479.56189966705233, 10]
# [588.05800973385101, 5]
# [676.35538378501894, 3]
# [777.71941972920695, 2]
# Recognizing the following word:
# [[  3   5  16  12 155]
#  [ 19   3  25  29 438]
#  [ 38  25   7   7  49]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Answer: het_Mem-medial
# Recognizing the following word:
# [[  3  37  12  20 198]
#  [ 10   2  31  53 616]
#  [ 44  39  17  18 257]
#  [ 64  42  14  15 182]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Answer: bet_kaf
# Recognizing the following word:
# [[  3   3  30  16 419]
#  [ 36   4  24  15 242]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Answer: Lamed_alef
# Recognizing the following word:
# [[  3   0   9   8  62]
#  [ 12   8  13  14 144]
#  [ 14   0  26  21 268]
#  [ 44   0  18  34 332]
#  [ 64   0  48  31 890]
#  [113   2  46  31 918]
#  [159  26   7   7  49]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Answer: Nun-medial_Shin_kaf_Shin
# Recognizing the following word:
# [[  3   9   7   7  49]
#  [  8  25  10  15 112]
#  [ 14   3  41  35 737]]
# Average width: 36.1944444444
# Recognizing the following character:
# Answer: Qof
# Recognizing the following word:
# [[   3    2   55   31 1145]
#  [  63    4   20   27  354]
#  [  82    3   17   28  293]
#  [ 103    5   21   28  363]
#  [ 126   11   10   13  108]
#  [ 138    9   14   28  277]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Answer: Lamed_Waw_Waw_Zayin
# Recognizing the following word:
# [[   3    3   81   35 1612]
#  [  88    8   54   34 1063]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Answer: Lamed_Tet
# Recognizing the following word:
# [[   3    3   13   18  192]
#  [  20    3   48   28  852]
#  [  71    4   79   31 1575]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Answer: Mem-medial_ayin
# Recognizing the following word:
# [[  3   3  18  25 288]
#  [ 14  33   8  11  82]
#  [ 21   5  27  30 504]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Answer: Zayin_Waw
# Recognizing the following word:
# [[   3    3   32   33  594]
#  [  35    4   57   38 1379]
#  [  94    9   42   31  814]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Answer: Samekh_Pe_Tet
# Recognizing the following word:
# [[   3    0   99   36 1852]
#  [ 104    5   33   28  601]
#  [ 141    7   55   33 1110]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Answer: Nun-medial_ayin_Shin_ayin_Shin
# Recognizing the following word:
# [[   3   12   31   53 1008]
#  [  36    3   22   24  342]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Answer: kaf_Yod
# Recognizing the following word:
# [[  3   3  22  18 309]
#  [ 18  23   7  10  70]
#  [ 28   7  36  30 646]
#  [ 65   7  30  31 569]
#  [ 97  11  16  30 341]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Answer: Waw_ayin_Mem_Nun-final
# Recognizing the following word:
# [[ 10   0  18  54 644]]
# Average width: 36.1944444444
# Recognizing the following character:
# Answer: bet
# Recognizing the following word:
# [[  3   0  24  30 465]
#  [ 31   3  13  14 167]
#  [ 39  22   7   9  63]
#  [ 47   2  46  32 894]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Answer: he_Nun-final
# Recognizing the following word:
# [[  3   5  30  17 383]
#  [ 12  27   7   7  49]
#  [ 26   3  32  31 550]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Answer: Mem-medial_he
# Recognizing the following word:
# [[  3   3  15  16 195]
#  [ 14  20   8  11  84]
#  [ 21   3  12  13 139]
#  [ 30  19   8  12  94]
#  [ 40   3  34  27 613]
#  [ 76   6  18  27 307]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Answer: Waw_ayin_he
# Recognizing the following word:
# [[   3   18   47   29  769]
#  [  52   16   62   33 1044]
#  [  62    0   11   15  133]
#  [ 120   30   22   14  266]
#  [ 146   29   16   15  204]]
# Average width: 36.1944444444
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Recognizing the following character:
# Answer: Taw_Lamed_Yod_Qof
