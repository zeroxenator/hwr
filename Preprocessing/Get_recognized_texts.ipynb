# %%
import os
import cv2
from recognize_handwriting import *

# %%
for path in os.listdir('image-data'):
    image = cv2.imread('image-data/' + path, cv2.IMREAD_GRAYSCALE)
    recognize_handwriting(image, 'image-data/' + path, plot = False)
# Out:
# Average word height and width: 67.5714285714 66.4285714286
# [266.28983298406047, 2]
# [587.29489178500035, 3]
# [-100, 1]
# Recognizing the following word:
# Candidates: []
# Combinations: [()]
# Combi: () Probability: 0
# Best word:
# Best?!: ['']
# Recognizing the following word:
# 5
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['nun-final'] [0.92437488]
# ---------------------------------------------------
#
#
# Candidates: [['nun-final']]
# Combinations: [('nun-final',)]
# Combi: ('nun-final',) Probability: 0
# Best word: nun-final
# Best?!: ['nun-final']
# Recognizing the following word:
# 5
# Component small enough,  proceed to recognition:
# Recognizing the following character:
# Recognition result: ['ayin'] [0.97993213]
# ---------------------------------------------------
#
#
# Candidates: [['ayin']]
# Combinations: [('ayin',)]
# Combi: ('ayin',) Probability: 0.036138613861386136
# Best word: ayin
# ...
