# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
image = cv2.imread('test.jpg', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# Show the original image containing the text

# %%
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
image_median = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 19, 10)
#_, image_median =  cv2.threshold(image,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
image_median = cv2.medianBlur(image_median, 9)

n_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(image_median, 4, cv2.CV_32S)
print(stats)
n_labels


im3, contours, hierarchy = cv2.findContours(image_median,cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
im3 = cv2.drawContours(im3, contours, -1, (0,255,0), 3)

plt.figure(figsize = (500,10))
plt.imshow(im3, cmap='gray')
plt.show()
# Out:
# [[    331      35    1701    1589  247919]
#  [      0       0    2165    1624 2698978]
#  [    682      71     142     142   19776]
#  [    854      71     142     144   19225]
#  [   1370      73     146     144   20059]
#  [   1542      74     144     144   20370]
#  [    791     263     769    1117  478811]
#  [   1113     310       5       9      31]
#  [   1092     326      27      34     566]
#  [    979     554       8      16      59]
#  [    971     570       5       7      22]
#  [   1467     595      33      10     257]
#  [    662     651       7       8      41]
#  [   1469     672      12      10      82]
#  [   1916     716      52      34     810]
#  [   1887     731       2       2       3]
#  [   1914     746      11       9      71]
#  [   1933     755      19      22     260]
#  [   1914     765      54      31     698]
#  [    881     793       5       4      12]
#  [   1928     797      18      12     129]
#  [   1914     811      52      21     521]
#  [   1934     842       7      20     128]
#  [   1914     870      53      38     996]
#  [   1086     957       7      30     164]
#  [   1506     958       1       1       1]
#  [   1885    1032       4       9      30]
#  [   1090    1036       9      19     119]
#  [    899    1133      28      44     791]
#  [    474    1405       8       3      16]
#  [    628    1406       1       1       1]
#  [   1138    1407       3       1       3]
#  [   1143    1406       4       3       6]
#  [   1386    1407       2       1       2]
#  [   1177    1444      17      18     247]
#  [    452    1456      53      72    3447]
#  [   1101    1480      11      72     540]
#  [    370    1489      17      18     245]
#  [   1983    1490      17      18     252]
#  [   1178    1528      43       8     265]
#  [    898    1543       2       1       2]
#  [   1312    1542       2       2       3]
#  [   1402    1543       1       1       1]
#  [   1480    1543       1       1       1]]

# %%
height, width = labels.shape 
component = np.zeros((height,width))
# compute the second-highest area component
area = stats[:, 4]
biggest = np.amax(area)
print(biggest)


for i in range(height):
    for j in range(width):
        if(labels[i][j] == 6):
            component[i][j] = 255
# Out:
# 2698978

# %% [markdown]
# Show the original image after removing noise with a median filter

# %%
plt.figure(figsize = (500,10))
plt.imshow(component, cmap='gray')
plt.show()

# %%
def compute_class_stats(histogram, lower_limit, upper_limit):
    class_occurance = 0
    class_mean = 0
    #compute class occurance
    for i in range(lower_limit, upper_limit):
        if(i +1 in histogram):
            class_occurance += histogram[i+1]
    #compute class mean
    for i in range(lower_limit, upper_limit):
        if(i +1 in histogram):
            class_mean += (i * histogram[i+1]) / class_occurance
        
    return class_occurance, class_mean
        
    
    

def multi_otsu_thresholding(image):
    #count all the different greylevels in the image
    histogram = {}
    height, width = image.shape
    N = height * width
    for i in range(height):
        for j in range(width):
            if(image[i,j] not in histogram):
                histogram[image[i,j]] = image[i,j]
            else:
                 histogram[image[i,j]] += 1
    #calculate p_i: divide each count by the total number of pixels
    for key, value in histogram.items():
        histogram[key] = histogram[key] / N
    #print(histogram)
    k1 = 2
    k2 = 3
    
    total_mean = 0
    total_variance = 0
    #compute the total mean
    for i in range(255):
        if(i + 1 in histogram):
            total_mean += i * histogram[i + 1]
    
    #compute the total variance
    for i in range(255):
        if(i +1 in histogram):
            total_variance += (i+1 - total_mean) * (i+1 - total_mean) * histogram[i + 1]
    
    maximum_variance = 0
    thresholds = [1, 2]
    #for every possible thresholds k1 and k2:
    for k1 in range(1,255):
        for k2 in range(1,255):    
            #1. compute w0, w1 and w2: class occurence of all three classes
            #2. compute u1, u2 and u3: class means of all three classes
            w0, u0 = compute_class_stats(histogram, 1, k1)
            w1, u1 = compute_class_stats(histogram, k1 + 1, k2)
            w2, u2 = compute_class_stats(histogram, k2 + 1, 255)        
            #3. compute and store the between classes variance.
            #variance = w0 * w1 * w2 * (u2 - u1 - u0) * (u2 - u1 - u0)
            variance01 = w0 * w1 * (u1 - u0) * (u1 - u0)
            variance02 = w0 * w2 * (u2 - u0) * (u2 - u0)
            variance12 = w1 * w2 * (u2 - u1) * (u2 - u1)
            variance = variance01 + variance02 + variance12
            #print(variance)
            #4. overwrite current optimal thresholds if variance is higher
            #than current maximum
            if(variance > maximum_variance):
                maximum_variance = variance
                thresholds[0] = k1
                thresholds[1] = k2
                
        print("Progress:", round(k1/255 * 100, 1), "%")
    print(thresholds[0],thresholds[1], maximum_variance) 
    #threshold the image using the optimal k1 and k2
    for i in range(height):
        for j in range(width):
            if(image[i,j] < thresholds[0]):
                image[i,j] = 0
            elif(image[i,j] > thresholds[1]):
                image[i,j] = 255
            else:
                image[i,j] = 125         
    #return the image
    return image

new_image =  multi_otsu_thresholding(image)
# Out:
# Progress: 0.4 %
# Progress: 0.8 %
# Progress: 1.2 %
# Progress: 1.6 %
# Progress: 2.0 %
# Progress: 2.4 %
# Progress: 2.7 %
# Progress: 3.1 %
# Progress: 3.5 %
# Progress: 3.9 %
# Progress: 4.3 %
# Progress: 4.7 %
# Progress: 5.1 %
# Progress: 5.5 %
# Progress: 5.9 %
# Progress: 6.3 %
# Progress: 6.7 %
# Progress: 7.1 %
# Progress: 7.5 %
# Progress: 7.8 %
# Progress: 8.2 %
# Progress: 8.6 %
# Progress: 9.0 %
# Progress: 9.4 %
# Progress: 9.8 %
# Progress: 10.2 %
# Progress: 10.6 %
# Progress: 11.0 %
# Progress: 11.4 %
# Progress: 11.8 %
# Progress: 12.2 %
# Progress: 12.5 %
# Progress: 12.9 %
# Progress: 13.3 %
# Progress: 13.7 %
# Progress: 14.1 %
# Progress: 14.5 %
# Progress: 14.9 %
# Progress: 15.3 %
# Progress: 15.7 %
# Progress: 16.1 %
# Progress: 16.5 %
# Progress: 16.9 %
# Progress: 17.3 %
# Progress: 17.6 %
# Progress: 18.0 %
# Progress: 18.4 %
# Progress: 18.8 %
# Progress: 19.2 %
# Progress: 19.6 %
# Progress: 20.0 %
# Progress: 20.4 %
# Progress: 20.8 %
# Progress: 21.2 %
# Progress: 21.6 %
# Progress: 22.0 %
# Progress: 22.4 %
# Progress: 22.7 %
# Progress: 23.1 %
# Progress: 23.5 %
# Progress: 23.9 %
# Progress: 24.3 %
# Progress: 24.7 %
# Progress: 25.1 %
# Progress: 25.5 %
# Progress: 25.9 %
# Progress: 26.3 %
# Progress: 26.7 %
# Progress: 27.1 %
# Progress: 27.5 %
# Progress: 27.8 %
# Progress: 28.2 %
# Progress: 28.6 %
# Progress: 29.0 %
# Progress: 29.4 %
# Progress: 29.8 %
# Progress: 30.2 %
# Progress: 30.6 %
# Progress: 31.0 %
# Progress: 31.4 %
# Progress: 31.8 %
# Progress: 32.2 %
# Progress: 32.5 %
# Progress: 32.9 %
# Progress: 33.3 %
# Progress: 33.7 %
# Progress: 34.1 %
# Progress: 34.5 %
# Progress: 34.9 %
# Progress: 35.3 %
# Progress: 35.7 %
# Progress: 36.1 %
# Progress: 36.5 %
# Progress: 36.9 %
# Progress: 37.3 %
# Progress: 37.6 %
# Progress: 38.0 %
# Progress: 38.4 %
# Progress: 38.8 %
# Progress: 39.2 %
# Progress: 39.6 %
# Progress: 40.0 %
# Progress: 40.4 %
# Progress: 40.8 %
# Progress: 41.2 %
# Progress: 41.6 %
# Progress: 42.0 %
# Progress: 42.4 %
# Progress: 42.7 %
# Progress: 43.1 %
# Progress: 43.5 %
# Progress: 43.9 %
# Progress: 44.3 %
# Progress: 44.7 %
# Progress: 45.1 %
# Progress: 45.5 %
# Progress: 45.9 %
# Progress: 46.3 %
# Progress: 46.7 %
# Progress: 47.1 %
# Progress: 47.5 %
# Progress: 47.8 %
# Progress: 48.2 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b9a2d02347a3> in <module>()
#      84     return image
#      85
# ---> 86 new_image =  multi_otsu_thresholding(image)
#
# <ipython-input-7-b9a2d02347a3> in multi_otsu_thresholding(image)
#      53             #1. compute w0, w1 and w2: class occurence of all three classes
#      54             #2. compute u1, u2 and u3: class means of all three classes
# ---> 55             w0, u0 = compute_class_stats(histogram, 1, k1)
#      56             w1, u1 = compute_class_stats(histogram, k1 + 1, k2)
#      57             w2, u2 = compute_class_stats(histogram, k2 + 1, 255)
#
# <ipython-input-7-b9a2d02347a3> in compute_class_stats(histogram, lower_limit, upper_limit)
#       5     for i in range(lower_limit, upper_limit):
#       6         if(i +1 in histogram):
# ----> 7             class_occurance += histogram[i+1]
#       8     #compute class mean
#       9     for i in range(lower_limit, upper_limit):
#
# KeyboardInterrupt:

# %%
plt.figure(figsize = (500,20))
plt.imshow(new_image, cmap='gray')
plt.show()

# %%
plt.figure(figsize = (500,20))
new_image_smooth = cv2.medianBlur(new_image, 3)
plt.imshow(new_image_smooth, cmap='gray')
plt.show()

# %%
plt.figure(figsize = (500,20))
new_image_smooth_adaptive = cv2.adaptiveThreshold(new_image_smooth, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 9, 0)

plt.imshow(new_image_smooth_adaptive, cmap='gray')
plt.show()
