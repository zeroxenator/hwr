# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('image-output/test15_extracted.jpg', cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
_, image_bin = cv2.threshold(image,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
image_bin = 255 - image_bin
kernel = np.ones((5,5),np.uint8)
image_bin = cv2.morphologyEx(image_bin, cv2.MORPH_CLOSE, kernel)
image_bin = 255 - image_bin

#image_bin = cv2.medianBlur(image_bin, 3)

# %%
plt.figure(figsize = (500,10))
plt.imshow(image_bin, cmap='gray', aspect = 1)
plt.show()

# %%
image_bin = 255 - image_bin
n_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(image_bin, 8, cv2.CV_32S)
image_bin = 255 - image_bin
centroids
# Out:
# array([[  898.33823065,   539.35892586],
#        [ 1097.55199265,  1006.72639517],
#        [  165.5       ,    41.5       ],
#        [  316.66666667,    48.        ],
#        [ 1222.        ,   113.        ],
#        [ 1227.57931034,   186.48571429],
#        [ 1333.        ,   233.        ],
#        [  193.90518784,   288.92093023],
#        [ 1212.93877551,   242.67346939],
#        [   58.83824039,   296.12192587],
#        [  996.63698225,   331.22721893],
#        [ 1212.81034483,   283.20689655],
#        [  342.4730806 ,   300.49283211],
#        [ 1243.01136364,   284.76136364],
#        [  435.13091309,   301.31243124],
#        [ 1058.        ,   281.        ],
#        [ 1308.94069128,   331.53652789],
#        [  553.61706349,   309.09240363],
#        [  699.77620397,   308.85977337],
#        [  777.23196448,   312.87680355],
#        [ 1052.66666667,   297.33333333],
#        [ 1098.26703499,   339.56537753],
#        [ 1165.18097208,   333.25439504],
#        [ 1056.        ,   307.        ],
#        [ 1242.        ,   308.5       ],
#        [ 1207.76897321,   341.90848214],
#        [ 1237.11111111,   317.22222222],
#        [ 1492.30946502,   334.63209877],
#        [ 1411.78519856,   333.6299639 ],
#        [ 1611.38138925,   337.29357798],
#        [ 1246.19230769,   348.57692308],
#        [  289.11084553,   412.53152076],
#        [  791.59689643,   425.00505233],
#        [ 1259.        ,   382.5       ],
#        [   58.58868145,   408.79404901],
#        [ 1447.35722928,   442.97186933],
#        [  136.86170213,   414.96276596],
#        [  404.43776371,   415.8649789 ],
#        [  448.59757943,   417.07866868],
#        [  505.41109626,   421.0381016 ],
#        [  593.21560403,   425.22399329],
#        [ 1225.58730159,   413.28571429],
#        [  670.60853909,   428.34002058],
#        [ 1684.46912114,   442.60213777],
#        [    0.        ,   422.5       ],
#        [  913.69762746,   443.41039879],
#        [ 1183.        ,   422.5       ],
#        [ 1664.        ,   422.5       ],
#        [ 1173.        ,   426.        ],
#        [ 1185.        ,   429.        ],
#        [ 1279.21527778,   443.13425926],
#        [ 1575.10192147,   451.00083542],
#        [ 1624.54352031,   445.58027079],
#        [  399.80829016,   448.03972366],
#        [ 1676.85714286,   472.71428571],
#        [ 1684.5       ,   476.        ],
#        [ 1703.        ,   477.        ],
#        [ 1705.        ,   480.        ],
#        [ 1725.        ,   480.8125    ],
#        [ 1308.66666667,   484.33333333],
#        [ 1676.11148864,   583.16818858],
#        [ 1315.        ,   487.5       ],
#        [ 1184.        ,   489.        ],
#        [ 1375.66155492,   546.01890157],
#        [   29.00906149,   517.29773463],
#        [  256.80191859,   519.432979  ],
#        [  447.36740462,   519.12341027],
#        [   77.95949367,   515.15189873],
#        [  103.59766764,   515.01166181],
#        [  360.3630363 ,   522.45214521],
#        [  571.27398408,   522.12107248],
#        [  692.47058824,   523.85021786],
#        [  763.01976936,   528.04118616],
#        [  914.06784936,   538.46093993],
#        [  372.        ,   521.        ],
#        [  343.5       ,   524.5       ],
#        [ 1476.47562098,   548.29070837],
#        [ 1546.09222222,   547.07944444],
#        [  380.11320755,   532.45283019],
#        [ 1812.8346056 ,   539.55216285],
#        [ 1248.99647059,   554.64627451],
#        [ 1008.        ,   542.        ],
#        [ 1149.41647597,   562.97559115],
#        [  998.17647059,   561.29411765],
#        [ 1669.        ,   561.5       ],
#        [ 1671.42857143,   567.14285714],
#        [ 1674.        ,   579.5       ],
#        [  980.5       ,   584.5       ],
#        [  975.        ,   585.5       ],
#        [  987.5       ,   585.5       ],
#        [ 1479.38530585,   643.91256649],
#        [ 1675.14285714,   598.19047619],
#        [ 1181.62117997,   652.9155348 ],
#        [   58.67446271,   620.24336283],
#        [  287.81413549,   627.95035461],
#        [  118.23940678,   621.08898305],
#        [  150.23799127,   621.52838428],
#        [  554.57623075,   630.80589894],
#        [  406.64175258,   627.57216495],
#        [  774.3012766 ,   639.68042553],
#        [  857.48863636,   634.38920455],
#        [  699.71777476,   638.37720488],
#        [  952.        ,   625.        ],
#        [ 1594.37027027,   647.1277027 ],
#        [ 1911.02997449,   649.33545918],
#        [ 1935.62857143,   632.57142857],
#        [ 1341.91401702,   658.63546798],
#        [   39.63636364,   642.09090909],
#        [  400.03001715,   726.80017153],
#        [ 1664.06857367,   732.13479624],
#        [  712.04520397,   730.44597574],
#        [ 1436.04      ,   701.16      ],
#        [  184.54417514,   730.34636435],
#        [  832.4119349 ,   730.2954792 ],
#        [ 1658.33333333,   710.33333333],
#        [ 1681.        ,   711.        ],
#        [  975.17930793,   734.63753932],
#        [  275.04217736,   735.21593367],
#        [  521.6157429 ,   734.72473218],
#        [  613.96955773,   733.06145893],
#        [ 1557.3490566 ,   744.90711176],
#        [ 1950.4       ,   729.08571429],
#        [ 1430.78345324,   749.44964029],
#        [ 1317.44129264,   752.71382406],
#        [ 1490.02966102,   745.63665254],
#        [  847.        ,   747.        ],
#        [  753.        ,   761.        ],
#        [ 1630.94117647,   771.91176471],
#        [  809.        ,   774.5       ],
#        [ 1623.63414634,   779.2195122 ],
#        [  746.        ,   777.        ],
#        [ 1618.2       ,   787.4       ],
#        [ 1956.09090909,   794.54545455],
#        [  857.21900389,   820.47474391],
#        [  716.40309372,   827.83196846],
#        [  970.37012658,   822.29974684],
#        [ 1237.48837209,   805.81395349],
#        [  275.82191781,   815.19178082],
#        [  350.11664134,   828.67477204],
#        [  518.95573964,   833.56473373],
#        [ 1659.36979641,   834.56548162],
#        [ 1500.38252508,   840.65593645],
#        [  655.75      ,   840.25      ],
#        [  884.2       ,   846.8       ],
#        [ 1747.12903226,   855.70967742],
#        [  887.76      ,   853.44      ],
#        [ 1508.83333333,   858.54166667],
#        [  896.        ,   859.        ],
#        [  850.66666667,   864.66666667],
#        [  832.4       ,   868.3       ],
#        [  908.        ,   868.5       ],
#        [  915.63333333,   874.56666667],
#        [ 1752.        ,   870.        ],
#        [  904.47368421,   876.81578947],
#        [  762.59589993,   918.12508687],
#        [  566.61904762,   878.47619048],
#        [  595.81189882,   931.49875312],
#        [  921.5       ,   881.5       ],
#        [  910.8       ,   884.6       ],
#        [ 1518.        ,   884.        ],
#        [  906.75      ,   886.75      ],
#        [  897.58342115,   931.68071654],
#        [  557.        ,   915.        ],
#        [  686.50580645,   935.28903226],
#        [  506.29292929,   925.74747475],
#        [  462.40576767,   936.86839968],
#        [  972.        ,   920.        ],
#        [  760.43478261,   962.86956522],
#        [  714.11973392,  1026.25055432],
#        [  785.        ,   995.        ],
#        [ 1037.        ,  1006.5       ],
#        [  984.32952692,  1030.48531811],
#        [  829.93110048,  1034.6446571 ],
#        [ 1006.        ,  1052.        ],
#        [ 1011.        ,  1053.        ],
#        [  982.5       ,  1065.        ],
#        [ 1007.        ,  1065.        ],
#        [  994.        ,  1068.5       ],
#        [ 1015.        ,  1068.5       ],
#        [  979.        ,  1071.        ],
#        [ 1007.        ,  1071.        ],
#        [  763.24637284,  1128.05447577],
#        [  968.65      ,  1073.4       ],
#        [ 1003.        ,  1072.        ],
#        [  995.        ,  1075.5       ],
#        [ 1001.08333333,  1077.08333333],
#        [ 1009.57142857,  1079.52380952],
#        [  891.        ,  1082.33333333],
#        [  963.        ,  1082.        ],
#        [  975.94285714,  1086.85714286],
#        [  940.89963216,  1130.6489753 ],
#        [ 1017.        ,  1088.        ],
#        [  887.        ,  1088.5       ],
#        [  997.45833333,  1093.875     ],
#        [  915.        ,  1091.        ],
#        [  987.        ,  1096.        ],
#        [ 1010.        ,  1106.        ],
#        [ 1047.05102041,  1126.650913  ],
#        [  845.92857143,  1134.36904762],
#        [ 1007.        ,  1111.        ],
#        [  999.        ,  1114.        ],
#        [ 1005.5       ,  1121.1       ],
#        [ 1015.        ,  1139.        ],
#        [  961.5       ,  1151.5       ],
#        [ 1019.        ,  1150.        ],
#        [  977.33333333,  1155.66666667],
#        [ 1010.5       ,  1156.5       ],
#        [  888.31578947,  1160.94736842],
#        [  987.88888889,  1161.        ],
#        [  977.        ,  1170.        ],
#        [  988.        ,  1171.        ],
#        [  989.        ,  1174.        ],
#        [  976.        ,  1181.        ],
#        [  990.99006711,  1225.03704698],
#        [  904.        ,  1206.        ],
#        [ 1083.41142857,  1214.29714286],
#        [  905.        ,  1208.        ],
#        [ 1053.8       ,  1253.6       ],
#        [ 1110.54166667,  1445.45833333],
#        [ 1081.        ,  1515.33333333]])

# %%
n_labels
# Out:
# 220

# %%
stats
# Out:
# array([[      0,       4,    1975,    1518, 1418396],
#        [      0,       0,    1979,    1530, 1410834],
#        [    164,      41,       4,       2,       6],
#        ...,
#        [   1053,    1253,       3,       2,       5],
#        [   1108,    1442,       6,       7,      24],
#        [   1080,    1515,       3,       2,       3]], dtype=int32)

# %%
min_thresh = 400
max_thresh = 3000
boxes = []
box_centroids = []
for i in range(len(stats)):
    if(stats[i][4] >= min_thresh and stats[i][4] <= max_thresh):
        x = stats[i][0]
        y = stats[i][1]
        width = stats[i][2]
        height = stats[i][3]
        boxes.append(stats[i])
        box_centroids.append(centroids[i])
        cv2.rectangle(image,(x,y),(x + width,y + height),(0,200,0),3)

# %%
final_image = np.copy(image)
plt.figure(figsize = (500,14))
plt.imshow(final_image, cmap='gray', aspect = 1)
plt.show()

# %%
avg_width = 0
avg_height = 0
N = len(boxes)

# %%
for box in boxes:
    avg_width += box[2]
    avg_height += box[3]
avg_width /= N
avg_height /= N
avg_height *= 2

# %%
avg_width
# Out:
# 81.236111111111114

# %%
avg_height
# Out:
# 51.861111111111114

# %%
word_lines = []
line = []
# add first box to first line
line.append(boxes[0])
previous_centroid = box_centroids[0][1]
boxes.pop(0)
for i in range(len(boxes)):
    box = boxes[i]
    #check if box belongs to the same line as the previous one: check if centroid of box falls within the range of the previous
    #box
    centroid_y = box_centroids[i][1]
    if(centroid_y >= (previous_centroid - avg_height) and (centroid_y <= previous_centroid + avg_height)):
        line.append(box)
        previous_centroid = centroid_y
    else:
        #if not, add the line to the collection of lines and start a new one
        word_lines.append(line)
        line = []

# %%
image = cv2.imread('image-output/test15_extracted.jpg', cv2.IMREAD_GRAYSCALE)
width, height = image.shape
print(word_lines)
# Out:
# [[array([1217,  116,   31,  115, 1015], dtype=int32), array([ 146,  234,  105,   90, 2795], dtype=int32)], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]

# %%
min_height = 99999
max_height = 0

# %%
# draw lines for the first strip
for box in word_lines[0]:
    if(box[1] < min_height):
        min_height = box[1]
    elif(box[1] + box[3]  > max_height):
        max_height = box[1] + box[3] 

        
cv2.line(image,(0,min_height),(width, min_height),(0,200,0),3)    
cv2.line(image,(0,max_height),(width, max_height),(0,200,0),3) 
print(min_height)
print(max_height)
# Out:
# 116
# 324

# %%
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()
