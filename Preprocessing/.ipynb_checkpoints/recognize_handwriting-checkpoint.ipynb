# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *

# %%
path = 'image-data/test7.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image)
# Out:
# [[     0      4    751   1053 377149]
#  [     0      0    769   1057 346859]
#  [   341      7      2      1      2]
#  ...,
#  [   325   1022      2      2      3]
#  [   391   1022      1      1      1]
#  [   347   1024      2      1      2]]
# [180.08783992606092, 6]
# [276.76935165744101, 2]
# [373.87216721496844, 7]
# [471.6954295382746, 5]
# [556.73039537796581, 8]
# [668.16254712085265, 7]
# [751.81006384627892, 6]
# [829.87604836392279, 7]
# [926.68768414223143, 6]
# [992.41247368830705, 4]
