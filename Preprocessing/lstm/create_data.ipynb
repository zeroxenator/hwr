# %%
from create_words_dataset import *

# %%
generate_words()
# Out:
# Ngram #: 0
# Ngram: Lamed_Alef
# Ngram #: 1
# Ngram: Lamed_Waw_Kaf
# Ngram #: 2
# Ngram: Resh_Shin_Alef
# Ngram #: 3
# Ngram: Lamed_Ayin
# Ngram #: 4
# Ngram: Taw_Alef
# Ngram #: 5
# Ngram: Yod_Kaf
# Ngram #: 6
# Ngram: Alef_Waw_Lamed
# Ngram #: 7
# Ngram: Dalet_Ayin
# Ngram #: 8
# Ngram: Yod_Dalet
# Ngram #: 9
# Ngram: Nun-final_Mem-medial
# Ngram #: 10
# Ngram: Alef_Lamed
# Ngram #: 11
# Ngram: Shin_Yod_Alef
# Ngram #: 12
# Ngram: Mem_Ayin
# Ngram #: 13
# Ngram: Lamed_Waw_Kaf_Waw
# Ngram #: 14
# Ngram: Alef_Yod_Kaf
# Ngram #: 15
# Ngram: Taw_Alef_Waw
# Ngram #: 16
# Ngram: Alef_Waw_Lamed_Waw
# Ngram #: 17
# Ngram: Yod_Nun-medial_Bet
# Ngram #: 18
# Ngram: He_Kaf
# Ngram #: 19
# Ngram: Lamed_Waw_Kaf_Lamed
# Ngram #: 20
# Ngram: Lamed_Kaf
# Ngram #: 21
# Ngram: Lamed_Waw_Kaf_Bet
# Ngram #: 22
# Ngram: Waw_Lamed
# Ngram #: 23
# Ngram: Alef_Lamed_Waw
# Ngram #: 24
# Ngram: Alef_Waw_He
# Ngram #: 25
# Ngram #: 26
# Ngram: Waw_Bet
# Ngram #: 27
# Ngram: He_Lamed
# Ngram #: 28
# ...
